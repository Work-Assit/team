# %%
pip install python-docx textract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import docx
import textract
import re

def extract_skills_from_resume(file_path, skills_list):
    matched_skills = []

    # Extract text from different file formats
    file_extension = os.path.splitext(file_path)[1].lower()

    if file_extension == '.docx':
        doc = docx.Document(file_path)
        resume_text = ' '.join([p.text for p in doc.paragraphs])

    elif file_extension == '.pdf':
        resume_text = textract.process(file_path, method='pdfminer').decode('utf-8')

    elif file_extension == '.txt':
        with open(file_path, 'r', encoding='utf-8') as f:
            resume_text = f.read()

    else:
        return matched_skills

    for skill in skills_list:
        if re.search(r'\b' + re.escape(skill) + r'\b', resume_text, re.IGNORECASE):
            matched_skills.append(skill)

    return matched_skills

def extract_skills_from_folder(folder_path, skills_list):
    matched_skills = []

    # Iterate through files in the folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Extract skills from each resume
        if os.path.isfile(file_path):
            skills = extract_skills_from_resume(file_path, skills_list)
            if skills:
                matched_skills.append((file_name, skills))

    return matched_skills

# Example usage
folder_path = 'C:\\Users\\Shivam\\Desktop\\python\\77 work aasist'
skills =["Python", "Java", "JavaScript", "HTML", "CSS", "SQL","Analytical Skills","Good Communication Skills","Knowledge and understanding of banking products and services",
"Strong network within and outside the branch","Current-Account Knowledge","Team handling skills","Power Point", "Excel", "Word and MS Office", "C++ Basics","Business Development",
"Sales", "Team Management", "Customer Service", "Relationship Management","MS Office: Word", "Excel", "PowerPoint","DCA (Diploma in Computer ApplicationMS-office, Photoshop",
"Positive Attitude", "Comprehensive Problem Solving Abilities", "Efficient Time Management", "Hard Working","Positive Attitude", "Comprehensive Problem Solving Abilities", 
"Efficient Time Management", "Hard Working","Quick Learner", "Good Conversational Skills", "Self-Motivated", "Positive Attitude", "Burning Desire to Succeed", "Adaptability to Change", 
"Multitasking Ability","Calm under Pressure", "Effective Problem Solving","Typing speed wpm- 30","-MS-CIT","Patience", "Punctuality", "Hard Working", "Self-Confidence", "Positive Thinking",
"Microsoft Word", "Microsoft Excel", "Microsoft PowerPoint", "Microsoft Outlook","Passionate to learn","Excellent motivation","convincing power","	Dedication and determination towards the aim.",
"relationship building skill","Expert knowledge of the selling process","and effective sales technique","Pro-active, organized ","and a positive can-do attitude","Strong Interpersonal Organizational Skills",
"Sincerity towards Job", "Punctuality", "Ability to Cope Under Pressure", "Meticulousness", "Versatility", "Excellent Communication Skills", "Independence", "Teamwork","Goal-Oriented", "Quick Learner",
"Strong Work Ethic","Strong Client Relations", "Sales Experience", "Training Development Aptitude", "Excellent Communication Skills", "Self-Motivated","Basic Computer","Good time management and organizational skills",
"Excellent command over written and verbal communication","Familiar with major computer applications like MS Word, PowerPoint, and the internet","Communication","Manage time & resources effectively",
"have earned the title of “very well organized” among friends & family.A multitasker","Adaptable with positive & learning attitude","Windows 7&8","MS-Word, MS-Excel, MS-PowerPoint","Quick Learner","Self Confident", 
"Communication skills", "Help & patience","Customer service", "Communication Skills","Basic Accounting", "Office Management","Microsoft Office", "Sales and Marketing", "Team Management", "Banking Operation Skills", 
"Relationship Building", "Work Management Skills", "Communication Skills","I can type 30 Words per Minute.","Ability to adapt to different situations", "Hardworking & Straight Forward", "Positive thinking", "MS Word", "MS Excel",
"Knowledge and operation of MS Office", "Internet Browsing", "Tally ERP9","Composing e-mails", "Windows XP, Vista, Win7 MS Office", "Good knowledge of sales and marketing", "Knowledge of various types of sales",
"for each and every marketing strategy","Hard work", "Positive attitude", "Teamwork and Multitasking","MS-CIT", "Tally", "Typing", "Good in preparing daily revenue Reports", "Good interpersonal and organisational skills",
"IRDA certified with SP Code", "To speak: Hindi, English, Telugu, and Urdu", "To understand: Hindi, English, Telugu, Marathi, and Urdu", "To write: English, Hindi, and Telugu", "Diploma in Revit Architecture",
"Diploma in Auto Cad 2D & 3D", "Financial Business Analytics", "Team Management", "Big Data Analytics", "Negotiation Skills", "MS Excel", "Financial Risk Management", "Basic Skills Of Computer", "Solid Edge",
"C Programming", "CNC Programming", "MS Office", "Tally ERP9", "Hardworking nature", "Positive attitude", "Team building and leadership qualities","Communication Skills", "Digital Marketing",
"Market Research and Analysis", "Branding and Creative Skills", "Data Analysis", "Strategic Thinking", "Relationship Building", "Project Management", "Creativity and Innovation",
"Adaptability and Flexibility","Financial Analysis", "Risk Management", "Banking Regulations and Compliance", "Customer Service", "Sales and Business Development", "Financial Planning and Wealth Management",
"Communication and Interpersonal Skills", "Technology and Digital Banking", "Leadership and Team Management", "Attention to Detail and Analytical Thinking","Data Analysis", "Statistical Analysis",
"Data Visualization", "Programming Languages (e.g., Python, R)", "SQL and Database Management", "Machine Learning", "Data Mining and Data Warehousing", "Problem-Solving and Critical Thinking",
"Data Governance and Quality Assurance", "Business Acumen","Sales Techniques", "Customer Relationship Management (CRM)", "Strategic Planning", "Market Research and Analysis", "Brand Management",
"Digital Marketing", "Communication and Presentation Skills", "Relationship Building and Networking", "Analytical Skills", "Team Collaboration","Campaign Development and Execution",
"Market Research and Analysis", "Brand Management", "Digital Marketing", "Creative Thinking and Content Creation", "Data Analysis and Insights", "Communication and Presentation Skills",
"Project Management", "Client Relationship Management", "Team Collaboration and Leadership","Aircraft Design and Engineering", "Aerospace Systems and Technologies",
"Computer-Aided Design (CAD) and Simulation", "Aerospace Manufacturing and Production", "Aircraft Maintenance and Inspection", "Aerospace Testing and Evaluation",
"Systems Integration and Project Management", "Safety and Regulatory Compliance", "Aerospace Research and Development", "Communication and Collaboration","Crop and Soil Management",
"Livestock Care and Management", "Agricultural Machinery and Equipment", "Agribusiness and Farm Management", "Sustainable Agriculture Practices", "Research and Data Analysis",
"Crop Rotation and Diversification", "Pest and Disease Management", "Agricultural Policy and Regulations", "Communication and Collaboration","Programming Languages (e.g., Python, Java, C++, JavaScript)",
"Software Development", "Web Development (HTML, CSS, JavaScript, PHP, Ruby, Node.js)", "Database Management (SQL, NoSQL, MySQL, MongoDB)", "Networking and Infrastructure", "Cybersecurity", "Cloud Computing (AWS, Azure, Google Cloud)",
"IT Support and Troubleshooting", "Data Analysis and Visualization (Excel, Tableau, Python libraries)","Project Management", "Construction Methods and Techniques", "Blueprint Reading and Interpretation",
"Safety and Compliance", "Materials and Equipment Handling", "Team Leadership and Collaboration", "Problem Solving and Decision Making", "Quality Control and Assurance", "Communication and Negotiation", "Construction Documentation",
"Curriculum Development", "Instructional Design", "Classroom Management", "Differentiated Instruction", "Student Assessment and Evaluation", "Technology Integration", "Communication and Collaboration", "Special Education and Inclusion",
"Classroom Differentiation", "Professional Development","Renewable Energy Technologies", "Energy Management", "Sustainability Practices", "Project Development and Implementation", "Energy Policy and Regulations", "Data Analysis and Modeling",
"Energy Systems and Infrastructure", "Energy Economics and Financial Analysis", "Stakeholder Engagement", "Communication and Presentation","Performance Skills", "Stage or Set Design", "Production Management", "Scriptwriting or Screenwriting",
"Directing or Choreography", "Technical Skills", "Creative Development", "Improvisation", "Event Planning and Promotion", "Audience Engagement","Fashion Design", "Trend Forecasting", "Styling", "Garment Construction", "Textile Knowledge", "Fashion Illustration",
"Fashion Branding", "Fashion Merchandising", "Fashion Retailing", "Fashion Photography", "Fashion Marketing and PR", "Fashion Technology","Data Analysis", "Economic Modeling", "Policy Analysis", "Quantitative Research", "Economic Forecasting", "Financial Analysis",
"Microeconomic Theory", "Macroeconomic Analysis", "Econometric Analysis", "Policy Evaluation", "Economic Reporting and Communication", "Economic Research","Culinary Skills", "Food Safety and Hygiene", "Menu Development", "Beverage Knowledge", "Customer Service",
"Operations Management", "Team Leadership", "Communication and Interpersonal Skills", "Problem-Solving", "Adaptability and Multitasking", "Knowledge of Dietary Restrictions", "Menu Costing and Profitability","Patient Care", "Medical Knowledge", "Technical Skills",
"Clinical Skills", "Interdisciplinary Collaboration", "Communication Skills", "Problem-Solving and Critical Thinking", "Attention to Detail", "Empathy and Emotional Intelligence", "Time Management", "Adaptability and Flexibility", "Continuous Learning","Customer Service",
"Communication", "Interpersonal Skills", "Attention to Detail", "Problem-Solving", "Time Management", "Flexibility and Adaptability", "Conflict Resolution", "Technical Skills", "Multilingual Skills", "Sales and Upselling", "Knowledge of Local Attractions","Manufacturing Processes",
"Equipment Operation", "Quality Control", "Lean Manufacturing", "Safety Compliance", "Problem-Solving", "Technical Skills", "Teamwork and Collaboration", "Time Management", "Attention to Detail", "Communication Skills", "Continuous Learning","Mining Operations", "Safety Compliance",
"Equipment Operation", "Geological Knowledge", "Mine Planning and Management", "Maintenance and Repairs", "Environmental Stewardship", "Teamwork and Collaboration", "Problem-Solving", "Data Analysis and Reporting", "Communication Skills", "Continuous Learning","Pharmaceutical Research",
"Drug Development", "Quality Control", "Regulatory Compliance", "Pharmaceutical Manufacturing", "Analytical Skills", "Data Analysis and Interpretation", "Documentation and Reporting", "Project Management", "Communication Skills", "Teamwork and Collaboration", "Continuous Learning","Network Operations",
"Telecommunication Technologies", "System Maintenance", "Troubleshooting", "Data and Voice Communication", "Network Security", "Customer Support", "Project Management", "Documentation and Reporting", "Vendor Management", "Communication Skills", "Continuous Learning","Transportation Operations", "Logistics",
"Safety and Compliance", "Vehicle Operation", "Route Optimization", "Customer Service", "Problem-Solving", "Time Management", "Communication Skills", "Technology Proficiency", "Documentation and Reporting", "Continuous Learning"]

matched_skills = extract_skills_from_folder(folder_path, skills)

# Print file name and matched skills
for file_name, skills in matched_skills:
    print(f"File: {file_name}")
    print(f"Skills: {skills}")
    print()
# Out:
# File: ABHIJEET REXWAL.docx
# Skills: ['Power Point', 'Excel', 'Word and MS Office', 'C++ Basics', 'Sales', 'Excel', 'Hard Working', 'Hard Working', 'Hard Working', 'Positive Thinking', 'Communication', 'Positive thinking', 'MS Office', 'Communication']
#
# File: AMAN BHARDWAJ.docx
# Skills: ['Business Development', 'Sales', 'Sales and Business Development']
#
# File: ANISH KUMAR.docx
# Skills: ['Business Development']
#
# File: ARUN KUMAR AKKUDA.docx
# Skills: ['Sales']
#
# File: ARUNA KUMARI.docx
# Skills: ['Customer Service', 'Customer service', 'Customer Service', 'Technical Skills', 'Customer Service', 'Technical Skills', 'Time Management', 'Customer Service', 'Time Management', 'Technical Skills', 'Technical Skills', 'Time Management', 'Customer Service', 'Time Management']
#
# File: ASHOK BABA.docx
# ...

# %%
import os
import docx
import textract
import re
import pandas as pd

def extract_skills_from_resume(file_path, skills_list):
    matched_skills = []

    # Extract text from different file formats
    file_extension = os.path.splitext(file_path)[1].lower()

    if file_extension == '.docx':
        doc = docx.Document(file_path)
        resume_text = ' '.join([p.text for p in doc.paragraphs])

    elif file_extension == '.pdf':
        resume_text = textract.process(file_path, method='pdfminer').decode('utf-8')

    elif file_extension == '.txt':
        with open(file_path, 'r', encoding='utf-8') as f:
            resume_text = f.read()

    else:
        return matched_skills

    matched_skills = [skill for skill in skills_list if re.search(r'\b' + re.escape(skill) + r'\b', resume_text, re.IGNORECASE)]
    return matched_skills

def extract_skills_from_folder(folder_path, skills_list):
    matched_skills = []

    # Iterate through files in the folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Extract skills from each resume
        if os.path.isfile(file_path):
            skills = extract_skills_from_resume(file_path, skills_list)
            if skills:
                matched_skills.append([file_name, ', '.join(skills)])

    return matched_skills

# Example usage
folder_path = 'C:\\Users\\Shivam\\Desktop\\python\\77 work aasist'
skills =["Python", "Java", "JavaScript", "HTML", "CSS", "SQL","Analytical Skills","Good Communication Skills","Knowledge and understanding of banking products and services",
"Strong network within and outside the branch","Current-Account Knowledge","Team handling skills","Power Point", "Excel", "Word and MS Office", "C++ Basics","Business Development",
"Sales", "Team Management", "Customer Service", "Relationship Management","MS Office: Word", "Excel", "PowerPoint","DCA (Diploma in Computer ApplicationMS-office, Photoshop",
"Positive Attitude", "Comprehensive Problem Solving Abilities", "Efficient Time Management", "Hard Working","Positive Attitude", "Comprehensive Problem Solving Abilities", 
"Efficient Time Management", "Hard Working","Quick Learner", "Good Conversational Skills", "Self-Motivated", "Positive Attitude", "Burning Desire to Succeed", "Adaptability to Change", 
"Multitasking Ability","Calm under Pressure", "Effective Problem Solving","Typing speed wpm- 30","-MS-CIT","Patience", "Punctuality", "Hard Working", "Self-Confidence", "Positive Thinking",
"Microsoft Word", "Microsoft Excel", "Microsoft PowerPoint", "Microsoft Outlook","Passionate to learn","Excellent motivation","convincing power","	Dedication and determination towards the aim.",
"relationship building skill","Expert knowledge of the selling process","and effective sales technique","Pro-active, organized ","and a positive can-do attitude","Strong Interpersonal Organizational Skills",
"Sincerity towards Job", "Punctuality", "Ability to Cope Under Pressure", "Meticulousness", "Versatility", "Excellent Communication Skills", "Independence", "Teamwork","Goal-Oriented", "Quick Learner",
"Strong Work Ethic","Strong Client Relations", "Sales Experience", "Training Development Aptitude", "Excellent Communication Skills", "Self-Motivated","Basic Computer","Good time management and organizational skills",
"Excellent command over written and verbal communication","Familiar with major computer applications like MS Word, PowerPoint, and the internet","Communication","Manage time & resources effectively",
"have earned the title of “very well organized” among friends & family.A multitasker","Adaptable with positive & learning attitude","Windows 7&8","MS-Word, MS-Excel, MS-PowerPoint","Quick Learner","Self Confident", 
"Communication skills", "Help & patience","Customer service", "Communication Skills","Basic Accounting", "Office Management","Microsoft Office", "Sales and Marketing", "Team Management", "Banking Operation Skills", 
"Relationship Building", "Work Management Skills", "Communication Skills","I can type 30 Words per Minute.","Ability to adapt to different situations", "Hardworking & Straight Forward", "Positive thinking", "MS Word", "MS Excel",
"Knowledge and operation of MS Office", "Internet Browsing", "Tally ERP9","Composing e-mails", "Windows XP, Vista, Win7 MS Office", "Good knowledge of sales and marketing", "Knowledge of various types of sales",
"for each and every marketing strategy","Hard work", "Positive attitude", "Teamwork and Multitasking","MS-CIT", "Tally", "Typing", "Good in preparing daily revenue Reports", "Good interpersonal and organisational skills",
"IRDA certified with SP Code", "To speak: Hindi, English, Telugu, and Urdu", "To understand: Hindi, English, Telugu, Marathi, and Urdu", "To write: English, Hindi, and Telugu", "Diploma in Revit Architecture",
"Diploma in Auto Cad 2D & 3D", "Financial Business Analytics", "Team Management", "Big Data Analytics", "Negotiation Skills", "MS Excel", "Financial Risk Management", "Basic Skills Of Computer", "Solid Edge",
"C Programming", "CNC Programming", "MS Office", "Tally ERP9", "Hardworking nature", "Positive attitude", "Team building and leadership qualities","Communication Skills", "Digital Marketing",
"Market Research and Analysis", "Branding and Creative Skills", "Data Analysis", "Strategic Thinking", "Relationship Building", "Project Management", "Creativity and Innovation",
"Adaptability and Flexibility","Financial Analysis", "Risk Management", "Banking Regulations and Compliance", "Customer Service", "Sales and Business Development", "Financial Planning and Wealth Management",
"Communication and Interpersonal Skills", "Technology and Digital Banking", "Leadership and Team Management", "Attention to Detail and Analytical Thinking","Data Analysis", "Statistical Analysis",
"Data Visualization", "Programming Languages (e.g., Python, R)", "SQL and Database Management", "Machine Learning", "Data Mining and Data Warehousing", "Problem-Solving and Critical Thinking",
"Data Governance and Quality Assurance", "Business Acumen","Sales Techniques", "Customer Relationship Management (CRM)", "Strategic Planning", "Market Research and Analysis", "Brand Management",
"Digital Marketing", "Communication and Presentation Skills", "Relationship Building and Networking", "Analytical Skills", "Team Collaboration","Campaign Development and Execution",
"Market Research and Analysis", "Brand Management", "Digital Marketing", "Creative Thinking and Content Creation", "Data Analysis and Insights", "Communication and Presentation Skills",
"Project Management", "Client Relationship Management", "Team Collaboration and Leadership","Aircraft Design and Engineering", "Aerospace Systems and Technologies",
"Computer-Aided Design (CAD) and Simulation", "Aerospace Manufacturing and Production", "Aircraft Maintenance and Inspection", "Aerospace Testing and Evaluation",
"Systems Integration and Project Management", "Safety and Regulatory Compliance", "Aerospace Research and Development", "Communication and Collaboration","Crop and Soil Management",
"Livestock Care and Management", "Agricultural Machinery and Equipment", "Agribusiness and Farm Management", "Sustainable Agriculture Practices", "Research and Data Analysis",
"Crop Rotation and Diversification", "Pest and Disease Management", "Agricultural Policy and Regulations", "Communication and Collaboration","Programming Languages (e.g., Python, Java, C++, JavaScript)",
"Software Development", "Web Development (HTML, CSS, JavaScript, PHP, Ruby, Node.js)", "Database Management (SQL, NoSQL, MySQL, MongoDB)", "Networking and Infrastructure", "Cybersecurity", "Cloud Computing (AWS, Azure, Google Cloud)",
"IT Support and Troubleshooting", "Data Analysis and Visualization (Excel, Tableau, Python libraries)","Project Management", "Construction Methods and Techniques", "Blueprint Reading and Interpretation",
"Safety and Compliance", "Materials and Equipment Handling", "Team Leadership and Collaboration", "Problem Solving and Decision Making", "Quality Control and Assurance", "Communication and Negotiation", "Construction Documentation",
"Curriculum Development", "Instructional Design", "Classroom Management", "Differentiated Instruction", "Student Assessment and Evaluation", "Technology Integration", "Communication and Collaboration", "Special Education and Inclusion",
"Classroom Differentiation", "Professional Development","Renewable Energy Technologies", "Energy Management", "Sustainability Practices", "Project Development and Implementation", "Energy Policy and Regulations", "Data Analysis and Modeling",
"Energy Systems and Infrastructure", "Energy Economics and Financial Analysis", "Stakeholder Engagement", "Communication and Presentation","Performance Skills", "Stage or Set Design", "Production Management", "Scriptwriting or Screenwriting",
"Directing or Choreography", "Technical Skills", "Creative Development", "Improvisation", "Event Planning and Promotion", "Audience Engagement","Fashion Design", "Trend Forecasting", "Styling", "Garment Construction", "Textile Knowledge", "Fashion Illustration",
"Fashion Branding", "Fashion Merchandising", "Fashion Retailing", "Fashion Photography", "Fashion Marketing and PR", "Fashion Technology","Data Analysis", "Economic Modeling", "Policy Analysis", "Quantitative Research", "Economic Forecasting", "Financial Analysis",
"Microeconomic Theory", "Macroeconomic Analysis", "Econometric Analysis", "Policy Evaluation", "Economic Reporting and Communication", "Economic Research","Culinary Skills", "Food Safety and Hygiene", "Menu Development", "Beverage Knowledge", "Customer Service",
"Operations Management", "Team Leadership", "Communication and Interpersonal Skills", "Problem-Solving", "Adaptability and Multitasking", "Knowledge of Dietary Restrictions", "Menu Costing and Profitability","Patient Care", "Medical Knowledge", "Technical Skills",
"Clinical Skills", "Interdisciplinary Collaboration", "Communication Skills", "Problem-Solving and Critical Thinking", "Attention to Detail", "Empathy and Emotional Intelligence", "Time Management", "Adaptability and Flexibility", "Continuous Learning","Customer Service",
"Communication", "Interpersonal Skills", "Attention to Detail", "Problem-Solving", "Time Management", "Flexibility and Adaptability", "Conflict Resolution", "Technical Skills", "Multilingual Skills", "Sales and Upselling", "Knowledge of Local Attractions","Manufacturing Processes",
"Equipment Operation", "Quality Control", "Lean Manufacturing", "Safety Compliance", "Problem-Solving", "Technical Skills", "Teamwork and Collaboration", "Time Management", "Attention to Detail", "Communication Skills", "Continuous Learning","Mining Operations", "Safety Compliance",
"Equipment Operation", "Geological Knowledge", "Mine Planning and Management", "Maintenance and Repairs", "Environmental Stewardship", "Teamwork and Collaboration", "Problem-Solving", "Data Analysis and Reporting", "Communication Skills", "Continuous Learning","Pharmaceutical Research",
"Drug Development", "Quality Control", "Regulatory Compliance", "Pharmaceutical Manufacturing", "Analytical Skills", "Data Analysis and Interpretation", "Documentation and Reporting", "Project Management", "Communication Skills", "Teamwork and Collaboration", "Continuous Learning","Network Operations",
"Telecommunication Technologies", "System Maintenance", "Troubleshooting", "Data and Voice Communication", "Network Security", "Customer Support", "Project Management", "Documentation and Reporting", "Vendor Management", "Communication Skills", "Continuous Learning","Transportation Operations", "Logistics",
"Safety and Compliance", "Vehicle Operation", "Route Optimization", "Customer Service", "Problem-Solving", "Time Management", "Communication Skills", "Technology Proficiency", "Documentation and Reporting", "Continuous Learning"]

skills = extract_skills_from_folder(folder_path, skills)

# Save output to Excel file
output_file = 'Skills.xlsx'

df = pd.DataFrame(matched_skills, columns=['File', 'Skills'])
df.to_excel(output_file, index=False)
print(f"Skills saved to {output_file} file.")
# Out:
# Skills saved to Skills.xlsx file.
