# %%
# !pip install python-docx
# !pip install PyPDF2
# Out:
# Requirement already satisfied: python-docx in c:\users\mihir shah\anaconda3\lib\site-packages (0.8.11)
# Requirement already satisfied: lxml>=2.3.2 in c:\users\mihir shah\anaconda3\lib\site-packages (from python-docx) (4.9.1)
# Requirement already satisfied: PyPDF2 in c:\users\mihir shah\anaconda3\lib\site-packages (3.0.1)

# %%
import os
import docx
import PyPDF2

# List of possible designations in preferential order
possible_designations = [
    "President",
 "Vice President",
 "Assistant Vice President",
 "Branch President",
 "Brach Supervisor",
 "Branch Head",
 "Senior Manager",
 "Sr Manager",
 "Senior Bank Officer",
 "Senior Officer",
 "Senior Processing Officer",
 "Branch Manager",
 "Branch Credit Manager",
 "Deputy Branch Manager",
 "Deputy Manager",
 "Assistant Branch Manager",
 "Relationship Manager",
 "Relationship Officer",
 "Assistant Manager",
 "Team Manager",
 "Team Leader",
 "Team Leader(Sales & Marketing)",
 "Asset & Wealth Manager",
 "Asset Desk Manager",
 "Wealth Manager",
 "Portfolio Manager",
 "Assistant Portfolio Manager",
 "Assistant Portfolio Manager-Sales",
 "Credit & Risk Analyst",
 "Credit Analyst",
 "Analyst",
 "Branch Operations Manager",
 "Branch Sales Manager",
 "Area Business Manager",
 "Area Manager", 
 "Area Retail Officer",
 "Area Officer",
 "Business Developpment Executive",
 "Desk Manager",
 "Desk Officer",
 "Processing Executive",
 "Process Associate",
 "Aquisition Manager",
 "Assistant Aquisition Manager",
 "Bank Assurance Officer",
 "Privilege Banker",
 "Personal Banker",
 "Senior Sales Officer",
 "Sales Executive",
 "Sales Manager",
 "Associate Sales Manager",
 "Sales Officer",
 "Branch Sales Officer",
 "Sales & Marketing Officer",
 "CASA Sales Officer",
 "Sales Representative",
 "Marketing Executive",
 "Marketing Officer",
 "Business Sales Manager",
 "Unit Sales Manager",
 "Assistant Sales Executive",
 "Field Sales Executive",
 "Retail Sales Executive",
 "Junior Sales Executive",
 "Tele Sales Officer",
 "Sales Promoter",
 "Brand Promoter",
 "Category Head Promoter",
 "Store Manager",
 "Assistant Store Manager",
 "SSE - Store Sales Executive",
 "Sales Trainee",
 "Operations Manager",
 "Financial Planner",
 "Associate Financial Service Manager",
 "Financial Consultant",
 "Investment Advisor",
 "Senior Relationship Manager",
 "Senior Customer Service Executive",
 "Key Relationship Manager",
 "Relationship Executive",
 "Assistant Relationship Manager",
 "Customer Relationship Manager",
 "Digital Relationship Manager",
 "E - Relationship Manager",
 "Assistant E - Relationship Manager",
 "Customer Service Manager",
 "Customer Service Officer",
 "Customer Representative Manager",
 "Customer Service Executive",
 "Customer Service Associate",
 "Citizen Service Executive",
 "CSR Executive",
 "Front Office Executive",
 "Senior Account Officer",
 "Account Manager ",
 "Key Account Manager",
 "Accounts Officer",
 "Accounts Incharge",
 "Accountant",
 "Assistant Accountant",
 "Employee Welfare Officer",
 "Contract Administrative Employee",
 "Agency Developpment Manager",
 "Corporate Agency Manager",
 "Agency Manager",
 "Diploma Engineering Trainee",
 "Extreme Fiber Executive",
 "Senior Fashion Consultant",
 "Fashion Consultant",
 "Fashion Advisor",
 "Patient's Care Executive",
 "Technician"
]

# Function to extract present designation from a DOCX file
def extract_designation_from_docx(file_path):
    doc = docx.Document(file_path)
    for paragraph in doc.paragraphs:
        for designation in possible_designations:
            if designation.lower() in paragraph.text.lower():
                return designation
    return None

# Function to extract present designation from a PDF file
def extract_designation_from_pdf(file_path):
    with open(file_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            text = page.extract_text()
            for designation in possible_designations:
                if designation.lower() in text.lower():
                    return designation
    return None

# Folder containing resumes
resumes_folder = "D://Work_A"

# Iterate over files in the folder
for file_name in os.listdir(resumes_folder):
    file_path = os.path.join(resumes_folder, file_name)
    if file_name.endswith(".docx"):
        designation = extract_designation_from_docx(file_path)
    elif file_name.endswith(".pdf"):
        designation = extract_designation_from_pdf(file_path)
    else:
        continue
    
    if designation:
        print(f"{file_name}: {designation}")
    else:
        print(f"{file_name}: Designation not found")
# Out:
# Abhijeet_rexwal.docx: Account Manager
# AK_khan.docx: Fashion Advisor
# Amankumar_Akurada.docx: Sales Officer
# Aman_Bharadwaj.docx: Senior Sales Officer
# Amit_Tekwani.pdf: Account Manager
# aneel_sahoo.docx: Branch Manager
# Anish_Kumar.docx: Relationship Manager
# Aruna_kumari.docx: Assistant Manager
# Ashok_baba.docx: Sales Officer
# Asit_paul.docx: Relationship Manager
# Aspathwar_naresh.docx: Relationship Manager
# atul_sharma.docx: Branch Manager
# babasreeta_mishra.docx: Desk Officer
# Bhakti_parmar.pdf: Designation not found
# bhavna_mulchandani.pdf: Branch Manager
# biswaranjan_kar.docx: Branch Manager
# Boudhuru_satishkumar.pdf: Designation not found
# Chandrakant_sahebrao_kanade.docx: Deputy Manager
# Chirag_Bhatt.docx: Relationship Manager
# Deepakkumar_Patnaik.docx: Agency Manager
# Golajana_Ravi.docx: Accountant
# Hamid_Zarger.docx: Bank Assurance Officer
# Hemant_Sharma.pdf: Area Business Manager
# Hema_Singh.docx: Assistant Manager
# Ippli_Chanti.docx: Relationship Officer
# Israr_Ali.docx: Senior Sales Officer
# Javedakhtar_Chaudhri.docx: Relationship Manager
# Jeetendra_Kumar.docx: Sales Representative
# Kalpana_Sk.pdf: Designation not found
# karthikeyan.docx: Process Associate
# Kaustabh_Manjrekar.docx: Area Manager
# Kavya_Santoshkumar.docx: Sales Executive
# Kiran_s.docx: Assistant Manager
# Krishan_Shekhawat.docx: Store Manager
# Kushal_Agrawal.docx: Relationship Manager
# Laxmanrao_MyCharla.pdf: Designation not found
# Mahesh_Ayyappa.docx: Team Leader
# Mahesh_balukolhe.docx: Sales Executive
# Mane_Gopal.docx: Sales Manager
# Manisha_Prasad.docx: Customer Service Manager
# Mohammad_baig.docx: Sales Executive
# Monica_kinger.pdf: Wealth Manager
# Mouli_karnaparthi.docx: Sales Manager
# Mustak_abbigairi.pdf: Designation not found
# Nana_Dungarnath_Bhandari.docx: Sales Executive
# Neelmani_Arora.docx: Deputy Manager
# Neetu_Kumar.docx: Designation not found
# Nikshita_B.docx: Assistant Manager
# nirakar_sahoo.docx: Senior Manager
# Nityananda.docx: Sales Manager
# N_Sandiya.pdf: Designation not found
# pankaj_sahoo.docx: Branch Head
# Parvezuddin.docx: Sales Executive
# Patha_Chaterjee.docx: Relationship Manager
# prabhudatta_das.pdf: Branch Manager
# Pratik_Shelke.docx: Deputy Manager
# Premkumar_M.docx: Relationship Manager
# Pritam_Das.docx: Operations Manager
# priyanka_gupta.docx: Branch Manager
# Rachabanti_shivkrishna.pdf: Sales Executive
# rajeev_soni.docx: Branch Sales Manager
# rajeshkumar_dora.docx: Branch Manager
# Raman_mishra.docx: Relationship Officer
# Ravilla_Jagdish.docx: Credit & Risk Analyst
# Ravi_kumar.docx: Branch Manager
# ritesh_mishra.docx: Branch Manager
# Sagar_Dhanna.pdf: Assistant Manager
# Samabraju_naveen.pdf: Store Manager
# sambit_chaudhri.docx: Branch Manager
# Sanchita.docx: Assistant Manager
# sanjeev_banerjee.docx: Senior Manager
# sanket_sharma.pdf: Senior Manager
# santosh_nanda.docx: Branch Manager
# Santosh_Singh_A.pdf: Sales Manager
# Santosh_Singh_B.docx: Designation not found
# saptdeep_guha.docx: Branch Head
# saroj_mahapatra.docx: Branch Manager
# Satish_Kumar.docx: Sales Executive
# saumitra_tripathy.docx: Branch Manager
# Sd_Yakub_Paasha.docx: Relationship Manager
# Shabeer_Mulla.pdf: Designation not found
# Shaik_Rehman.pdf: Sales Executive
# Shashank_Paliwaal.docx: Relationship Manager
# Shubhangi_Singh.docx: CSR Executive
# Sivannarayana_M.docx: Senior Processing Officer
# Sonal_Anand.docx: Relationship Manager
# sumant_biswal.docx: Branch Head
# sumeet_raut.docx: Deputy Manager
# Susanth_Koro.docx: Sales Officer
# Syam_Sunder.docx: Branch Manager
# Tabraiz_Mehdi.docx: Senior Fashion Consultant
# tushar_mathur.docx: Branch Manager
# Vikash_anand.docx: Branch Credit Manager
# Vikash_Sharma.pdf: Branch Manager
# Vikrant_Singh.docx: Sales Officer
# Vishwa_Teja_Tiruvairupati.docx: Relationship Manager
# Vivek_Singh.pdf: Designation not found

# %%
import os
import docx
import PyPDF2

# List of possible designations in preferential order
possible_designations = [
     "President",
 "Vice President",
 "Assistant Vice President",
 "Branch President",
 "Brach Supervisor",
 "Branch Head",
 "Senior Manager",
 "Sr Manager",
 "Senior Bank Officer",
 "Senior Officer",
 "Senior Processing Officer",
 "Branch Manager",
 "Branch Credit Manager",
 "Deputy Branch Manager",
 "Deputy Manager",
 "Assistant Branch Manager",
 "Relationship Manager",
 "Relationship Officer",
 "Assistant Manager",
 "Team Manager",
 "Team Leader",
 "Team Leader(Sales & Marketing)",
 "Asset & Wealth Manager",
 "Asset Desk Manager",
 "Wealth Manager",
 "Portfolio Manager",
 "Assistant Portfolio Manager",
 "Assistant Portfolio Manager-Sales",
 "Credit & Risk Analyst",
 "Credit Analyst",
 "Analyst",
 "Branch Operations Manager",
 "Branch Sales Manager",
 "Area Business Manager",
 "Area Manager", 
 "Area Retail Officer",
 "Area Officer",
 "Business Developpment Executive",
 "Desk Manager",
 "Desk Officer",
 "Processing Executive",
 "Process Associate",
 "Aquisition Manager",
 "Assistant Aquisition Manager",
 "Bank Assurance Officer",
 "Privilege Banker",
 "Personal Banker",
 "Senior Sales Officer",
 "Sales Executive",
 "Sales Manager",
 "Associate Sales Manager",
 "Sales Officer",
 "Branch Sales Officer",
 "Sales & Marketing Officer",
 "CASA Sales Officer",
 "Sales Representative",
 "Marketing Executive",
 "Marketing Officer",
 "Business Sales Manager",
 "Unit Sales Manager",
 "Assistant Sales Executive",
 "Field Sales Executive",
 "Retail Sales Executive",
 "Junior Sales Executive",
 "Tele Sales Officer",
 "Sales Promoter",
 "Brand Promoter",
 "Category Head Promoter",
 "Store Manager",
 "Assistant Store Manager",
 "SSE - Store Sales Executive",
 "Sales Trainee",
 "Operations Manager",
 "Financial Planner",
 "Associate Financial Service Manager",
 "Financial Consultant",
 "Investment Advisor",
 "Senior Relationship Manager",
 "Senior Customer Service Executive",
 "Key Relationship Manager",
 "Relationship Executive",
 "Assistant Relationship Manager",
 "Customer Relationship Manager",
 "Digital Relationship Manager",
 "E - Relationship Manager",
 "Assistant E - Relationship Manager",
 "Customer Service Manager",
 "Customer Service Officer",
 "Customer Representative Manager",
 "Customer Service Executive",
 "Customer Service Associate",
 "Citizen Service Executive",
 "CSR Executive",
 "Front Office Executive",
 "Senior Account Officer",
 "Account Manager ",
 "Key Account Manager",
 "Key account manager",
 "Accounts Officer",
 "Accounts Incharge",
 "Accountant",
 "Assistant Accountant",
 "Employee Welfare Officer",
 "Contract Administrative Employee",
 "Agency Developpment Manager",
 "Corporate Agency Manager",
 "Agency Manager",
 "Diploma Engineering Trainee",
 "Extreme Fiber Executive",
 "Senior Fashion Consultant",
 "Fashion Consultant",
 "Fashion Advisor",
 "Patient's Care Executive",
 "Technician"
]

# Function to extract present designation from a DOCX file
def extract_designation_from_docx(file_path):
    doc = docx.Document(file_path)
    for paragraph in doc.paragraphs:
        for designation in possible_designations:
            if designation.lower() in paragraph.text.lower():
                return designation
    return None

# Function to extract present designation from a PDF file
def extract_designation_from_pdf(file_path):
    with open(file_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            text = page.extract_text()
            for designation in possible_designations:
                if designation.lower() in text.lower():
                    return designation
    return None

# Folder containing resumes
resumes_folder = "D://new_cvs"

# Iterate over files in the folder
for file_name in os.listdir(resumes_folder):
    file_path = os.path.join(resumes_folder, file_name)
    if file_name.endswith(".docx"):
        designation = extract_designation_from_docx(file_path)
    elif file_name.endswith(".pdf"):
        designation = extract_designation_from_pdf(file_path)
    else:
        continue
    
    if designation:
        print(f"{file_name}: {designation}\n")
    else:
        print(f"{file_name}: Designation not found")
# Out:
# 0_Babasreeta Mishra Resume.docx: Desk Officer
#
# A JOSEPHIN STELLA-BM_Work Assist.docx: Branch Head
#
# Abhijeet rexwal - Customer sales officer - 4 Yrs 0 Month.docx: Account Manager
#
# Abhishek kumar pandey - workassist.docx: Designation not found
# Aditi chauhan - Key account manager - 8 Yrs 0 Month.docx: Accountant
#
# Aditi chauhan - Key account manager - 8 Yrs 0 Month_1.docx: Accountant
#
# Ak khan - Fashion consultant - 6 Yrs 0 Month.docx: Fashion Advisor
#
# AkshayGurav - workassist.docx: Deputy Manager
#
# Aman bharadwaj  - Deputy manager - 2 Yrs 0 Month.docx: Senior Sales Officer
#
# Anand mishra - Select relationship manager - 7 Yrs 0 Month.docx: Assistant Manager
#
# Anand mishra - Select relationship manager - 7 Yrs 0 Month_1.docx: Assistant Manager
#
# AnimeshMishra - workassist.docx: Deputy Manager
#
# AnimeshMishra - workassist_1.docx: Deputy Manager
#
# Anshu thakur - Relationship manager - 2 Yrs 0 Month.docx: Designation not found
# Aparna venkatesan - Assistant manager - 1 Yr 0 Month.docx: Assistant Manager
#
# Arun kumar akkurada - Agency development manager - 11 Yrs 0 Month.docx: Sales Officer
#
# ArunaKumari__Visakhapatnam_4.03_yrs.docx: Assistant Manager
#
# Arunkumar  - Area sales manager - 8 Yrs 0 Month.docx: Sales Manager
#
# Ashok baba - Sales officer - 4 Yrs 0 Month.docx: Sales Officer
#
# Asit paul - Privilege banker - 8 Yrs 5 Months.docx: Relationship Manager
#
# Aspathwar naresh - Relationship manager - 6 Yrs 0 Month.docx: Relationship Manager
#
# AVIJIT GHOSH RESUME.docx: Designation not found
# AVIJIT GHOSH RESUME_1.docx: Designation not found
# Ayesha_Naik_resume_2023.docx: Designation not found
# Ayesha_Naik_resume_2023_1.docx: Designation not found
# B raza hussain hussain - Relationship manager banca channel - 7 Yrs 6 Months.docx: Relationship Manager
#
# Bhakti h parmar - Relationship manager - 1 Yr 0 Month.docx: Designation not found
# Bhaven thakrar - Senior manager - 10 Yrs 0 Month.docx: Designation not found
# Bhaven thakrar - Senior manager - 10 Yrs 0 Month_1.docx: Designation not found
# Bipul laskar - Deputy manager - 6 Yrs 0 Month.docx: Accountant
#
# Bipul laskar - Deputy manager - 6 Yrs 0 Month_1.docx: Accountant
#
# Biswaranjan kar  - Branch manager - 10 Yrs 0 Month (1).docx: Branch Manager
#
# Boddhuru satish kumar - Deputy manager - 0 Yr 8 Months.docx: Designation not found
# CA Rajhath Kapoor.docx: Designation not found
# CA Rajhath Kapoor_1.docx: Designation not found
# Chandrakant sahebrao kanade - Deputy manager - 8 Yrs 0 Month.docx: Deputy Manager
#
# Cheziyan  - Relationship manager - 3 Yrs 4 Months.docx: Relationship Officer
#
# Darshan damania - Sr manager - 9 Yrs 0 Month.docx: Credit Analyst
#
# Darshan damania - Sr manager - 9 Yrs 0 Month_1.docx: Credit Analyst
#
# DEEPAKKUMARPATNAIK__Visakhapatnam_6.06_yrs.docx: Agency Manager
#
# Dilip Singh CV....docx: Senior Officer
#
# Dilip Singh CV..._1.docx: Senior Officer
#
# DIVYA JINDAL - workassist.docx: Relationship Manager
#
# DIVYA JINDAL - workassist_1.docx: Relationship Manager
#
# DOC-20230116-WA0002..docx: Relationship Manager
#
# DOC-20230421-WA0037. (1) (1) (1).docx: Designation not found
# DOC-20230421-WA0037. (1) (1) (1)_1.docx: Designation not found
# DOC-20230421-WA0037. (1) (1).docx: Designation not found
# DOC-20230421-WA0037. (1) (1)_1.docx: Designation not found
# DOC-20230421-WA0037. (1).docx: Designation not found
# DOC-20230421-WA0037..docx: Designation not found
# Farvin m - Relationship manager - 2 Yrs 9 Months.docx: Relationship Manager
#
# Girish tripathi - Relationships officer - 10 Yrs 0 Month (1).docx: Relationship Manager
#
# Girish tripathi - Relationships officer - 10 Yrs 0 Month.docx: Relationship Manager
#
# GolajanaRavi__Visakhapatnam_1.06_yrs.docx: Accountant
#
# Hamid ahmad zargar - Senior relationship manager - 6 Yrs 0 Month.docx: Designation not found
# Hema - workassist.docx: Assistant Manager
#
# Hemant sharma  - Sales officer field - 4 Yrs 0 Month.docx: Designation not found
# iimjobs_Alok_Goel.docx: Sales Manager
#
# iimjobs_Alok_Goel_1.docx: Sales Manager
#
# iimjobs_Ankit_pandey.docx: Team Leader
#
# iimjobs_Ankit_pandey_1.docx: Team Leader
#
# iimjobs_Anshuman_Sarkar.docx: Branch Head
#
# iimjobs_Arun_Kumar_N_V.docx: Analyst
#
# iimjobs_Divyanshu_vijay.docx: Key Account Manager
#
# iimjobs_Ganapathyramarajan.docx: Relationship Manager
#
# iimjobs_Kunal_Phate (1).docx: President
#
# iimjobs_Kunal_Phate (1)_1.docx: President
#
# iimjobs_Kundan_Chauhan (1).docx: Assistant Manager
#
# iimjobs_Kundan_Chauhan (1)_1.docx: Assistant Manager
#
# iimjobs_Mahesh.docx: Designation not found
# iimjobs_Mahesh_1.docx: Designation not found
# iimjobs_Manishkumar_Rameshchandra_Patel.docx: Designation not found
# iimjobs_Manishkumar_Rameshchandra_Patel_1.docx: Designation not found
# iimjobs_Mohita_Pant_Bhaduri.docx: Designation not found
# iimjobs_Mohita_Pant_Bhaduri_1.docx: Designation not found
# iimjobs_MOHUDDIN.docx: President
#
# iimjobs_MOHUDDIN_1.docx: President
#
# iimjobs_Prashant_Subramanian.docx: Senior Manager
#
# iimjobs_Rajneesh_K_Jha.docx: Senior Manager
#
# iimjobs_Rajneesh_K_Jha_1.docx: Senior Manager
#
# iimjobs_RAKHESH_RAGHUNATH_NAIR.docx: Designation not found
# iimjobs_RAKHESH_RAGHUNATH_NAIR_1.docx: Designation not found
# iimjobs_Ramesh_Singh_Rawat.docx: Branch Head
#
# iimjobs_Sandeep_Jagdhane.docx: Sales Manager
#
# iimjobs_Sandeep_Jagdhane_1.docx: Sales Manager
#
# iimjobs_shelendra_agarwal.docx: Branch Manager
#
# iimjobs_shelendra_agarwal_1.docx: Branch Manager
#
# iimjobs_Tadipatri_Madhav_Murthy.docx: Designation not found
# iimjobs_Tadipatri_Madhav_Murthy_1.docx: Designation not found
# IppiliChanti__Visakhapatnam_1_yrs.docx: Relationship Officer
#
# Israr ali - Assistant manager - 3 Yrs 0 Month (2).docx: Senior Sales Officer
#
# Javedakhtar choudhary - Relationship manager - 6 Yrs 0 Month (1).docx: Relationship Manager
#
# Jayanta kumar kalita - Deputy manager - 7 Yrs 0 Month.docx: Accountant
#
# Jayanta kumar kalita - Deputy manager - 7 Yrs 0 Month_1.docx: Accountant
#
# Jeetendra kumar - Deputy manager - 4 Yrs 0 Month.docx: Sales Representative
#
# Kalaiyarasan g - Relationship manager - 5 Yrs 0 Month.docx: Designation not found
# Kalpana sk - Sales executive customer - 1 Yr 0 Month.docx: Designation not found
# Kamol kalita - Branch sales manager - 7 Yrs 0 Month (1) (1).docx: Branch Sales Manager
#
# Kamol kalita - Branch sales manager - 7 Yrs 0 Month (1) (1)_1.docx: Branch Sales Manager
#
# Karthikeyan Resume.docx: Process Associate
#
# Kiran c shinde - Assistant manager - 3 Yrs 6 Months.docx: Assistant Manager
#
# Kiran c shinde - Assistant manager - 3 Yrs 6 Months_1.docx: Assistant Manager
#
# Kiran s  - Relationship manager - 5 Yrs 0 Month.docx: Assistant Manager
#
# Koushik chakraborty  - Deputy manager 1 - 5 Yrs 0 Month.docx: Relationship Executive
#
# KOYYASANTOSHKUMAR__Visakhapatnam_5_yrs.docx: Sales Executive
#
# Kuldeep  - Deputy manager - 4 Yrs 8 Months.docx: Sales Executive
#
# Kuldeep  - Deputy manager - 4 Yrs 8 Months_1.docx: Sales Executive
#
# Kushal agrawal - Relationship manager - 1 Yr 1 Month.docx: Relationship Manager
#
# LakshmanraoMycharla__Visakhapatnam_0.04_yrs.docx: Designation not found
# Latest Resume 2023 2.docx: Credit Analyst
#
# Latest Resume 2023 2_1.docx: Credit Analyst
#
# LOHITHSH__Bengaluru_Bangalore_8.09_yrs.docx: Designation not found
# LOHITHSH__Bengaluru_Bangalore_8.09_yrs_1.docx: Designation not found
# Mahesh ayyappa bagaler - Sales executive - 4 Yrs 0 Month (1).docx: Team Leader
#
# Mahesh desai - Sale - 10 Yrs 7 Months.docx: Sales Officer
#
# Mamta yadav - Deputy manager - 5 Yrs 0 Month.docx: Operations Manager
#
# Mamta yadav - Deputy manager - 5 Yrs 0 Month_1.docx: Operations Manager
#
# Mane gopal - Relationship manager - 3 Yrs 0 Month.docx: Sales Manager
#
# ManishaPrasad - workassist.docx: Customer Service Manager
#
# Manne  - Chief manager - 11 Yrs 0 Month.docx: Relationship Manager
#
# Manne  - Chief manager - 11 Yrs 0 Month_1.docx: Relationship Manager
#
# manoj fernandez_40660466.docx: Designation not found
# manoj fernandez_40660466_1.docx: Designation not found
# Mohammed faisal baig - Sales executive officer - 0 Yr 0 Month.docx: Sales Executive
#
# MonicaKinger__Gurgaon_Gurugram_0.06_yrs.docx: Designation not found
# Mouli Kanaparthi CV.docx: Sales Manager
#
# Muhmmad ameer - Workassist.docx: Deputy Manager
#
# muhmmadameer CV.docx: Deputy Manager
#
# muhmmadameer CV_1.docx: Deputy Manager
#
# MukutAli[4y_8m] (1) (1).docx: Sales Executive
#
# MukutAli[4y_8m] (1) (1)_1.docx: Sales Executive
#
# Mustak abbigeri - Sales officer - 1 Yr 0 Month (2).docx: Designation not found
# Muthu kumar  - Relationship manager - 4 Yrs 4 Months.docx: Relationship Manager
#
# Muzammil. v - Sales officer - 3 Yrs 0 Month.docx: Sales Officer
#
# Naukri_AbdulNabiShaikh[6y_0m] (1).docx: Relationship Manager
#
# Naukri_AbdulNabiShaikh[6y_0m].docx: Relationship Manager
#
# Naukri_AbhijeetSingh[6y_0m].docx: Relationship Manager
#
# Naukri_Amitendrasinghthakur[6y_6m].docx: Relationship Manager
#
# Naukri_Amitendrasinghthakur[6y_6m]_1.docx: Relationship Manager
#
# Naukri_AMITTTEKWANI[12y_0m].docx: Designation not found
# Naukri_AmrutGupta[4y_6m].docx: Sales Officer
#
# Naukri_ARDHENDUSAHA[3y_6m].docx: Designation not found
# Naukri_AshishPandey[7y_4m].docx: Relationship Manager
#
# Naukri_awnishsingh[7y_0m].docx: Relationship Manager
#
# Naukri_BEDPRAKASHGUPTA[10y_0m].docx: Branch Manager
#
# Naukri_BikashKumarNath[12y_0m].docx: Designation not found
# Naukri_ChiragAshokBhatt[15y_0m].docx: Relationship Manager
#
# Naukri_DeepakAggarwal[12y_0m].docx: Team Leader
#
# Naukri_deepakbaraily[6y_0m].docx: Accountant
#
# Naukri_deepakbaraily[6y_0m]_1.docx: Accountant
#
# Naukri_DeepikaKota[4y_0m].docx: Designation not found
# Naukri_GovindMohanThakur[14y_0m].docx: Analyst
#
# Naukri_GovindMohanThakur[14y_0m]_1.docx: Analyst
#
# Naukri_HemalathaVelusamy[7y_0m].docx: Senior Manager
#
# Naukri_HimanshuPratapSingh[4y_0m].docx: Deputy Manager
#
# Naukri_HimanshuPratapSingh[4y_0m]_1.docx: Deputy Manager
#
# Naukri_HirenkumarNai[6y_6m].docx: Relationship Manager
#
# Naukri_kalyani[8y_0m].docx: Deputy Manager
#
# Naukri_KanikaBansal[2y_3m].docx: Team Leader
#
# Naukri_KanikaBansal[2y_3m]_1.docx: Team Leader
#
# Naukri_KaustubhManjrekar[10y_0m].docx: Area Manager
#
# Naukri_MaheshBaluKolhe[6y_6m].docx: Sales Executive
#
# Naukri_MAKANIRAJANKUMAR[4y_2m].docx: Relationship Manager
#
# Naukri_MFarhanChaudhari[11y_0m].docx: Team Leader
#
# Naukri_MFarhanChaudhari[11y_0m]_1.docx: Team Leader
#
# Naukri_NanaDurganathBhandari[4y_0m].docx: Sales Executive
#
# Naukri_NeelamKumari[7y_0m].docx: Designation not found
# Naukri_NeelamKumari[7y_0m]_1.docx: Designation not found
# Naukri_PankajChhatrodiya[6y_6m].docx: Senior Officer
#
# Naukri_Parvezuddin[11y_0m].docx: Sales Executive
#
# Naukri_PrashantYogi[4y_0m].docx: Deputy Manager
#
# Naukri_PrashantYogi[4y_0m]_1.docx: Deputy Manager
#
# Naukri_PratikRajendraShelke[9y_9m].docx: Deputy Manager
#
# Naukri_PreetikaDamani[12y_0m].docx: President
#
# Naukri_princenaveen[4y_6m].docx: Designation not found
# Naukri_Rahuljha[4y_7m].docx: Designation not found
# Naukri_Rahuljha[4y_7m]_1.docx: Designation not found
# Naukri_RAJESHCHILUMALA[7y_0m].docx: Assistant Manager
#
# Naukri_RAJESHCHILUMALA[7y_0m]_1.docx: Assistant Manager
#
# Naukri_RITUPARNABISWAS[3y_0m].docx: Sales Executive
#
# Naukri_RITUPARNABISWAS[3y_0m]_1.docx: Sales Executive
#
# Naukri_RuckmaniMeena[6y_6m].docx: Customer Service Officer
#
# Naukri_RuckmaniMeena[6y_6m]_1.docx: Customer Service Officer
#
# Naukri_SagarGSawant[16y_0m].docx: Assistant Manager
#
# Naukri_saikumarsinghb[10y_0m].docx: Senior Manager
#
# Naukri_SaurabhAbhishek[7y_6m].docx: Relationship Manager
#
# Naukri_SaurabhAbhishek[7y_6m]_1.docx: Relationship Manager
#
# Naukri_SHIKRITIADAK[6y_6m].docx: Assistant Manager
#
# Naukri_ShubhangSunkara[0y_1m].docx: Designation not found
# Naukri_ShubhangSunkara[0y_1m]_1.docx: Designation not found
# Naukri_SiddharthRJain[11y_4m].docx: Assistant Manager
#
# Naukri_SINGHPREETIRAJANISHA[6y_0m].docx: Relationship Manager
#
# Naukri_SnigdhaKumari[4y_6m].docx: Privilege Banker
#
# Naukri_Subbulakshmis[17y_0m].docx: Relationship Manager
#
# Naukri_SurajBhalerao[11y_0m].docx: Designation not found
# Naukri_SurajBhalerao[11y_0m]_1.docx: Designation not found
# Naukri_SUVANKARDEB[6y_6m].docx: Sales Executive
#
# Naukri_vipulsprajapati[12y_0m].docx: Relationship Executive
#
# Naukri_YOGESWARISK[16y_0m].docx: Relationship Manager
#
# Naukri_YuvanaSabharish[12y_0m].docx: Senior Manager
#
# Navin chandra - Senior business development manager - 7 Yrs 3 Months (1).docx: Relationship Manager
#
# Navin chandra - Senior business development manager - 7 Yrs 3 Months (1)_1.docx: Relationship Manager
#
# Navin chandra - Senior business development manager - 7 Yrs 3 Months.docx: Relationship Manager
#
# Navin chandra - Senior business development manager - 7 Yrs 3 Months_1.docx: Relationship Manager
#
# Neelmani arora  - Deputy manager - 7 Yrs 4 Months.docx: Deputy Manager
#
# Neetu  - Sales officer - 3 Yrs 0 Month (1).docx: Designation not found
# Nehamishra_Work assist (1).docx: Assistant Manager
#
# Nehamishra_Work assist.docx: Assistant Manager
#
# NIKHIL ZOPE RESUME - workassist (1).docx: Account Manager
#
# Nikshitha  - Relationship manager - 4 Yrs 0 Month.docx: Assistant Manager
#
# Nishant Patel_Work Assist.docx: Personal Banker
#
# Nishi kanta barui - Customer relationship officer - 1 Yr 10 Months.docx: Designation not found
# Nithyananda nithyananda - Business development manager - 5 Yrs 0 Month.docx: Sales Manager
#
# Pankaj sharma - Senior preferred relationship manager - 6 Yrs 0 Month (1).docx: Sales Manager
#
# Parinaz tavadia - Branch operation manager - 15 Yrs 0 Month.docx: Branch Manager
#
# Piyush sinha - Client service - 10 Yrs 0 Month.docx: Team Leader
#
# Piyush vaid - Preferred relationship manager - 2 Yrs 0 Month (1).docx: Designation not found
# Piyush vaid - Preferred relationship manager - 2 Yrs 0 Month (1)_1.docx: Designation not found
# Piyush vaid - Preferred relationship manager - 2 Yrs 0 Month.docx: Designation not found
# Piyush vaid - Preferred relationship manager - 2 Yrs 0 Month_1.docx: Designation not found
# Prasenjit sardar - Finance - 3 Yrs 0 Month.docx: Designation not found
# PreetiSarkar__Mumbai_2.01_yrs.docx: Designation not found
# PreetiSarkar__Mumbai_2.01_yrs_1.docx: Designation not found
# Premkumar - workassist.docx: Relationship Manager
#
# PritamDas__Visakhapatnam_5.11_yrs.docx: Operations Manager
#
# Rachabantishivakrishna  - Sales executive - 4 Yrs 5 Months.docx: Designation not found
# Rajesh_Workassist (1)_.docx: Branch Manager
#
# Rakhi mahato - Deputy manager - 1 Yr 0 Month.docx: Deputy Manager
#
# Ramakrishnan  - Relationship officer - 3 Yrs 10 Months.docx: Relationship Officer
#
# Ramakrishnan  - Relationship officer - 3 Yrs 10 Months_1.docx: Relationship Officer
#
# Raman mishra - Casa sales officer - 5 Yrs 1 Month.docx: Relationship Officer
#
# RAMU M_Work Assist.docx: Senior Manager
#
# Ramya  - Business development manager - 4 Yrs 0 Month.docx: Relationship Officer
#
# RASHMI SHARMA CV.docx: Senior Manager
#
# Ravi  - Deputy manager - 5 Yrs 0 Month (1).docx: Sales Executive
#
# Ravi gupta - Relationship officer - 6 Yrs 4 Months.docx: Designation not found
# Ravi gupta - Relationship officer - 6 Yrs 4 Months_1.docx: Designation not found
# Ravi kumar - Manager - 6 Yrs 0 Month.docx: Branch Manager
#
# Ravi roshan - workassist.docx: Sales Manager
#
# Ravi roshan - workassist_1.docx: Sales Manager
#
# Ravilla-Jagadeesh-updated-Resume.docx: Credit & Risk Analyst
#
# Resume (3) (1).docx: Sales Officer
#
# Resume (4).docx: Designation not found
# Resume (5).docx: Relationship Manager
#
# Resume (5)_1.docx: Relationship Manager
#
# resume_d_dias.docx: Designation not found
# resume_d_dias_1.docx: Designation not found
# Reume Swarup Banerjee .docx: Sales Manager
#
# Ritik nigam - Senior deputy manager - 4 Yrs 0 Month.docx: Deputy Manager
#
# Rubi sah - Deputy manager - 3 Yrs 0 Month.docx: Designation not found
# rubiyaparveen[10y_0m].docx: Portfolio Manager
#
# rubiyaparveen[10y_0m]_1.docx: Portfolio Manager
#
# Sagar dhanna - Relationship manager - 6 Yrs 0 Month.docx: Designation not found
# Sai bharadwaj anantaraju - Manager - 8 Yrs 0 Month (1).docx: Relationship Manager
#
# Sai bharadwaj anantaraju - Manager - 8 Yrs 0 Month (1)_1.docx: Relationship Manager
#
# Sai bharadwaj anantaraju - Manager - 8 Yrs 0 Month.docx: Relationship Manager
#
# Sai bharadwaj anantaraju - Manager - 8 Yrs 0 Month_1.docx: Relationship Manager
#
# Sanchita  - Relationship manager - 6 Yrs 0 Month.docx: Assistant Manager
#
# Santosh kumar - Deputy manager - 7 Yrs 0 Month.docx: Deputy Manager
#
# Santosh kumar - Deputy manager - 7 Yrs 0 Month_1.docx: Deputy Manager
#
# Santosh singh - Am - 6 Yrs 0 Month.docx: Sales Officer
#
# Santosh singh - Business development executive - 6 Yrs 6 Months.docx: Designation not found
# Saranya dasi - Assistant manager - 4 Yrs 6 Months.docx: Assistant Manager
#
# Saranya dasi - Assistant manager - 4 Yrs 6 Months_1.docx: Assistant Manager
#
# Satish kumar - Retail sales executive - 5 Yrs 6 Months (1).docx: Sales Executive
#
# Satish kumar - Retail sales executive - 5 Yrs 6 Months.docx: Sales Executive
#
# Sd yakub pasha - Relationship manager - 4 Yrs 0 Month.docx: Relationship Manager
#
# Senthilkumar Kulandaivelu_Work Assist.docx: Relationship Manager
#
# Shabeer mulla - Sales officer - 3 Yrs 0 Month.docx: Designation not found
# Shaik rehman - Sales executive - 5 Yrs 2 Months.docx: Designation not found
# Shailendea singh pawar - Relationship manager - 7 Yrs 6 Months.docx: Relationship Manager
#
# Shailendea singh pawar - Relationship manager - 7 Yrs 6 Months_1.docx: Relationship Manager
#
# Shaisthabanu__Chennai_4.08_yrs.docx: Designation not found
# Shaisthabanu__Chennai_4.08_yrs_1.docx: Designation not found
# Shashank Paliwal - workassist.docx: Relationship Manager
#
# Sheeja Kuriakose-BM_Work Assist.docx: Branch Manager
#
# Shubhanshi singh - Deputy manager - 6 Yrs 0 Month.docx: CSR Executive
#
# Shweta singh - Value banker - 8 Yrs 6 Months.docx: Senior Officer
#
# Single  - Branch sales manager - 9 Yrs 1 Month.docx: Branch Sales Manager
#
# Single  - Branch sales manager - 9 Yrs 1 Month_1.docx: Branch Sales Manager
#
# Sivaraj  - Deputy manager - 4 Yrs 0 Month.docx: Relationship Manager
#
# Sneha balasubramanyam - Manager retail - 6 Yrs 1 Month.docx: Assistant Manager
#
# Sneha balasubramanyam - Manager retail - 6 Yrs 1 Month_1.docx: Assistant Manager
#
# Sneha__Hyderabad_Secunderabad,Telangana_1_yrs.docx: Team Leader
#
# Sneha__Hyderabad_Secunderabad,Telangana_1_yrs_1.docx: Team Leader
#
# Soutick bhattacharjee  - Presently working in bandhan bank ltd as a branch sales officer from 17th aug2015 to till date. - 7 Yrs 0 Month (1) (2).docx: Assistant Manager
#
# Spondon neog  - Assistant manager - 7 Yrs 0 Month.docx: Sales Officer
#
# Spondon neog  - Assistant manager - 7 Yrs 0 Month_1.docx: Sales Officer
#
# Sunny Mukherjee..docx: Deputy Manager
#
# Sunny Mukherjee._1.docx: Deputy Manager
#
# SupriyaTarafdar__Guwahati_5.02_yrs.docx: Deputy Manager
#
# SupriyaTarafdar__Guwahati_5.02_yrs_1.docx: Deputy Manager
#
# Susanth koro - Senior officer - 7 Yrs 6 Months.docx: Sales Officer
#
# SYAMSUNDAR__Visakhapatnam_11.01_yrs.docx: Branch Manager
#
# Tabraiz  mehdi  - Senior sales advisor - 8 Yrs 3 Months.docx: Senior Fashion Consultant
#
# Talla rajashekar reddy - Senior manager - 7 Yrs 0 Month (1).docx: Designation not found
# Talla rajashekar reddy - Senior manager - 7 Yrs 0 Month (1)_1.docx: Designation not found
# Talla rajashekar reddy - Senior manager - 7 Yrs 0 Month.docx: Designation not found
# Talla rajashekar reddy - Senior manager - 7 Yrs 0 Month_1.docx: Designation not found
# TimesJobs_ABHINAY Wasnik_148789305.docx: Relationship Officer
#
# TimesJobs_ABHINAY Wasnik_148789305_1.docx: Relationship Officer
#
# TimesJobs_Anurag Sharma_147281150.docx: Designation not found
# TimesJobs_APURBA BANERJEE _129653097.docx: Deputy Manager
#
# TimesJobs_APURBA BANERJEE _129653097_1.docx: Deputy Manager
#
# TimesJobs_Dipak Mondal _142980348.docx: Customer Service Officer
#
# TimesJobs_Dipak Mondal _142980348_1.docx: Customer Service Officer
#
# TimesJobs_Eswari Gadepalli_145845543.docx: Branch Manager
#
# TimesJobs_Eswari Gadepalli_145845543_1.docx: Branch Manager
#
# TimesJobs_Haridas Khelkar_152290403.docx: Assistant Manager
#
# TimesJobs_Haridas Khelkar_152290403_1.docx: Assistant Manager
#
# TimesJobs_KUNAL CHAITRAM SHENDE _149170196.docx: Designation not found
# TimesJobs_KUNAL CHAITRAM SHENDE _149170196_1.docx: Designation not found
# TimesJobs_MOHMMAD SULTHAN_119871403.docx: Designation not found
# TimesJobs_MOHMMAD SULTHAN_119871403_1.docx: Designation not found
# TimesJobs_mukeesh ahmad _149515398.docx: Sales Executive
#
# TimesJobs_Piyush  Garghate_152629533.docx: Sales Officer
#
# TimesJobs_Piyush  Garghate_152629533_1.docx: Sales Officer
#
# TimesJobs_Rahul Ganguly _144069423.docx: Designation not found
# TimesJobs_Rahul Ganguly _144069423_1.docx: Designation not found
# TimesJobs_Randhir kanojiya_151424264.docx: Relationship Officer
#
# TimesJobs_Randhir kanojiya_151424264_1.docx: Relationship Officer
#
# TimesJobs_SABIR ALAM_117478302.docx: Deputy Manager
#
# TimesJobs_SABIR ALAM_117478302_1.docx: Deputy Manager
#
# TimesJobs_Sandeep Singh _149274090.docx: Relationship Manager
#
# TimesJobs_vikas yadav_144445882.docx: Relationship Officer
#
# TimesJobs_VIPIN Sakhare_148098130.docx: Deputy Manager
#
# TimesJobs_VIPIN Sakhare_148098130_1.docx: Deputy Manager
#
# Ujjwal mishra - Yes premia relationship manager - 9 Yrs 0 Month.docx: Assistant Manager
#
# Ujjwal mishra - Yes premia relationship manager - 9 Yrs 0 Month_1.docx: Assistant Manager
#
# Updated CV Gaurav.docx: Assistant Manager
#
# Vikash sharma - Branch sales manager - 7 Yrs 3 Months.docx: Designation not found
# vikrantsingh__Gurgaon_Gurugram_8.1_yrs.docx: Sales Officer
#
# Viswa teja tiruvaipati - Relationship manager - 5 Yrs 0 Month.docx: Relationship Manager
#
# Vivek singh - Manager - 3 Yrs 6 Months.docx: Designation not found
# work assist M.Bhakialakshmi[11y_0m] (1).docx: Branch Manager
#
# Work Assist_AMITKUMAR[16y_0m] (1).docx: Designation not found
# Work Assist_AMITKUMAR[16y_0m] (1)_1.docx: Designation not found
# Work Assist_AMITKUMAR[16y_0m].docx: Designation not found
# Work Assist_AnileshKumarSingh[16y_0m].docx: Analyst
#
# Work Assist_DEEPAKKUMAR[1y_0m].docx: Senior Officer
#
# Work Assist_DEEPAKKUMAR[1y_0m]_1.docx: Senior Officer
#
# Work Assist_DurgeshYadav[7y_0m].docx: Deputy Manager
#
# Work Assist_DurgeshYadav[7y_0m]_1.docx: Deputy Manager
#
# Work Assist_Resume Somya (1) (1).docx: Designation not found
# Work Assist_Resume Somya (1) (1)_1.docx: Designation not found
# Work Assist_Resume Somya (1).docx: Designation not found
# Work Assist_SachinKumar[17y_0m].docx: Senior Manager
#
# WorkassistsPANKAJLOCHANSAHOO[12y_0m] (1).docx: Branch Head
#
# Workassist_AnishKumar[3y_6m].docx: Relationship Manager
#
# Workassist_AritraChakraborty[18y_0m].docx: Accountant
#
# Workassist_KrishanShekhawat[12y_0m].docx: Store Manager
#
# Workassist_MAHENDRANAM[7y_0m] (1) (1).docx: Designation not found
# Workassist_Prashant.docx: Deputy Manager
#
# Workassist_Prashant_1.docx: Deputy Manager
#
# Workassist_Ranjit mhase  - Chief manager legal - 11 Yrs 0 Month.docx: Senior Manager
#
# Workassist_rupamjha[1y_6m].docx: Sales Manager
#
# Workassist_VivekAwasthi[16y_0m].docx: Relationship Manager
#
# workassit.in Pathachatterjee.docx: Relationship Manager
