# %%
import os
import docx
import textract
import re

def extract_skills_from_resume(file_path, skills_list):
    matched_skills = []

    # Extract text from different file formats
    file_extension = os.path.splitext(file_path)[1].lower()

    if file_extension == '.docx':
        doc = docx.Document(file_path)
        resume_text = ' '.join([p.text for p in doc.paragraphs])

    elif file_extension == '.pdf':
        resume_text = textract.process(file_path, method='pdfminer').decode('utf-8')

    elif file_extension == '.txt':
        with open(file_path, 'r', encoding='utf-8') as f:
            resume_text = f.read()

    else:
        return matched_skills

    for skill in skills_list:
        if re.search(r'\b' + re.escape(skill) + r'\b', resume_text, re.IGNORECASE):
            matched_skills.append(skill)

    return matched_skills

def extract_skills_from_folder(folder_path, soft_skills_list, technical_skills_list):
    matched_skills = []

    # Iterate through files in the folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Extract skills from each resume
        if os.path.isfile(file_path):
            skills = extract_skills_from_resume(file_path, soft_skills_list + technical_skills_list)
            if skills:
                matched_skills.append((file_name, skills))

    return matched_skills

# Example usage
folder_path = 'C:\\Users\\Shivam\\Desktop\\python\\300 work assist'
soft_skills = [ "Analytical Skills", "Good Communication", "Strong network", "Team handling", "Business Development",
               "Sales", "Team Management", "Customer Service", "Relationship Management", "Positive Attitude",
               "Comprehensive Problem Solving", "Efficient Time Management", "Hard Working", "Quick Learner",
               "Conversational Skills", "Self-Motivated", "Burning Desire to Succeed", "Adaptability to Change",
               "Multitasking Ability", "Calm under Pressure", "Patience", "Punctuality", "Self-Confidence",
               "Positive Thinking", "Passionate to learn", "Excellent motivation", "Convincing power",
               "Dedication and determination", "Relationship building", "Expert knowledge of the selling process",
               "Pro-active, organized, and a can-do attitude", "Interpersonal Organizational Skills", 
               "Sincerity towards Job", "Ability to Cope Under Pressure", "Meticulousness", "Versatility",
               "Independence", "Teamwork", "Goal-Oriented", "Strong Work Ethic", "Strong Client Relations",
               "Training Development Aptitude", "Basic Computer", "Good time management and organizational skills",
               "Excellent command over written and verbal communication", "Manage time & resources effectively",
               "Adaptable with positive & learning attitude", "Straight Forward", "Help & patience",
               "Basic Accounting", "Office Management", "Good knowledge of sales and marketing",
               "Knowledge of various types of sales", "Hard work", "Multitasking",
               "Good in preparing daily revenue Reports", "Good interpersonal and organizational skills",
               "To speak: Hindi, English, Telugu, and Urdu", "To understand: Marathi", "To write: Hindi",
               "Hardworking nature", "Team building and leadership qualities", "Market Research and Analysis",
               "Branding and Creative Skills", "Strategic Thinking", "Project Management", "Creativity and Innovation",
               "Adaptability and Flexibility", "Attention to Detail and Analytical Thinking", "Strategic Planning",
               "Brand Management", "Digital Marketing", "Creative Thinking and Content Creation",
               "Data Analysis and Insights", "Client Relationship Management", "Campaign Development and Execution",
               "Current-Account Knowledge", "Banking Operation Skills", "Work Management Skills", "Relationship Building",
               "Team Collaboration", "Conflict Resolution", "Continuous Learning","Never say die attitud","Give 100% to my job",
               "Fast Learner","Adaptable to all situations","Accept Challenges","Melting Knowledge","High Adaptability"
               "Self Confident and Hard Working","Dedication and Perfection in work","pressure handling","Very meticulous and versatile",
               "Sincerity towards job and punctuality","Able to cope under pressure","Convincing Power and good communication skills","self-motivate & dynamic",
               "emotionally stable","spoken communication skills","Achieving branch target","Sales and target oriented","Compliance ","Believe in ethics & morals",
               "Client Acquisition Skills.",""
              ]
technical_skills = [
"Python", "Java", "JavaScript", "HTML", "CSS", "SQL", "Power Point", "Excel", "Word", "MS Office", "C++ Basics",
"MS-CIT", "DCA (Diploma in Computer Application) MS-office, Photoshop", "Microsoft Outlook", "Windows 7&8",
"Windows XP, Vista, Win7 MS Office", "Tally ERP9", "Tally", "Typing", "Knowledge and operation of MS Office",
"Internet Browsing", "Programming Languages (e.g., Python, R)", "Database Management", "Machine Learning",
"Data Mining and Data Warehousing", "Data Analysis", "Statistical Analysis", "Data Visualization",
"Software Development", "Web Development", "Networking and Infrastructure", "Cybersecurity",
"Cloud Computing", "IT Support and Troubleshooting", "Construction Methods and Techniques",
"Blueprint Reading and Interpretation", "Safety and Compliance", "Materials and Equipment Handling",
"Problem Solving and Decision Making", "Quality Control and Assurance", "Communication and Negotiation",
"Construction Documentation", "Curriculum Development", "Instructional Design", "Classroom Management",
"Differentiated Instruction", "Student Assessment and Evaluation", "Technology Integration",
"Renewable Energy Technologies", "Energy Management", "Sustainability Practices", "Project Development and Implementation",
"Energy Policy and Regulations", "Data Analysis and Modeling", "Performance Skills", "Stage or Set Design",
"Production Management", "Scriptwriting or Screenwriting", "Directing or Choreography", "Creative Development",
"Improvisation", "Event Planning and Promotion", "Audience Engagement", "Fashion Design", "Trend Forecasting",
"Styling", "Garment Construction", "Textile Knowledge", "Fashion Illustration", "Fashion Branding",
"Fashion Merchandising", "Fashion Retailing", "Fashion Photography", "Fashion Marketing and PR",
"Fashion Technology", "Economic Modeling", "Policy Analysis", "Quantitative Research", "Economic Forecasting",
"Financial Analysis", "Microeconomic Theory", "Macroeconomic Analysis", "Econometric Analysis",
"Policy Evaluation", "Economic Reporting and Communication", "Economic Research", "Culinary Skills",
"Food Safety and Hygiene", "Menu Development", "Beverage Knowledge", "Operations Management",
"Knowledge of Dietary Restrictions", "Menu Costing and Profitability", "Patient Care", "Medical Knowledge",
"Clinical Skills", "Interdisciplinary Collaboration", "Problem-Solving and Critical Thinking",
"Empathy and Emotional Intelligence", "Time Management", "Adaptability and Flexibility", "Customer Service",
"Interpersonal Skills", "Conflict Resolution", "Multilingual Skills", "Sales and Upselling",
"Knowledge of Local Attractions", "Manufacturing Processes", "Equipment Operation", "Quality Control",
"Lean Manufacturing", "Safety Compliance", "Teamwork and Collaboration", "Mining Operations",
"Geological Knowledge", "Mine Planning and Management", "Maintenance and Repairs", "Environmental Stewardship",
"Data Analysis and Reporting", "Pharmaceutical Research", "Drug Development", "Regulatory Compliance",
"Pharmaceutical Manufacturing", "Analytical Skills", "Data Interpretation", "Documentation and Reporting",
"Project Management", "Network Operations", "Telecommunication Technologies", "System Maintenance",
"Troubleshooting", "Data and Voice Communication", "Network Security", "Customer Support", "Vendor Management",
"Transportation Operations", "Logistics", "Vehicle Operation", "Route Optimization", "Technology Proficiency","Microsoft Office",
"Knowledge of Banking Software","Proficiency in Data Management","CRM", "RAP", "Admin", "Flex-cube", "Fin-ware"," Internet","telly",
"MS Access","Foxpro","GST Training","Six Sigma Training","Completed 250 Hours of Computer Training Under ICWAI ITT Training Center;"
"Functional lessoning with IT Department;","Corporate Strategy", "Growth strategies"," Internal control","Business Reviews",
"Operational","business & Process excellence","Risk analysis","Annual Strategic Business/Operational & Financial planning and analysis",
"Revenue Planning Execution, analysis","assurance & enhancement","Industry & Competition analysis","Scenario Planning and analysis","SOP",
"DOA","Improvement in Policy","Process, System","organizational restructuring & audit Compliance","Demand & Supply planning","Business & Consumer analysis",
"Analytics & Insights","Financial resource/budget allocation","New business initiative","MIS & Dashboards","Internal Vigilance","Highlight area of concern and business risk",
"Post- merger integration","Flexcube","Windows,", "Nudi4.0","Big Data Analytics","Financial Risk Management","Financial Business Analytics","CNC Programmin","Internal Auditing",
"FX Online","I Neo+","Branch Banking Operations","Building and Maintaining relations with clients","Excellent Product Knowledge.","NETS", "Talisma","CTS 2010","CASA","TASc","NRI",
"Capacity of leading the team","Reporting Skills", "Administrative Writing Skills", "Communication skills - written and verbal","Planning and organizing", "Problem assessment and problem solving",
"Information gathering and information monitoring", "Attention to detail and accuracy","Inventory Control", "Managing Processes", "Customer service orientation", "Teamwork","Microsoft Office Skills",
"Installing configuring administrating software applications","Installation Experience of General Software Packages / Operating Systems"]


def extract_skills_from_resume(file_path, skills_list):
    matched_skills = []

    # Extract text from different file formats
    file_extension = os.path.splitext(file_path)[1].lower()

    if file_extension == '.docx':
        doc = docx.Document(file_path)
        resume_text = ' '.join([p.text for p in doc.paragraphs])

    elif file_extension == '.pdf':
        resume_text = textract.process(file_path, method='pdfminer').decode('utf-8')

    elif file_extension == '.txt':
        with open(file_path, 'r', encoding='utf-8') as f:
            resume_text = f.read()

    else:
        return matched_skills

    for skill in skills_list:
        if re.search(r'\b' + re.escape(skill) + r'\b', resume_text, re.IGNORECASE):
            matched_skills.append(skill)

    return matched_skills


def extract_skills_from_folder(folder_path, soft_skills_list, technical_skills_list):
    matched_skills = []

    # Iterate through files in the folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Extract skills from each resume
        if os.path.isfile(file_path):
            soft_skills = extract_skills_from_resume(file_path, soft_skills_list)
            technical_skills = extract_skills_from_resume(file_path, technical_skills_list)
            if soft_skills or technical_skills:
                matched_skills.append((file_name, soft_skills, technical_skills))

    return matched_skills


# Example usage
folder_path = 'C:\\Users\\Shivam\\Desktop\\python\\300 work assist'
matched_skills = extract_skills_from_folder(folder_path, soft_skills, technical_skills)

for file_name, soft_skills, technical_skills in matched_skills:
    print(f"File: {file_name}")
    print("Soft Skills:", soft_skills)
    print("Technical Skills:", technical_skills)
    print()
# Out:
# File: 0_Babasreeta Mishra Resume.docx
# Soft Skills: ['Analytical Skills', 'Good Communication', 'Strong network', 'Team handling', 'Sales', 'Current-Account Knowledge', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Typing', 'Analytical Skills', 'Microsoft Office']
#
# File: 1203193765.docx
# Soft Skills: ['Analytical Skills', 'Sales', 'Customer Service', 'Positive Attitude', '']
# Technical Skills: ['Customer Service', 'Analytical Skills', 'Operational']
#
# File: 1453074482.docx
# Soft Skills: ['Team handling', 'Sales', '']
# Technical Skills: ['Excel', 'Word', 'Typing', 'Financial Analysis']
#
# File: A JOSEPHIN STELLA-BM_Work Assist.docx
# Soft Skills: ['Team handling', 'Sales', 'Customer Service', 'Relationship Management', 'Relationship building', 'Hard work', 'Relationship Building', '']
# Technical Skills: ['Word', 'Customer Service', 'Admin']
#
# File: Abhijeet rexwal - Customer sales officer - 4 Yrs 0 Month.docx
# Soft Skills: ['Good Communication', 'Sales', 'Hard Working', 'Positive Thinking', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office', 'C++ Basics']
#
# File: Aditi chauhan - Key account manager - 8 Yrs 0 Month.docx
# Soft Skills: ['Office Management', '']
# Technical Skills: ['Excel', 'Tally', ' Internet']
#
# File: Aditi chauhan - Key account manager - 8 Yrs 0 Month_1.docx
# Soft Skills: ['Office Management', '']
# Technical Skills: ['Excel', 'Tally', ' Internet']
#
# File: Ak khan - Fashion consultant - 6 Yrs 0 Month.docx
# Soft Skills: ['Business Development', '']
# Technical Skills: []
#
# File: AkshayGurav - workassist.docx
# Soft Skills: ['Compliance ', '']
# Technical Skills: ['Power Point', 'Excel', 'Word']
#
# File: Aman bharadwaj  - Deputy manager - 2 Yrs 0 Month.docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: []
#
# File: Anand mishra - Select relationship manager - 7 Yrs 0 Month.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Excel']
#
# File: Anand mishra - Select relationship manager - 7 Yrs 0 Month_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Excel']
#
# File: AnimeshMishra - workassist.docx
# Soft Skills: ['Sales', 'Team Management', 'Project Management', '']
# Technical Skills: ['SQL', 'Project Management']
#
# File: AnimeshMishra - workassist_1.docx
# Soft Skills: ['Sales', 'Team Management', 'Project Management', '']
# Technical Skills: ['SQL', 'Project Management']
#
# File: Anshu thakur - Relationship manager - 2 Yrs 0 Month.docx
# Soft Skills: ['Good Communication', 'Positive Attitude', '']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'MS-CIT']
#
# File: Aparna venkatesan - Assistant manager - 1 Yr 0 Month.docx
# Soft Skills: ['Hard Working', '']
# Technical Skills: ['Excel', 'Word', 'Tally', 'Microsoft Office', 'CRM']
#
# File: Arun kumar akkurada - Agency development manager - 11 Yrs 0 Month.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: ArunaKumari__Visakhapatnam_4.03_yrs.docx
# Soft Skills: ['Customer Service', '']
# Technical Skills: ['Time Management', 'Customer Service']
#
# File: Arunkumar  - Area sales manager - 8 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Positive Attitude', '']
# Technical Skills: ['MS Office']
#
# File: Ashok baba - Sales officer - 4 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Positive Attitude', 'Comprehensive Problem Solving', 'Efficient Time Management', 'Hard Working', '']
# Technical Skills: ['Time Management']
#
# File: Asit paul - Privilege banker - 8 Yrs 5 Months.docx
# Soft Skills: ['Sales', 'Customer Service', 'Relationship Management', '']
# Technical Skills: ['Customer Service']
#
# File: Aspathwar naresh - Relationship manager - 6 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Quick Learner', 'Conversational Skills', 'Self-Motivated', 'Burning Desire to Succeed', 'Calm under Pressure', '']
# Technical Skills: ['MS Office']
#
# File: AVIJIT GHOSH RESUME.docx
# Soft Skills: ['']
# Technical Skills: [' Internet']
#
# File: AVIJIT GHOSH RESUME_1.docx
# Soft Skills: ['']
# Technical Skills: [' Internet']
#
# File: Ayesha_Naik_resume_2023.docx
# Soft Skills: ['Customer Service', 'Positive Attitude', '']
# Technical Skills: ['Time Management', 'Customer Service']
#
# File: Ayesha_Naik_resume_2023_1.docx
# Soft Skills: ['Customer Service', 'Positive Attitude', '']
# Technical Skills: ['Time Management', 'Customer Service']
#
# File: B raza hussain hussain - Relationship manager banca channel - 7 Yrs 6 Months.docx
# Soft Skills: ['Business Development', 'Sales', 'Continuous Learning', '']
# Technical Skills: []
#
# File: Bhakti h parmar - Relationship manager - 1 Yr 0 Month.docx
# Soft Skills: ['Basic Computer', '']
# Technical Skills: ['Typing']
#
# File: Bhaven thakrar - Senior manager - 10 Yrs 0 Month.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Bhaven thakrar - Senior manager - 10 Yrs 0 Month_1.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Bipul laskar - Deputy manager - 6 Yrs 0 Month.docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship Management', 'Brand Management', 'Client Relationship Management', '']
# Technical Skills: ['Excel', 'Word', 'Operations Management']
#
# File: Bipul laskar - Deputy manager - 6 Yrs 0 Month_1.docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship Management', 'Brand Management', 'Client Relationship Management', '']
# Technical Skills: ['Excel', 'Word', 'Operations Management']
#
# File: Biswaranjan kar  - Branch manager - 10 Yrs 0 Month (1).docx
# Soft Skills: ['Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Basic Computer', 'Compliance ', '']
# Technical Skills: ['Customer Service', 'NRI']
#
# File: Boddhuru satish kumar - Deputy manager - 0 Yr 8 Months.docx
# Soft Skills: ['Positive Attitude', '']
# Technical Skills: []
#
# File: CA Rajhath Kapoor.docx
# Soft Skills: ['Team Management', '']
# Technical Skills: ['Excel', 'MS Office', 'Tally']
#
# File: CA Rajhath Kapoor_1.docx
# Soft Skills: ['Team Management', '']
# Technical Skills: ['Excel', 'MS Office', 'Tally']
#
# File: Chandrakant sahebrao kanade - Deputy manager - 8 Yrs 0 Month.docx
# Soft Skills: ['']
# Technical Skills: ['MS-CIT', 'Microsoft Office', 'CASA']
#
# File: Cheziyan  - Relationship manager - 3 Yrs 4 Months.docx
# Soft Skills: ['']
# Technical Skills: ['Power Point', 'MS Office', ' Internet']
#
# File: Darshan damania - Sr manager - 9 Yrs 0 Month.docx
# Soft Skills: ['Relationship building', 'Relationship Building', 'Compliance ', '']
# Technical Skills: ['MS Office', 'Tally', ' Internet', ' Internal control', 'Operational']
#
# File: Darshan damania - Sr manager - 9 Yrs 0 Month_1.docx
# Soft Skills: ['Relationship building', 'Relationship Building', 'Compliance ', '']
# Technical Skills: ['MS Office', 'Tally', ' Internet', ' Internal control', 'Operational']
#
# File: DEEPAKKUMARPATNAIK__Visakhapatnam_6.06_yrs.docx
# Soft Skills: ['Sales', 'Hard Working', 'Patience', 'Positive Thinking', 'Project Management', '']
# Technical Skills: ['Interpersonal Skills', 'Project Management']
#
# File: Dilip Singh CV....docx
# Soft Skills: ['Compliance ', '']
# Technical Skills: ['Excel', 'Word', 'Risk analysis']
#
# File: Dilip Singh CV..._1.docx
# Soft Skills: ['Compliance ', '']
# Technical Skills: ['Excel', 'Word', 'Risk analysis']
#
# File: DIVYA JINDAL - workassist.docx
# Soft Skills: ['Hard Working', 'Teamwork', 'Office Management', 'Multitasking', 'Digital Marketing', '']
# Technical Skills: ['Excel', 'Word', 'Tally', 'Teamwork']
#
# File: DIVYA JINDAL - workassist_1.docx
# Soft Skills: ['Hard Working', 'Teamwork', 'Office Management', 'Multitasking', 'Digital Marketing', '']
# Technical Skills: ['Excel', 'Word', 'Tally', 'Teamwork']
#
# File: DOC-20230116-WA0002..docx
# Soft Skills: ['']
# Technical Skills: ['Interpersonal Skills']
#
# File: DOC-20230421-WA0037. (1) (1) (1).docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: DOC-20230421-WA0037. (1) (1) (1)_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: DOC-20230421-WA0037. (1) (1).docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: DOC-20230421-WA0037. (1) (1)_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: DOC-20230421-WA0037. (1).docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: Farvin m - Relationship manager - 2 Yrs 9 Months.docx
# Soft Skills: ['Team handling', 'Business Development', 'Sales', '']
# Technical Skills: ['Excel', 'NRI']
#
# File: Girish tripathi - Relationships officer - 10 Yrs 0 Month (1).docx
# Soft Skills: ['Sales', 'Customer Service', 'Relationship Management', 'Continuous Learning', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Customer Service', 'CASA']
#
# File: Girish tripathi - Relationships officer - 10 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Customer Service', 'Relationship Management', 'Continuous Learning', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Customer Service', 'CASA']
#
# File: GolajanaRavi__Visakhapatnam_1.06_yrs.docx
# Soft Skills: ['Good Communication', 'Positive Attitude', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office', 'Time Management']
#
# File: Hamid ahmad zargar - Senior relationship manager - 6 Yrs 0 Month.docx
# Soft Skills: ['Passionate to learn', 'Excellent motivation', 'Convincing power', 'Dedication and determination', '']
# Technical Skills: []
#
# File: Hema - workassist.docx
# Soft Skills: ['Sales', 'Customer Service', 'Relationship building', 'Expert knowledge of the selling process', 'Relationship Building', '']
# Technical Skills: ['Customer Service']
#
# File: Hemant sharma  - Sales officer field - 4 Yrs 0 Month.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: iimjobs_Alok_Goel.docx
# Soft Skills: ['Analytical Skills', 'Business Development', 'Sales', 'Relationship Management', '']
# Technical Skills: ['Analytical Skills', ' Internet', 'Risk analysis', 'CASA']
#
# File: iimjobs_Alok_Goel_1.docx
# Soft Skills: ['Analytical Skills', 'Business Development', 'Sales', 'Relationship Management', '']
# Technical Skills: ['Analytical Skills', ' Internet', 'Risk analysis', 'CASA']
#
# File: iimjobs_Ankit_pandey.docx
# Soft Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Relationship building', 'Relationship Building', '']
# Technical Skills: ['Customer Service']
#
# File: iimjobs_Ankit_pandey_1.docx
# Soft Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Relationship building', 'Relationship Building', '']
# Technical Skills: ['Customer Service']
#
# File: iimjobs_Anshuman_Sarkar.docx
# Soft Skills: ['Business Development', 'Sales', 'Compliance ', '']
# Technical Skills: ['CASA', 'TASc']
#
# File: iimjobs_Arun_Kumar_N_V.docx
# Soft Skills: ['Business Development', 'Sales', 'Team Management', 'Relationship Management', 'Teamwork', 'Project Management', 'Strategic Planning', 'Digital Marketing', 'Compliance ', '']
# Technical Skills: ['Interpersonal Skills', 'Project Management', 'Logistics', ' Internet', 'Operational', 'CASA', 'Teamwork']
#
# File: iimjobs_Divyanshu_vijay.docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship Management', 'Digital Marketing', '']
# Technical Skills: ['Excel', 'Word', 'Tally', 'telly']
#
# File: iimjobs_Ganapathyramarajan.docx
# Soft Skills: ['Team handling', 'Business Development', 'Sales', 'Team Management', 'Relationship Management', '']
# Technical Skills: ['Admin', 'Operational', 'Windows,']
#
# File: iimjobs_Kunal_Phate (1).docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: iimjobs_Kunal_Phate (1)_1.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: iimjobs_Kundan_Chauhan (1).docx
# Soft Skills: ['Compliance ', '']
# Technical Skills: ['Database Management', 'Software Development']
#
# File: iimjobs_Kundan_Chauhan (1)_1.docx
# Soft Skills: ['Compliance ', '']
# Technical Skills: ['Database Management', 'Software Development']
#
# File: iimjobs_Manishkumar_Rameshchandra_Patel.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: iimjobs_Manishkumar_Rameshchandra_Patel_1.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: iimjobs_MOHUDDIN.docx
# Soft Skills: ['Sales', 'Customer Service', 'Compliance ', '']
# Technical Skills: ['Customer Service', 'CRM', 'Operational', 'Risk analysis']
#
# File: iimjobs_MOHUDDIN_1.docx
# Soft Skills: ['Sales', 'Customer Service', 'Compliance ', '']
# Technical Skills: ['Customer Service', 'CRM', 'Operational', 'Risk analysis']
#
# File: iimjobs_Prashant_Subramanian.docx
# Soft Skills: ['Business Development', 'Sales', 'Customer Service', '']
# Technical Skills: ['MS Office', 'Financial Analysis', 'Customer Service', 'CASA']
#
# File: iimjobs_Rajneesh_K_Jha.docx
# Soft Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Compliance ', '']
# Technical Skills: ['Operations Management', 'Customer Service', 'Vendor Management', 'Operational', 'Branch Banking Operations', 'NRI']
#
# File: iimjobs_Rajneesh_K_Jha_1.docx
# Soft Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Compliance ', '']
# Technical Skills: ['Operations Management', 'Customer Service', 'Vendor Management', 'Operational', 'Branch Banking Operations', 'NRI']
#
# File: iimjobs_Ramesh_Singh_Rawat.docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: ['CASA', 'NRI']
#
# File: iimjobs_Sandeep_Jagdhane.docx
# Soft Skills: ['Sales', 'Hard work', '']
# Technical Skills: []
#
# File: iimjobs_Sandeep_Jagdhane_1.docx
# Soft Skills: ['Sales', 'Hard work', '']
# Technical Skills: []
#
# File: iimjobs_shelendra_agarwal.docx
# Soft Skills: ['Team handling', 'Business Development', 'Sales', 'Hard Working', 'Compliance ', '']
# Technical Skills: ['Java', 'CASA']
#
# File: iimjobs_shelendra_agarwal_1.docx
# Soft Skills: ['Team handling', 'Business Development', 'Sales', 'Hard Working', 'Compliance ', '']
# Technical Skills: ['Java', 'CASA']
#
# File: IppiliChanti__Visakhapatnam_1_yrs.docx
# Soft Skills: ['Sales', 'Positive Attitude', '']
# Technical Skills: ['MS Office', 'Tally ERP9', 'Tally', 'Knowledge and operation of MS Office', 'Internet Browsing', ' Internet']
#
# File: Israr ali - Assistant manager - 3 Yrs 0 Month (2).docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Tally', 'Operations Management', 'CASA']
#
# File: Javedakhtar choudhary - Relationship manager - 6 Yrs 0 Month (1).docx
# Soft Skills: ['Hard work', '']
# Technical Skills: ['Excel', 'Word']
#
# File: Jayanta kumar kalita - Deputy manager - 7 Yrs 0 Month.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Tally']
#
# File: Jayanta kumar kalita - Deputy manager - 7 Yrs 0 Month_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Tally']
#
# File: Jeetendra kumar - Deputy manager - 4 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['Customer Service']
#
# File: Kalaiyarasan g - Relationship manager - 5 Yrs 0 Month.docx
# Soft Skills: ['Quick Learner', '']
# Technical Skills: ['HTML']
#
# File: Kalpana sk - Sales executive customer - 1 Yr 0 Month.docx
# Soft Skills: ['Good Communication', 'Self-Motivated', 'Basic Computer', '']
# Technical Skills: []
#
# File: Kamol kalita - Branch sales manager - 7 Yrs 0 Month (1) (1).docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship Management', 'Client Relationship Management', '']
# Technical Skills: []
#
# File: Kamol kalita - Branch sales manager - 7 Yrs 0 Month (1) (1)_1.docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship Management', 'Client Relationship Management', '']
# Technical Skills: []
#
# File: Karthikeyan Resume.docx
# Soft Skills: ['Relationship Management', 'Good time management and organizational skills', 'Excellent command over written and verbal communication', '']
# Technical Skills: ['Power Point', 'Word', 'Time Management', ' Internet']
#
# File: Kiran c shinde - Assistant manager - 3 Yrs 6 Months.docx
# Soft Skills: ['Compliance ', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Tally', 'Time Management', 'Microsoft Office', 'Knowledge of Banking Software']
#
# File: Kiran c shinde - Assistant manager - 3 Yrs 6 Months_1.docx
# Soft Skills: ['Compliance ', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Tally', 'Time Management', 'Microsoft Office', 'Knowledge of Banking Software']
#
# File: Kiran s  - Relationship manager - 5 Yrs 0 Month.docx
# Soft Skills: ['Customer Service', 'Quick Learner', 'Patience', 'Help & patience', 'Basic Accounting', 'Office Management', '']
# Technical Skills: ['Excel', 'Word', 'Windows 7&8', 'Customer Service']
#
# File: Koushik chakraborty  - Deputy manager 1 - 5 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Basic Computer', '']
# Technical Skills: []
#
# File: KOYYASANTOSHKUMAR__Visakhapatnam_5_yrs.docx
# Soft Skills: ['Sales', 'Team Management', 'Customer Service', 'Hard Working', 'Punctuality', 'Relationship building', 'Banking Operation Skills', 'Work Management Skills', 'Relationship Building', '']
# Technical Skills: ['Typing', 'Customer Service', 'Microsoft Office']
#
# File: Kuldeep  - Deputy manager - 4 Yrs 8 Months.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Interpersonal Skills']
#
# File: Kuldeep  - Deputy manager - 4 Yrs 8 Months_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Interpersonal Skills']
#
# File: Kushal agrawal - Relationship manager - 1 Yr 1 Month.docx
# Soft Skills: ['Digital Marketing', '']
# Technical Skills: ['Excel', 'Word']
#
# File: LakshmanraoMycharla__Visakhapatnam_0.04_yrs.docx
# Soft Skills: ['Positive Attitude', 'Hardworking nature', 'Team building and leadership qualities', '']
# Technical Skills: ['MS Office', 'Tally ERP9', 'Tally']
#
# File: Latest Resume 2023 2.docx
# Soft Skills: ['']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'Tally', 'Financial Analysis']
#
# File: Latest Resume 2023 2_1.docx
# Soft Skills: ['']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'Tally', 'Financial Analysis']
#
# File: LOHITHSH__Bengaluru_Bangalore_8.09_yrs.docx
# Soft Skills: ['Punctuality', '']
# Technical Skills: ['Tally', 'Time Management']
#
# File: LOHITHSH__Bengaluru_Bangalore_8.09_yrs_1.docx
# Soft Skills: ['Punctuality', '']
# Technical Skills: ['Tally', 'Time Management']
#
# File: Mahesh ayyappa bagaler - Sales executive - 4 Yrs 0 Month (1).docx
# Soft Skills: ['Sales', 'Positive Attitude', 'Hard Working', 'Good knowledge of sales and marketing', 'Knowledge of various types of sales', '']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'Windows XP, Vista, Win7 MS Office']
#
# File: Mahesh desai - Sale - 10 Yrs 7 Months.docx
# Soft Skills: ['Sales', 'Team Management', 'Passionate to learn', '']
# Technical Skills: ['Tally', 'Troubleshooting']
#
# File: Mamta yadav - Deputy manager - 5 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Customer Service', 'Relationship Management', '']
# Technical Skills: ['MS Office', 'Operations Management', 'Customer Service', ' Internet']
#
# File: Mamta yadav - Deputy manager - 5 Yrs 0 Month_1.docx
# Soft Skills: ['Sales', 'Customer Service', 'Relationship Management', '']
# Technical Skills: ['MS Office', 'Operations Management', 'Customer Service', ' Internet']
#
# File: Mane gopal - Relationship manager - 3 Yrs 0 Month.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: ManishaPrasad - workassist.docx
# Soft Skills: ['Team handling', 'Sales', 'Team Management', 'Customer Service', 'Quick Learner', 'Good in preparing daily revenue Reports', '']
# Technical Skills: ['MS Office', 'Customer Service', 'CRM']
#
# File: Manne  - Chief manager - 11 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Compliance ', '']
# Technical Skills: ['Internet Browsing']
#
# File: Manne  - Chief manager - 11 Yrs 0 Month_1.docx
# Soft Skills: ['Sales', 'Compliance ', '']
# Technical Skills: ['Internet Browsing']
#
# File: manoj fernandez_40660466.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Troubleshooting', 'Customer Support']
#
# File: manoj fernandez_40660466_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Troubleshooting', 'Customer Support']
#
# File: Mohammed faisal baig - Sales executive officer - 0 Yr 0 Month.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office']
#
# File: MonicaKinger__Gurgaon_Gurugram_0.06_yrs.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Mouli Kanaparthi CV.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: Muhmmad ameer - Workassist.docx
# Soft Skills: ['Hard Working', 'Self-Motivated', 'Positive Thinking', '']
# Technical Skills: ['Excel', 'Word', ' Internet', 'CASA']
#
# File: muhmmadameer CV.docx
# Soft Skills: ['Hard Working', 'Self-Motivated', 'Positive Thinking', '']
# Technical Skills: ['Excel', 'Word', ' Internet', 'CASA']
#
# File: muhmmadameer CV_1.docx
# Soft Skills: ['Hard Working', 'Self-Motivated', 'Positive Thinking', '']
# Technical Skills: ['Excel', 'Word', ' Internet', 'CASA']
#
# File: MukutAli[4y_8m] (1) (1).docx
# Soft Skills: ['Good Communication', 'Sales', 'Self-Motivated', '']
# Technical Skills: []
#
# File: MukutAli[4y_8m] (1) (1)_1.docx
# Soft Skills: ['Good Communication', 'Sales', 'Self-Motivated', '']
# Technical Skills: []
#
# File: Mustak abbigeri - Sales officer - 1 Yr 0 Month (2).docx
# Soft Skills: ['']
# Technical Skills: ['CNC Programmin']
#
# File: Muthu kumar  - Relationship manager - 4 Yrs 4 Months.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: Muzammil. v - Sales officer - 3 Yrs 0 Month.docx
# Soft Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Relationship Management', '']
# Technical Skills: ['Time Management', 'Customer Service', 'CASA']
#
# File: Naukri_AbdulNabiShaikh[6y_0m] (1).docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship building', 'Relationship Building', '']
# Technical Skills: ['Power Point', 'Excel', 'Word']
#
# File: Naukri_AbdulNabiShaikh[6y_0m].docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship building', 'Relationship Building', '']
# Technical Skills: ['Power Point', 'Excel', 'Word']
#
# File: Naukri_AbhijeetSingh[6y_0m].docx
# Soft Skills: ['']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'Time Management']
#
# File: Naukri_Amitendrasinghthakur[6y_6m].docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: []
#
# File: Naukri_Amitendrasinghthakur[6y_6m]_1.docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: []
#
# File: Naukri_AmrutGupta[4y_6m].docx
# Soft Skills: ['Business Development', 'Sales', 'Team Management', 'Relationship building', 'Relationship Building', '']
# Technical Skills: ['MS Office', 'Interpersonal Skills', 'CASA']
#
# File: Naukri_ARDHENDUSAHA[3y_6m].docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Power Point', ' Internet', 'CASA']
#
# File: Naukri_AshishPandey[7y_4m].docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship building', 'Relationship Building', '']
# Technical Skills: []
#
# File: Naukri_awnishsingh[7y_0m].docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['CASA']
#
# File: Naukri_BEDPRAKASHGUPTA[10y_0m].docx
# Soft Skills: ['Sales', 'Customer Service', 'Relationship Management', 'Client Relationship Management', '']
# Technical Skills: ['Java', 'HTML', 'SQL', 'Excel', 'MS Office', 'Customer Service', 'CASA', 'TASc']
#
# File: Naukri_BikashKumarNath[12y_0m].docx
# Soft Skills: ['']
# Technical Skills: ['CRM', 'FX Online']
#
# File: Naukri_ChiragAshokBhatt[15y_0m].docx
# Soft Skills: ['Sales', 'Customer Service', 'Relationship Management', '']
# Technical Skills: ['Customer Service', 'CASA', 'NRI']
#
# File: Naukri_DeepakAggarwal[12y_0m].docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship Management', 'Project Management', 'Strategic Planning', 'Client Relationship Management', '']
# Technical Skills: ['Python', 'SQL', 'Excel', 'Word', 'MS Office', 'Data Analysis', 'Operations Management', 'Time Management', 'Interpersonal Skills', 'Data Interpretation', 'Project Management', 'Troubleshooting', 'Operational', 'Risk analysis']
#
# File: Naukri_deepakbaraily[6y_0m].docx
# Soft Skills: ['Business Development', 'Sales', 'Hard Working', 'Positive Thinking', 'Relationship building', 'Relationship Building', '']
# Technical Skills: ['Tally ERP9', 'Tally', 'Typing']
#
# File: Naukri_deepakbaraily[6y_0m]_1.docx
# Soft Skills: ['Business Development', 'Sales', 'Hard Working', 'Positive Thinking', 'Relationship building', 'Relationship Building', '']
# Technical Skills: ['Tally ERP9', 'Tally', 'Typing']
#
# File: Naukri_DeepikaKota[4y_0m].docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: Naukri_GovindMohanThakur[14y_0m].docx
# Soft Skills: ['Team handling', '']
# Technical Skills: ['Python', 'SQL', 'Excel', 'Operational', 'Flexcube']
#
# File: Naukri_GovindMohanThakur[14y_0m]_1.docx
# Soft Skills: ['Team handling', '']
# Technical Skills: ['Python', 'SQL', 'Excel', 'Operational', 'Flexcube']
#
# File: Naukri_HemalathaVelusamy[7y_0m].docx
# Soft Skills: ['Sales', 'Team Management', 'Customer Service', 'Relationship Management', '']
# Technical Skills: ['Customer Service', 'Operational', 'NRI']
#
# File: Naukri_HimanshuPratapSingh[4y_0m].docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship Management', '']
# Technical Skills: []
#
# File: Naukri_HimanshuPratapSingh[4y_0m]_1.docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship Management', '']
# Technical Skills: []
#
# File: Naukri_HirenkumarNai[6y_6m].docx
# Soft Skills: ['Sales', 'Customer Service', 'Positive Attitude', 'Self-Motivated', '']
# Technical Skills: ['Customer Service', 'CASA']
#
# File: Naukri_kalyani[8y_0m].docx
# Soft Skills: ['Sales', 'Customer Service', 'Positive Attitude', 'Quick Learner', 'Basic Computer', 'Compliance ', '']
# Technical Skills: ['Customer Service', 'Operational']
#
# File: Naukri_KanikaBansal[2y_3m].docx
# Soft Skills: ['Analytical Skills', 'Customer Service', 'Compliance ', '']
# Technical Skills: ['Customer Service', 'Analytical Skills']
#
# File: Naukri_KanikaBansal[2y_3m]_1.docx
# Soft Skills: ['Analytical Skills', 'Customer Service', 'Compliance ', '']
# Technical Skills: ['Customer Service', 'Analytical Skills']
#
# File: Naukri_KaustubhManjrekar[10y_0m].docx
# Soft Skills: ['Manage time & resources effectively', 'Adaptable with positive & learning attitude', '']
# Technical Skills: ['MS-CIT', 'Microsoft Office']
#
# File: Naukri_MaheshBaluKolhe[6y_6m].docx
# Soft Skills: ['Sales', 'Positive Attitude', 'Teamwork', 'Hard work', 'Multitasking', '']
# Technical Skills: ['Teamwork']
#
# File: Naukri_MAKANIRAJANKUMAR[4y_2m].docx
# Soft Skills: ['Good Communication', 'Fast Learner', '']
# Technical Skills: ['MS Office', 'Typing', 'Interpersonal Skills', 'Quality Control', 'CASA']
#
# File: Naukri_MFarhanChaudhari[11y_0m].docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['SQL', 'Customer Service']
#
# File: Naukri_MFarhanChaudhari[11y_0m]_1.docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['SQL', 'Customer Service']
#
# File: Naukri_NanaDurganathBhandari[4y_0m].docx
# Soft Skills: ['Business Development', 'Sales', 'Customer Service', 'Relationship Management', 'Client Relationship Management', 'Compliance ', '']
# Technical Skills: ['MS-CIT', 'Tally', 'Typing', 'Customer Service', 'CASA']
#
# File: Naukri_PankajChhatrodiya[6y_6m].docx
# Soft Skills: ['Business Development', 'Sales', 'Customer Service', 'Basic Computer', '']
# Technical Skills: ['Customer Service']
#
# File: Naukri_Parvezuddin[11y_0m].docx
# Soft Skills: ['Good Communication', 'Sales', 'Hard work', '']
# Technical Skills: ['Tally']
#
# File: Naukri_PrashantYogi[4y_0m].docx
# Soft Skills: ['Team handling', 'Sales', '']
# Technical Skills: ['MS Office', ' Internet']
#
# File: Naukri_PrashantYogi[4y_0m]_1.docx
# Soft Skills: ['Team handling', 'Sales', '']
# Technical Skills: ['MS Office', ' Internet']
#
# File: Naukri_PratikRajendraShelke[9y_9m].docx
# Soft Skills: ['']
# Technical Skills: ['Excel', 'Microsoft Office', 'NRI']
#
# File: Naukri_PreetikaDamani[12y_0m].docx
# Soft Skills: ['Team Management', 'Relationship Management', 'Goal-Oriented', 'Compliance ', '']
# Technical Skills: []
#
# File: Naukri_princenaveen[4y_6m].docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Naukri_Rahuljha[4y_7m].docx
# Soft Skills: ['Hard work', 'Believe in ethics & morals', '']
# Technical Skills: []
#
# File: Naukri_Rahuljha[4y_7m]_1.docx
# Soft Skills: ['Hard work', 'Believe in ethics & morals', '']
# Technical Skills: []
#
# File: Naukri_RAJESHCHILUMALA[7y_0m].docx
# Soft Skills: ['Good Communication', 'Relationship Management', 'Positive Attitude', 'Hard work', 'Strategic Planning', '']
# Technical Skills: ['MS Office', ' Internet']
#
# File: Naukri_RAJESHCHILUMALA[7y_0m]_1.docx
# Soft Skills: ['Good Communication', 'Relationship Management', 'Positive Attitude', 'Hard work', 'Strategic Planning', '']
# Technical Skills: ['MS Office', ' Internet']
#
# File: Naukri_RITUPARNABISWAS[3y_0m].docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: Naukri_RITUPARNABISWAS[3y_0m]_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: Naukri_RuckmaniMeena[6y_6m].docx
# Soft Skills: ['Analytical Skills', 'Sales', 'Customer Service', 'Relationship Management', 'Positive Attitude', 'Hard Working', '']
# Technical Skills: ['Customer Service', 'Analytical Skills', 'Operational', 'CASA']
#
# File: Naukri_RuckmaniMeena[6y_6m]_1.docx
# Soft Skills: ['Analytical Skills', 'Sales', 'Customer Service', 'Relationship Management', 'Positive Attitude', 'Hard Working', '']
# Technical Skills: ['Customer Service', 'Analytical Skills', 'Operational', 'CASA']
#
# File: Naukri_SagarGSawant[16y_0m].docx
# Soft Skills: ['Relationship Management', 'Self-Motivated', 'Compliance ', '']
# Technical Skills: ['SQL', 'MS Office', 'Tally', 'Operational', 'NRI']
#
# File: Naukri_saikumarsinghb[10y_0m].docx
# Soft Skills: ['Sales', 'Customer Service', 'Quick Learner', 'Compliance ', '']
# Technical Skills: ['Excel', 'Word', 'Time Management', 'Customer Service', 'Microsoft Office', ' Internet', 'CASA']
#
# File: Naukri_SaurabhAbhishek[7y_6m].docx
# Soft Skills: ['Team handling', '']
# Technical Skills: []
#
# File: Naukri_SaurabhAbhishek[7y_6m]_1.docx
# Soft Skills: ['Team handling', '']
# Technical Skills: []
#
# File: Naukri_SHIKRITIADAK[6y_6m].docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: ['Excel', 'Word', 'CASA']
#
# File: Naukri_ShubhangSunkara[0y_1m].docx
# Soft Skills: ['']
# Technical Skills: ['Word']
#
# File: Naukri_ShubhangSunkara[0y_1m]_1.docx
# Soft Skills: ['']
# Technical Skills: ['Word']
#
# File: Naukri_SiddharthRJain[11y_4m].docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office', 'Operational']
#
# File: Naukri_SINGHPREETIRAJANISHA[6y_0m].docx
# Soft Skills: ['Good Communication', 'Business Development', 'Sales', 'Customer Service', 'Quick Learner', 'Basic Computer', 'Fast Learner', 'Accept Challenges', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office', 'Customer Service', 'CRM', 'CASA']
#
# File: Naukri_SnigdhaKumari[4y_6m].docx
# Soft Skills: ['']
# Technical Skills: ['Microsoft Office', 'CASA']
#
# File: Naukri_Subbulakshmis[17y_0m].docx
# Soft Skills: ['Sales', 'Team Management', 'Relationship Management', 'Hard Working', 'Client Relationship Management', '']
# Technical Skills: []
#
# File: Naukri_SurajBhalerao[11y_0m].docx
# Soft Skills: ['Analytical Skills', 'Business Development', 'Relationship Management', 'Relationship building', 'Relationship Building', 'Compliance ', '']
# Technical Skills: ['Financial Analysis', 'Analytical Skills']
#
# File: Naukri_SurajBhalerao[11y_0m]_1.docx
# Soft Skills: ['Analytical Skills', 'Business Development', 'Relationship Management', 'Relationship building', 'Relationship Building', 'Compliance ', '']
# Technical Skills: ['Financial Analysis', 'Analytical Skills']
#
# File: Naukri_SUVANKARDEB[6y_6m].docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Excel', 'Word', 'Tally']
#
# File: Naukri_vipulsprajapati[12y_0m].docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Customer Support', 'SOP', 'CASA']
#
# File: Naukri_YOGESWARISK[16y_0m].docx
# Soft Skills: ['Sales', 'Customer Service', 'Positive Attitude', 'Compliance ', '']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'Customer Service', 'CRM', 'NRI']
#
# File: Naukri_YuvanaSabharish[12y_0m].docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['Time Management', 'Customer Service']
#
# File: Navin chandra - Senior business development manager - 7 Yrs 3 Months (1).docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: ['CRM']
#
# File: Navin chandra - Senior business development manager - 7 Yrs 3 Months (1)_1.docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: ['CRM']
#
# File: Navin chandra - Senior business development manager - 7 Yrs 3 Months.docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: ['CRM']
#
# File: Navin chandra - Senior business development manager - 7 Yrs 3 Months_1.docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: ['CRM']
#
# File: Neelmani arora  - Deputy manager - 7 Yrs 4 Months.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office', 'Vendor Management', 'CRM']
#
# File: Neetu  - Sales officer - 3 Yrs 0 Month (1).docx
# Soft Skills: ['Hard work', '']
# Technical Skills: []
#
# File: Nehamishra_Work assist (1).docx
# Soft Skills: ['']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Typing', 'Microsoft Office']
#
# File: Nehamishra_Work assist.docx
# Soft Skills: ['']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Typing', 'Microsoft Office']
#
# File: NIKHIL ZOPE RESUME - workassist (1).docx
# Soft Skills: ['Sales', 'Customer Service', 'Self-Motivated', '']
# Technical Skills: ['Customer Service']
#
# File: Nikshitha  - Relationship manager - 4 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Positive Attitude', '']
# Technical Skills: ['Reporting Skills']
#
# File: Nishant Patel_Work Assist.docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['Customer Service', 'CASA']
#
# File: Nishi kanta barui - Customer relationship officer - 1 Yr 10 Months.docx
# Soft Skills: ['']
# Technical Skills: ['Tally']
#
# File: Nithyananda nithyananda - Business development manager - 5 Yrs 0 Month.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'Interpersonal Skills']
#
# File: Pankaj sharma - Senior preferred relationship manager - 6 Yrs 0 Month (1).docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: [' Internet']
#
# File: Parinaz tavadia - Branch operation manager - 15 Yrs 0 Month.docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: ['CASA', 'TASc']
#
# File: Piyush sinha - Client service - 10 Yrs 0 Month.docx
# Soft Skills: ['Team handling', 'Sales', 'Customer Service', '']
# Technical Skills: ['Customer Service', 'CASA']
#
# File: Piyush vaid - Preferred relationship manager - 2 Yrs 0 Month (1).docx
# Soft Skills: ['Adaptability to Change', 'Strategic Thinking', '']
# Technical Skills: []
#
# File: Piyush vaid - Preferred relationship manager - 2 Yrs 0 Month (1)_1.docx
# Soft Skills: ['Adaptability to Change', 'Strategic Thinking', '']
# Technical Skills: []
#
# File: Piyush vaid - Preferred relationship manager - 2 Yrs 0 Month.docx
# Soft Skills: ['Adaptability to Change', 'Strategic Thinking', '']
# Technical Skills: []
#
# File: Piyush vaid - Preferred relationship manager - 2 Yrs 0 Month_1.docx
# Soft Skills: ['Adaptability to Change', 'Strategic Thinking', '']
# Technical Skills: []
#
# File: Prasenjit sardar - Finance - 3 Yrs 0 Month.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office']
#
# File: PreetiSarkar__Mumbai_2.01_yrs.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: PreetiSarkar__Mumbai_2.01_yrs_1.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Premkumar - workassist.docx
# Soft Skills: ['Customer Service', 'Compliance ', '']
# Technical Skills: ['Customer Service']
#
# File: PritamDas__Visakhapatnam_5.11_yrs.docx
# Soft Skills: ['Good Communication', 'Business Development', 'Positive Attitude', 'Compliance ', '']
# Technical Skills: ['Microsoft Office', 'CRM']
#
# File: Rachabantishivakrishna  - Sales executive - 4 Yrs 5 Months.docx
# Soft Skills: ['']
# Technical Skills: ['Excel', 'Word', 'Internet Browsing', 'Time Management']
#
# File: Rajesh_Workassist (1)_.docx
# Soft Skills: ['Team handling', 'Sales', 'Customer Service', 'Relationship Management', 'Client Relationship Management', 'Compliance ', '']
# Technical Skills: ['MS Office', 'Customer Service', ' Internet', 'Customer service orientation']
#
# File: Rakhi mahato - Deputy manager - 1 Yr 0 Month.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Excel', 'MS Office', 'Tally']
#
# File: Ramakrishnan  - Relationship officer - 3 Yrs 10 Months.docx
# Soft Skills: ['Sales', '']
# Technical Skills: [' Internet', 'CASA']
#
# File: Ramakrishnan  - Relationship officer - 3 Yrs 10 Months_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: [' Internet', 'CASA']
#
# File: Raman mishra - Casa sales officer - 5 Yrs 1 Month.docx
# Soft Skills: ['']
# Technical Skills: ['CASA']
#
# File: RAMU M_Work Assist.docx
# Soft Skills: ['Sales', 'Compliance ', '']
# Technical Skills: []
#
# File: Ramya  - Business development manager - 4 Yrs 0 Month.docx
# Soft Skills: ['Business Development', 'Self-Motivated', 'Punctuality', 'Hard work', '']
# Technical Skills: ['CASA']
#
# File: RASHMI SHARMA CV.docx
# Soft Skills: ['Business Development', '']
# Technical Skills: []
#
# File: Ravi  - Deputy manager - 5 Yrs 0 Month (1).docx
# Soft Skills: ['Analytical Skills', 'Sales', '']
# Technical Skills: ['Analytical Skills', 'CASA']
#
# File: Ravi gupta - Relationship officer - 6 Yrs 4 Months.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Ravi gupta - Relationship officer - 6 Yrs 4 Months_1.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Ravi kumar - Manager - 6 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Customer Service', 'Project Management', 'Compliance ', '']
# Technical Skills: ['HTML', 'Power Point', 'Excel', 'MS Office', 'Tally', 'Customer Service', 'Project Management', 'CRM', 'Operational', 'NETS', 'Talisma']
#
# File: Ravi roshan - workassist.docx
# Soft Skills: ['Sales', 'Project Management', '']
# Technical Skills: ['Project Management', ' Internet']
#
# File: Ravi roshan - workassist_1.docx
# Soft Skills: ['Sales', 'Project Management', '']
# Technical Skills: ['Project Management', ' Internet']
#
# File: Ravilla-Jagadeesh-updated-Resume.docx
# Soft Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Relationship building', 'Relationship Building', 'Compliance ', '']
# Technical Skills: ['MS Office', 'Customer Service', 'Interpersonal Skills', 'Vendor Management', 'CRM', 'Operational', 'Flexcube']
#
# File: Resume (3) (1).docx
# Soft Skills: ['Sales', 'Customer Service', 'Hard Working', 'Positive Thinking', 'Basic Computer', 'Straight Forward', '']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'Time Management', 'Customer Service', ' Internet']
#
# File: Resume (4).docx
# Soft Skills: ['Team handling', 'Positive Attitude', 'Hard Working', '']
# Technical Skills: ['Admin']
#
# File: Resume (5).docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Microsoft Office', 'Admin']
#
# File: Resume (5)_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Microsoft Office', 'Admin']
#
# File: resume_d_dias.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: resume_d_dias_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: Reume Swarup Banerjee .docx
# Soft Skills: ['Team handling', 'Business Development', 'Sales', 'Team Management', 'Project Management', '']
# Technical Skills: ['Project Management', 'CRM']
#
# File: Ritik nigam - Senior deputy manager - 4 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Team Management', 'Conflict Resolution', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office', 'Conflict Resolution', ' Internet']
#
# File: rubiyaparveen[10y_0m].docx
# Soft Skills: ['Positive Attitude', 'Hard work', '']
# Technical Skills: ['Vendor Management']
#
# File: rubiyaparveen[10y_0m]_1.docx
# Soft Skills: ['Positive Attitude', 'Hard work', '']
# Technical Skills: ['Vendor Management']
#
# File: Sagar dhanna - Relationship manager - 6 Yrs 0 Month.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Sai bharadwaj anantaraju - Manager - 8 Yrs 0 Month (1).docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['Customer Service', ' Internet', 'Branch Banking Operations', 'CASA']
#
# File: Sai bharadwaj anantaraju - Manager - 8 Yrs 0 Month (1)_1.docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['Customer Service', ' Internet', 'Branch Banking Operations', 'CASA']
#
# File: Sai bharadwaj anantaraju - Manager - 8 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['Customer Service', ' Internet', 'Branch Banking Operations', 'CASA']
#
# File: Sai bharadwaj anantaraju - Manager - 8 Yrs 0 Month_1.docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['Customer Service', ' Internet', 'Branch Banking Operations', 'CASA']
#
# File: Sanchita  - Relationship manager - 6 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Hard Working', 'Quick Learner', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office']
#
# File: Santosh kumar - Deputy manager - 7 Yrs 0 Month.docx
# Soft Skills: ['']
# Technical Skills: ['CTS 2010', 'CASA', 'TASc', 'NRI']
#
# File: Santosh kumar - Deputy manager - 7 Yrs 0 Month_1.docx
# Soft Skills: ['']
# Technical Skills: ['CTS 2010', 'CASA', 'TASc', 'NRI']
#
# File: Santosh singh - Am - 6 Yrs 0 Month.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: Santosh singh - Business development executive - 6 Yrs 6 Months.docx
# Soft Skills: ['Good Communication', '']
# Technical Skills: ['Microsoft Office', 'CASA']
#
# File: Saranya dasi - Assistant manager - 4 Yrs 6 Months.docx
# Soft Skills: ['Good Communication', 'Sales', 'Quick Learner', 'Compliance ', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Typing', 'Interpersonal Skills', 'Microsoft Office', 'Operational', 'CASA']
#
# File: Saranya dasi - Assistant manager - 4 Yrs 6 Months_1.docx
# Soft Skills: ['Good Communication', 'Sales', 'Quick Learner', 'Compliance ', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Typing', 'Interpersonal Skills', 'Microsoft Office', 'Operational', 'CASA']
#
# File: Satish kumar - Retail sales executive - 5 Yrs 6 Months (1).docx
# Soft Skills: ['Sales', 'Customer Service', 'Fast Learner', '']
# Technical Skills: ['MS Office', 'Typing', 'Customer Service', ' Internet', 'Operational', 'Customer service orientation']
#
# File: Satish kumar - Retail sales executive - 5 Yrs 6 Months.docx
# Soft Skills: ['Sales', 'Customer Service', 'Fast Learner', '']
# Technical Skills: ['MS Office', 'Typing', 'Customer Service', ' Internet', 'Operational', 'Customer service orientation']
#
# File: Sd yakub pasha - Relationship manager - 4 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Quick Learner', '']
# Technical Skills: ['SQL', 'MS Office', 'Cloud Computing', 'Operational']
#
# File: Senthilkumar Kulandaivelu_Work Assist.docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['Customer Service', 'NRI']
#
# File: Shabeer mulla - Sales officer - 3 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Customer Service', 'Patience', '']
# Technical Skills: ['Customer Service', 'Inventory Control']
#
# File: Shaik rehman - Sales executive - 5 Yrs 2 Months.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Shailendea singh pawar - Relationship manager - 7 Yrs 6 Months.docx
# Soft Skills: ['Team handling', 'Self-Motivated', 'Goal-Oriented', '']
# Technical Skills: ['Interpersonal Skills']
#
# File: Shailendea singh pawar - Relationship manager - 7 Yrs 6 Months_1.docx
# Soft Skills: ['Team handling', 'Self-Motivated', 'Goal-Oriented', '']
# Technical Skills: ['Interpersonal Skills']
#
# File: Shaisthabanu__Chennai_4.08_yrs.docx
# Soft Skills: ['Good Communication', '']
# Technical Skills: ['Java', 'Word', ' Internet']
#
# File: Shaisthabanu__Chennai_4.08_yrs_1.docx
# Soft Skills: ['Good Communication', '']
# Technical Skills: ['Java', 'Word', ' Internet']
#
# File: Shashank Paliwal - workassist.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: Sheeja Kuriakose-BM_Work Assist.docx
# Soft Skills: ['Team handling', 'Business Development', 'Sales', 'Customer Service', 'Compliance ', '']
# Technical Skills: ['Customer Service']
#
# File: Shubhanshi singh - Deputy manager - 6 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Quick Learner', '']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'Patient Care', 'Logistics']
#
# File: Shweta singh - Value banker - 8 Yrs 6 Months.docx
# Soft Skills: ['Relationship Management', 'Hard Working', '']
# Technical Skills: ['Excel', 'Word', 'Tally', 'CASA']
#
# File: Single  - Branch sales manager - 9 Yrs 1 Month.docx
# Soft Skills: ['Sales', 'Quick Learner', 'Compliance ', '']
# Technical Skills: ['Excel', 'MS Office', 'Typing', 'Interpersonal Skills', 'Operational', 'CASA', 'NRI']
#
# File: Single  - Branch sales manager - 9 Yrs 1 Month_1.docx
# Soft Skills: ['Sales', 'Quick Learner', 'Compliance ', '']
# Technical Skills: ['Excel', 'MS Office', 'Typing', 'Interpersonal Skills', 'Operational', 'CASA', 'NRI']
#
# File: Sivaraj  - Deputy manager - 4 Yrs 0 Month.docx
# Soft Skills: ['Business Development', 'Sales', '']
# Technical Skills: ['CASA']
#
# File: Sneha balasubramanyam - Manager retail - 6 Yrs 1 Month.docx
# Soft Skills: ['Sales', 'Quick Learner', '']
# Technical Skills: ['Excel', 'Microsoft Office', 'CASA']
#
# File: Sneha balasubramanyam - Manager retail - 6 Yrs 1 Month_1.docx
# Soft Skills: ['Sales', 'Quick Learner', '']
# Technical Skills: ['Excel', 'Microsoft Office', 'CASA']
#
# File: Sneha__Hyderabad_Secunderabad,Telangana_1_yrs.docx
# Soft Skills: ['Business Development', 'Sales', 'Hard Working', '']
# Technical Skills: ['Power Point', 'Excel', 'Word']
#
# File: Sneha__Hyderabad_Secunderabad,Telangana_1_yrs_1.docx
# Soft Skills: ['Business Development', 'Sales', 'Hard Working', '']
# Technical Skills: ['Power Point', 'Excel', 'Word']
#
# File: Soutick bhattacharjee  - Presently working in bandhan bank ltd as a branch sales officer from 17th aug2015 to till date. - 7 Yrs 0 Month (1) (2).docx
# Soft Skills: ['Hard Working', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office', 'Tally', 'CASA', 'NRI']
#
# File: Spondon neog  - Assistant manager - 7 Yrs 0 Month.docx
# Soft Skills: ['Good Communication', 'Sales', 'Customer Service', 'Quick Learner', 'Patience', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office', 'Tally', 'Customer Service', 'Interpersonal Skills', 'CASA']
#
# File: Spondon neog  - Assistant manager - 7 Yrs 0 Month_1.docx
# Soft Skills: ['Good Communication', 'Sales', 'Customer Service', 'Quick Learner', 'Patience', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'MS Office', 'Tally', 'Customer Service', 'Interpersonal Skills', 'CASA']
#
# File: Sunny Mukherjee..docx
# Soft Skills: ['Compliance ', '']
# Technical Skills: ['Vendor Management']
#
# File: Sunny Mukherjee._1.docx
# Soft Skills: ['Compliance ', '']
# Technical Skills: ['Vendor Management']
#
# File: SupriyaTarafdar__Guwahati_5.02_yrs.docx
# Soft Skills: ['Business Development', 'Positive Attitude', '']
# Technical Skills: ['SQL', 'MS Office', 'Tally', 'MS Access']
#
# File: SupriyaTarafdar__Guwahati_5.02_yrs_1.docx
# Soft Skills: ['Business Development', 'Positive Attitude', '']
# Technical Skills: ['SQL', 'MS Office', 'Tally', 'MS Access']
#
# File: Susanth koro - Senior officer - 7 Yrs 6 Months.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['MS Office', ' Internet']
#
# File: SYAMSUNDAR__Visakhapatnam_11.01_yrs.docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Tally']
#
# File: Tabraiz  mehdi  - Senior sales advisor - 8 Yrs 3 Months.docx
# Soft Skills: ['Good Communication', 'Sales', '']
# Technical Skills: ['SOP']
#
# File: Talla rajashekar reddy - Senior manager - 7 Yrs 0 Month (1).docx
# Soft Skills: ['Good Communication', 'Sales', 'Customer Service', 'Hard Working', '']
# Technical Skills: ['MS Office', 'Internet Browsing', 'Customer Service', ' Internet', 'Customer service orientation']
#
# File: Talla rajashekar reddy - Senior manager - 7 Yrs 0 Month (1)_1.docx
# Soft Skills: ['Good Communication', 'Sales', 'Customer Service', 'Hard Working', '']
# Technical Skills: ['MS Office', 'Internet Browsing', 'Customer Service', ' Internet', 'Customer service orientation']
#
# File: Talla rajashekar reddy - Senior manager - 7 Yrs 0 Month.docx
# Soft Skills: ['Good Communication', 'Sales', 'Customer Service', 'Hard Working', '']
# Technical Skills: ['MS Office', 'Internet Browsing', 'Customer Service', ' Internet', 'Customer service orientation']
#
# File: Talla rajashekar reddy - Senior manager - 7 Yrs 0 Month_1.docx
# Soft Skills: ['Good Communication', 'Sales', 'Customer Service', 'Hard Working', '']
# Technical Skills: ['MS Office', 'Internet Browsing', 'Customer Service', ' Internet', 'Customer service orientation']
#
# File: TimesJobs_ABHINAY Wasnik_148789305.docx
# Soft Skills: ['Good Communication', 'Sales', 'Customer Service', 'Comprehensive Problem Solving', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Customer Service', 'Interpersonal Skills', 'Microsoft Office', 'Operational']
#
# File: TimesJobs_ABHINAY Wasnik_148789305_1.docx
# Soft Skills: ['Good Communication', 'Sales', 'Customer Service', 'Comprehensive Problem Solving', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Customer Service', 'Interpersonal Skills', 'Microsoft Office', 'Operational']
#
# File: TimesJobs_Anurag Sharma_147281150.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: TimesJobs_APURBA BANERJEE _129653097.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: TimesJobs_APURBA BANERJEE _129653097_1.docx
# Soft Skills: ['Sales', '']
# Technical Skills: []
#
# File: TimesJobs_Dipak Mondal _142980348.docx
# Soft Skills: ['Good Communication', 'Sales', 'Customer Service', 'Compliance ', '']
# Technical Skills: ['MS Office', 'Customer Service', 'CASA']
#
# File: TimesJobs_Dipak Mondal _142980348_1.docx
# Soft Skills: ['Good Communication', 'Sales', 'Customer Service', 'Compliance ', '']
# Technical Skills: ['MS Office', 'Customer Service', 'CASA']
#
# File: TimesJobs_Eswari Gadepalli_145845543.docx
# Soft Skills: ['Business Development', 'Sales', 'Customer Service', 'Strategic Planning', 'Compliance ', '']
# Technical Skills: ['MS Office', 'Customer Service', 'CRM', 'Operational', 'Flexcube', 'Branch Banking Operations']
#
# File: TimesJobs_Eswari Gadepalli_145845543_1.docx
# Soft Skills: ['Business Development', 'Sales', 'Customer Service', 'Strategic Planning', 'Compliance ', '']
# Technical Skills: ['MS Office', 'Customer Service', 'CRM', 'Operational', 'Flexcube', 'Branch Banking Operations']
#
# File: TimesJobs_Haridas Khelkar_152290403.docx
# Soft Skills: ['Sales', 'Self-Motivated', 'Hard work', 'Digital Marketing', '']
# Technical Skills: ['Tally', 'CRM']
#
# File: TimesJobs_Haridas Khelkar_152290403_1.docx
# Soft Skills: ['Sales', 'Self-Motivated', 'Hard work', 'Digital Marketing', '']
# Technical Skills: ['Tally', 'CRM']
#
# File: TimesJobs_KUNAL CHAITRAM SHENDE _149170196.docx
# Soft Skills: ['']
# Technical Skills: ['Excel']
#
# File: TimesJobs_KUNAL CHAITRAM SHENDE _149170196_1.docx
# Soft Skills: ['']
# Technical Skills: ['Excel']
#
# File: TimesJobs_MOHMMAD SULTHAN_119871403.docx
# Soft Skills: ['Hard work', '']
# Technical Skills: ['Excel', 'MS Office', 'Tally', 'CASA']
#
# File: TimesJobs_MOHMMAD SULTHAN_119871403_1.docx
# Soft Skills: ['Hard work', '']
# Technical Skills: ['Excel', 'MS Office', 'Tally', 'CASA']
#
# File: TimesJobs_mukeesh ahmad _149515398.docx
# Soft Skills: ['Good Communication', 'Sales', 'Positive Attitude', 'Teamwork', '']
# Technical Skills: ['Teamwork']
#
# File: TimesJobs_Piyush  Garghate_152629533.docx
# Soft Skills: ['Good Communication', 'Sales', 'Teamwork', '']
# Technical Skills: ['Teamwork']
#
# File: TimesJobs_Piyush  Garghate_152629533_1.docx
# Soft Skills: ['Good Communication', 'Sales', 'Teamwork', '']
# Technical Skills: ['Teamwork']
#
# File: TimesJobs_Rahul Ganguly _144069423.docx
# Soft Skills: ['']
# Technical Skills: ['Excel', 'Microsoft Office']
#
# File: TimesJobs_Rahul Ganguly _144069423_1.docx
# Soft Skills: ['']
# Technical Skills: ['Excel', 'Microsoft Office']
#
# File: TimesJobs_Randhir kanojiya_151424264.docx
# Soft Skills: ['Good Communication', 'Sales', 'Team Management', 'Quick Learner', 'Teamwork', '']
# Technical Skills: [' Internet', 'Teamwork']
#
# File: TimesJobs_Randhir kanojiya_151424264_1.docx
# Soft Skills: ['Good Communication', 'Sales', 'Team Management', 'Quick Learner', 'Teamwork', '']
# Technical Skills: [' Internet', 'Teamwork']
#
# File: TimesJobs_SABIR ALAM_117478302.docx
# Soft Skills: ['Business Development', 'Basic Computer', '']
# Technical Skills: ['Word', 'Tally', ' Internet', 'CASA', 'NRI']
#
# File: TimesJobs_SABIR ALAM_117478302_1.docx
# Soft Skills: ['Business Development', 'Basic Computer', '']
# Technical Skills: ['Word', 'Tally', ' Internet', 'CASA', 'NRI']
#
# File: TimesJobs_Sandeep Singh _149274090.docx
# Soft Skills: ['Business Development', 'Sales', 'Customer Service', '']
# Technical Skills: ['Excel', 'MS Office', 'Data Analysis', 'Customer Service', ' Internet', 'CASA']
#
# File: TimesJobs_vikas yadav_144445882.docx
# Soft Skills: ['Analytical Skills', 'Sales', 'Team Management', '']
# Technical Skills: ['MS Office', 'Analytical Skills', ' Internet']
#
# File: TimesJobs_VIPIN Sakhare_148098130.docx
# Soft Skills: ['Sales', 'Customer Service', 'Positive Thinking', 'Hard work', '']
# Technical Skills: ['Excel', 'Word', 'Customer Service']
#
# File: TimesJobs_VIPIN Sakhare_148098130_1.docx
# Soft Skills: ['Sales', 'Customer Service', 'Positive Thinking', 'Hard work', '']
# Technical Skills: ['Excel', 'Word', 'Customer Service']
#
# File: Ujjwal mishra - Yes premia relationship manager - 9 Yrs 0 Month.docx
# Soft Skills: ['Sales', 'Positive Attitude', 'Compliance ', '']
# Technical Skills: []
#
# File: Ujjwal mishra - Yes premia relationship manager - 9 Yrs 0 Month_1.docx
# Soft Skills: ['Sales', 'Positive Attitude', 'Compliance ', '']
# Technical Skills: []
#
# File: Updated CV Gaurav.docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'Customer Service', 'Microsoft Office', 'NRI']
#
# File: Vikash sharma - Branch sales manager - 7 Yrs 3 Months.docx
# Soft Skills: ['Quick Learner', 'Hard work', '']
# Technical Skills: ['Interpersonal Skills']
#
# File: vikrantsingh__Gurgaon_Gurugram_8.1_yrs.docx
# Soft Skills: ['Team handling', 'Business Development', 'Sales', 'Team Management', 'Customer Service', '']
# Technical Skills: ['MS Office', 'Problem Solving and Decision Making', 'Customer Service']
#
# File: Viswa teja tiruvaipati - Relationship manager - 5 Yrs 0 Month.docx
# Soft Skills: ['']
# Technical Skills: ['Typing', 'Interpersonal Skills', 'CASA']
#
# File: Vivek singh - Manager - 3 Yrs 6 Months.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: work assist M.Bhakialakshmi[11y_0m] (1).docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['MS Office', 'Customer Service']
#
# File: Work Assist_AnileshKumarSingh[16y_0m].docx
# Soft Skills: ['Analytical Skills', 'Sales', 'Compliance ', '']
# Technical Skills: ['Excel', 'Financial Analysis', 'Analytical Skills']
#
# File: Work Assist_DEEPAKKUMAR[1y_0m].docx
# Soft Skills: ['Business Development', 'Customer Service', 'Self-Motivated', 'Accept Challenges', '']
# Technical Skills: ['Customer Service']
#
# File: Work Assist_DEEPAKKUMAR[1y_0m]_1.docx
# Soft Skills: ['Business Development', 'Customer Service', 'Self-Motivated', 'Accept Challenges', '']
# Technical Skills: ['Customer Service']
#
# File: Work Assist_DurgeshYadav[7y_0m].docx
# Soft Skills: ['Sales', 'Customer Service', 'Positive Attitude', 'Hard Working', 'Quick Learner', '']
# Technical Skills: ['Word', 'Customer Service', 'Interpersonal Skills', 'CASA']
#
# File: Work Assist_DurgeshYadav[7y_0m]_1.docx
# Soft Skills: ['Sales', 'Customer Service', 'Positive Attitude', 'Hard Working', 'Quick Learner', '']
# Technical Skills: ['Word', 'Customer Service', 'Interpersonal Skills', 'CASA']
#
# File: Work Assist_Resume Somya (1) (1).docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Work Assist_Resume Somya (1) (1)_1.docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Work Assist_Resume Somya (1).docx
# Soft Skills: ['']
# Technical Skills: []
#
# File: Work Assist_SachinKumar[17y_0m].docx
# Soft Skills: ['Compliance ', '']
# Technical Skills: ['Operational']
#
# File: WorkassistsPANKAJLOCHANSAHOO[12y_0m] (1).docx
# Soft Skills: ['Business Development', 'Sales', 'Customer Service', 'Compliance ', '']
# Technical Skills: ['Customer Service']
#
# File: Workassist_AnishKumar[3y_6m].docx
# Soft Skills: ['Business Development', '']
# Technical Skills: []
#
# File: Workassist_AritraChakraborty[18y_0m].docx
# Soft Skills: ['Analytical Skills', 'Team handling', 'Business Development', 'Sales', 'Customer Service', '']
# Technical Skills: ['Power Point', 'Excel', 'Word', 'Customer Service', 'Analytical Skills', 'CRM', 'CASA', 'TASc', 'Planning and organizing']
#
# File: Workassist_KrishanShekhawat[12y_0m].docx
# Soft Skills: ['Sales', 'Customer Service', 'Hard Working', 'Positive Thinking', 'Basic Computer', 'Straight Forward', '']
# Technical Skills: ['Excel', 'Word', 'MS Office', 'Time Management', 'Customer Service', ' Internet']
#
# File: Workassist_MAHENDRANAM[7y_0m] (1) (1).docx
# Soft Skills: ['Quick Learner', 'Hard work', '']
# Technical Skills: ['Tally']
#
# File: Workassist_Prashant.docx
# Soft Skills: ['Team handling', 'Sales', '']
# Technical Skills: ['MS Office', ' Internet']
#
# File: Workassist_Prashant_1.docx
# Soft Skills: ['Team handling', 'Sales', '']
# Technical Skills: ['MS Office', ' Internet']
#
# File: Workassist_Ranjit mhase  - Chief manager legal - 11 Yrs 0 Month.docx
# Soft Skills: ['Team Management', 'Customer Service', 'Compliance ', '']
# Technical Skills: ['MS Office', 'Customer Service', 'Interpersonal Skills']
#
# File: Workassist_rupamjha[1y_6m].docx
# Soft Skills: ['Sales', '']
# Technical Skills: ['Excel', 'Word', 'CASA']
#
# File: Workassist_VivekAwasthi[16y_0m].docx
# Soft Skills: ['Business Development', 'Sales', 'Relationship Management', 'Compliance ', '']
# Technical Skills: ['Excel', 'Word', 'Operations Management', 'CASA']
#
# File: workassit.in Pathachatterjee.docx
# Soft Skills: ['Sales', 'Customer Service', '']
# Technical Skills: ['Customer Service']

# %%
import os
import docx
import textract
import re
import openpyxl

def extract_skills_from_resume(file_path, skills_list):
    matched_skills = []

    # Extract text from different file formats
    file_extension = os.path.splitext(file_path)[1].lower()

    if file_extension == '.docx':
        doc = docx.Document(file_path)
        resume_text = ' '.join([p.text for p in doc.paragraphs])

    elif file_extension == '.pdf':
        resume_text = textract.process(file_path, method='pdfminer').decode('utf-8')

    elif file_extension == '.txt':
        with open(file_path, 'r', encoding='utf-8') as f:
            resume_text = f.read()

    else:
        return matched_skills

    for skill in skills_list:
        if re.search(r'\b' + re.escape(skill) + r'\b', resume_text, re.IGNORECASE):
            matched_skills.append(skill)

    return matched_skills


def extract_skills_from_folder(folder_path, soft_skills_list, technical_skills_list):
    matched_skills = []

    # Iterate through files in the folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Extract skills from each resume
        if os.path.isfile(file_path):
            soft_skills = extract_skills_from_resume(file_path, soft_skills_list)
            technical_skills = extract_skills_from_resume(file_path, technical_skills_list)
            if soft_skills or technical_skills:
                matched_skills.append((file_name, soft_skills, technical_skills))

    return matched_skills


# Example usage
folder_path = 'C:\\Users\\Shivam\\Desktop\\python\\300 work assist'
soft_skills = [ "Analytical Skills", "Good Communication", "Strong network", "Team handling", "Business Development",
               "Sales", "Team Management", "Customer Service", "Relationship Management", "Positive Attitude",
               "Comprehensive Problem Solving", "Efficient Time Management", "Hard Working", "Quick Learner",
               "Conversational Skills", "Self-Motivated", "Burning Desire to Succeed", "Adaptability to Change",
               "Multitasking Ability", "Calm under Pressure", "Patience", "Punctuality", "Self-Confidence",
               "Positive Thinking", "Passionate to learn", "Excellent motivation", "Convincing power",
               "Dedication and determination", "Relationship building", "Expert knowledge of the selling process",
               "Pro-active, organized, and a can-do attitude", "Interpersonal Organizational Skills", 
               "Sincerity towards Job", "Ability to Cope Under Pressure", "Meticulousness", "Versatility",
               "Independence", "Teamwork", "Goal-Oriented", "Strong Work Ethic", "Strong Client Relations",
               "Training Development Aptitude", "Basic Computer", "Good time management and organizational skills",
               "Excellent command over written and verbal communication", "Manage time & resources effectively",
               "Adaptable with positive & learning attitude", "Straight Forward", "Help & patience",
               "Basic Accounting", "Office Management", "Good knowledge of sales and marketing",
               "Knowledge of various types of sales", "Hard work", "Multitasking",
               "Good in preparing daily revenue Reports", "Good interpersonal and organizational skills",
               "To speak: Hindi, English, Telugu, and Urdu", "To understand: Marathi", "To write: Hindi",
               "Hardworking nature", "Team building and leadership qualities", "Market Research and Analysis",
               "Branding and Creative Skills", "Strategic Thinking", "Project Management", "Creativity and Innovation",
               "Adaptability and Flexibility", "Attention to Detail and Analytical Thinking", "Strategic Planning",
               "Brand Management", "Digital Marketing", "Creative Thinking and Content Creation",
               "Data Analysis and Insights", "Client Relationship Management", "Campaign Development and Execution",
               "Current-Account Knowledge", "Banking Operation Skills", "Work Management Skills", "Relationship Building",
               "Team Collaboration", "Conflict Resolution", "Continuous Learning","Never say die attitud","Give 100% to my job",
               "Fast Learner","Adaptable to all situations","Accept Challenges","Melting Knowledge","High Adaptability"
               "Self Confident and Hard Working","Dedication and Perfection in work","pressure handling","Very meticulous and versatile",
               "Sincerity towards job and punctuality","Able to cope under pressure","Convincing Power and good communication skills","self-motivate & dynamic",
               "emotionally stable","spoken communication skills","Achieving branch target","Sales and target oriented","Compliance ","Believe in ethics & morals",
               "Client Acquisition Skills.",""
              ]
technical_skills = [
"Python", "Java", "JavaScript", "HTML", "CSS", "SQL", "Power Point", "Excel", "Word", "MS Office", "C++ Basics",
"MS-CIT", "DCA (Diploma in Computer Application) MS-office, Photoshop", "Microsoft Outlook", "Windows 7&8",
"Windows XP, Vista, Win7 MS Office", "Tally ERP9", "Tally", "Typing", "Knowledge and operation of MS Office",
"Internet Browsing", "Programming Languages (e.g., Python, R)", "Database Management", "Machine Learning",
"Data Mining and Data Warehousing", "Data Analysis", "Statistical Analysis", "Data Visualization",
"Software Development", "Web Development", "Networking and Infrastructure", "Cybersecurity",
"Cloud Computing", "IT Support and Troubleshooting", "Construction Methods and Techniques",
"Blueprint Reading and Interpretation", "Safety and Compliance", "Materials and Equipment Handling",
"Problem Solving and Decision Making", "Quality Control and Assurance", "Communication and Negotiation",
"Construction Documentation", "Curriculum Development", "Instructional Design", "Classroom Management",
"Differentiated Instruction", "Student Assessment and Evaluation", "Technology Integration",
"Renewable Energy Technologies", "Energy Management", "Sustainability Practices", "Project Development and Implementation",
"Energy Policy and Regulations", "Data Analysis and Modeling", "Performance Skills", "Stage or Set Design",
"Production Management", "Scriptwriting or Screenwriting", "Directing or Choreography", "Creative Development",
"Improvisation", "Event Planning and Promotion", "Audience Engagement", "Fashion Design", "Trend Forecasting",
"Styling", "Garment Construction", "Textile Knowledge", "Fashion Illustration", "Fashion Branding",
"Fashion Merchandising", "Fashion Retailing", "Fashion Photography", "Fashion Marketing and PR",
"Fashion Technology", "Economic Modeling", "Policy Analysis", "Quantitative Research", "Economic Forecasting",
"Financial Analysis", "Microeconomic Theory", "Macroeconomic Analysis", "Econometric Analysis",
"Policy Evaluation", "Economic Reporting and Communication", "Economic Research", "Culinary Skills",
"Food Safety and Hygiene", "Menu Development", "Beverage Knowledge", "Operations Management",
"Knowledge of Dietary Restrictions", "Menu Costing and Profitability", "Patient Care", "Medical Knowledge",
"Clinical Skills", "Interdisciplinary Collaboration", "Problem-Solving and Critical Thinking",
"Empathy and Emotional Intelligence", "Time Management", "Adaptability and Flexibility", "Customer Service",
"Interpersonal Skills", "Conflict Resolution", "Multilingual Skills", "Sales and Upselling",
"Knowledge of Local Attractions", "Manufacturing Processes", "Equipment Operation", "Quality Control",
"Lean Manufacturing", "Safety Compliance", "Teamwork and Collaboration", "Mining Operations",
"Geological Knowledge", "Mine Planning and Management", "Maintenance and Repairs", "Environmental Stewardship",
"Data Analysis and Reporting", "Pharmaceutical Research", "Drug Development", "Regulatory Compliance",
"Pharmaceutical Manufacturing", "Analytical Skills", "Data Interpretation", "Documentation and Reporting",
"Project Management", "Network Operations", "Telecommunication Technologies", "System Maintenance",
"Troubleshooting", "Data and Voice Communication", "Network Security", "Customer Support", "Vendor Management",
"Transportation Operations", "Logistics", "Vehicle Operation", "Route Optimization", "Technology Proficiency","Microsoft Office",
"Knowledge of Banking Software","Proficiency in Data Management","CRM", "RAP", "Admin", "Flex-cube", "Fin-ware"," Internet","telly",
"MS Access","Foxpro","GST Training","Six Sigma Training","Completed 250 Hours of Computer Training Under ICWAI ITT Training Center;"
"Functional lessoning with IT Department;","Corporate Strategy", "Growth strategies"," Internal control","Business Reviews",
"Operational","business & Process excellence","Risk analysis","Annual Strategic Business/Operational & Financial planning and analysis",
"Revenue Planning Execution, analysis","assurance & enhancement","Industry & Competition analysis","Scenario Planning and analysis","SOP",
"DOA","Improvement in Policy","Process, System","organizational restructuring & audit Compliance","Demand & Supply planning","Business & Consumer analysis",
"Analytics & Insights","Financial resource/budget allocation","New business initiative","MIS & Dashboards","Internal Vigilance","Highlight area of concern and business risk",
"Post- merger integration","Flexcube","Windows,", "Nudi4.0","Big Data Analytics","Financial Risk Management","Financial Business Analytics","CNC Programmin","Internal Auditing",
"FX Online","I Neo+","Branch Banking Operations","Building and Maintaining relations with clients","Excellent Product Knowledge.","NETS", "Talisma","CTS 2010","CASA","TASc","NRI",
"Capacity of leading the team","Reporting Skills", "Administrative Writing Skills", "Communication skills - written and verbal","Planning and organizing", "Problem assessment and problem solving",
"Information gathering and information monitoring", "Attention to detail and accuracy","Inventory Control", "Managing Processes", "Customer service orientation", "Teamwork","Microsoft Office Skills",
"Installing configuring administrating software applications","Installation Experience of General Software Packages / Operating Systems"]


matched_skills = extract_skills_from_folder(folder_path, soft_skills, technical_skills)

# Create a new Excel workbook and select the active sheet
workbook = openpyxl.Workbook()
sheet = workbook.active

# Write the headers to the sheet
sheet.cell(row=1, column=1, value='File Name')
sheet.cell(row=1, column=2, value='Soft Skills')
sheet.cell(row=1, column=3, value='Technical Skills')

# Write the matched skills to the sheet
row_index = 2
for file_name, soft_skills, technical_skills in matched_skills:
    sheet.cell(row=row_index, column=1, value=file_name)
    sheet.cell(row=row_index, column=2, value=', '.join(soft_skills))
    sheet.cell(row=row_index, column=3, value=', '.join(technical_skills))
    row_index += 1

# Save the workbook
output_file = 'WA new 300 skills.xlsx'
workbook.save(output_file)
print(f"Output saved to {output_file}")
# Out:
# Output saved to WA new 300 skills.xlsx
