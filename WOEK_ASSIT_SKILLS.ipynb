# %%
import os
import docx
import textract
import re

def extract_skills_from_resume(file_path, skills_list):
    matched_skills = []

    # Extract text from different file formats
    file_extension = os.path.splitext(file_path)[1].lower()

    if file_extension == '.docx':
        doc = docx.Document(file_path)
        resume_text = ' '.join([p.text for p in doc.paragraphs])

    elif file_extension == '.pdf':
        resume_text = textract.process(file_path, method='pdfminer').decode('utf-8')

    elif file_extension == '.txt':
        with open(file_path, 'r', encoding='utf-8') as f:
            resume_text = f.read()

    else:
        return matched_skills

    for skill in skills_list:
        if re.search(r'\b' + re.escape(skill) + r'\b', resume_text, re.IGNORECASE):
            matched_skills.append(skill)

    # Check if any skills were found
    if matched_skills:
        return matched_skills
    else:
        return ['Skills not found']

def extract_skills_from_folder(folder_path, skills_list):
    matched_skills = []

    # Iterate through files in the folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Extract skills from each resume
        if os.path.isfile(file_path):
            skills = extract_skills_from_resume(file_path, skills_list)
            matched_skills.append((file_name, skills))

    return matched_skills

# Example usage
folder_path = 'C:\\Users\\Shivam\\Desktop\\python\\WA NEW 300+ FILES'
skills = ["Analytical Skills", "Good Communication","Willing to work early mornings, late nights, and weekends","Strong network", "Team handling", "Business Development",
               "Sales", "Team Management", "Customer Service", "Relationship Management", "Positive Attitude",
               "Comprehensive Problem Solving", "Efficient Time Management", "Hard Working", "Quick Learner",
               "Conversational Skills", "Self-Motivated", "Burning Desire to Succeed", "Adaptability to Change",
               "Multitasking Ability", "Calm under Pressure", "Patience", "Punctuality", "Self-Confidence",
               "Positive Thinking", "Passionate to learn", "Excellent motivation", "Convincing power",
               "Dedication and determination", "Relationship building", "Expert knowledge of the selling process",
               "Pro-active, organized, and a can-do attitude", "Interpersonal Organizational Skills", 
               "Sincerity towards Job", "Ability to Cope Under Pressure", "Meticulousness", "Versatility",
               "Independence", "Teamwork", "Goal-Oriented", "Strong Work Ethic", "Strong Client Relations",
               "Training Development Aptitude", "Basic Computer", "Good time management and organizational skills",
               "Excellent command over written and verbal communication", "Manage time & resources effectively",
               "Adaptable with positive & learning attitude", "Straight Forward", "Help & patience",
               "Basic Accounting", "Office Management", "Good knowledge of sales and marketing",
               "Knowledge of various types of sales", "Hard work", "Multitasking",
               "Good in preparing daily revenue Reports", "Good interpersonal and organizational skills",
               "To speak: Hindi, English, Telugu, and Urdu", "To understand: Marathi", "To write: Hindi",
               "Hardworking nature", "Team building and leadership qualities", "Market Research and Analysis",
               "Branding and Creative Skills","Goal Oriented", "Strategic Thinking", "Project Management", "Creativity and Innovation",
               "Adaptability and Flexibility", "Attention to Detail and Analytical Thinking", "Strategic Planning",
               "Brand Management", "Digital Marketing", "Creative Thinking and Content Creation",
               "Data Analysis and Insights", "Client Relationship Management", "Campaign Development and Execution",
               "Current-Account Knowledge", "Banking Operation Skills", "Work Management Skills", "Relationship Building",
               "Team Collaboration", "Conflict Resolution", "Continuous Learning","Never say die attitud","Give 100% to my job",
               "Fast Learner","Adaptable to all situations","Accept Challenges","Melting Knowledge","High Adaptability"
               "Self Confident and Hard Working","Dedication and Perfection in work","pressure handling","Very meticulous and versatile",
               "Sincerity towards job and punctuality","Able to cope under pressure","Convincing Power and good communication skills","self-motivate & dynamic",
               "emotionally stable","spoken communication skills","Achieving branch target","Sales and target oriented","Compliance ","Believe in ethics & morals",
               "Client Acquisition Skills.","Excellent speaking voice over the phone","Sincerity", "Able to maintain a flexible schedule", "Ability to identify problem areas and implement solutions",
               "Capable of maintaining confidentiality", "Exceptional written and verbal communication skills","Specialize in client servicing","Exceptional organizational skills", "Ability to solve problems independently",
               "Ability to multitask and meet deadlines", "Willing to work early mornings", "late nights and weekends","Excellent Attitude Towards Team Work And Common Goals", "Hardworking And Fast Learner",
                "Python", "Java", "JavaScript", "HTML", "CSS", "SQL", "Power Point", "Excel", "Word", "MS Office", "C++ Basics","C",
                "MS-CIT", "DCA (Diploma in Computer Application) MS-office, Photoshop", "Microsoft Outlook", "Windows 7&8",
                "Windows XP, Vista, Win7 MS Office", "Tally ERP9", "Tally", "Typing", "Knowledge and operation of MS Office",
                "Internet Browsing", "Programming Languages (e.g., Python, R)", "Database Management", "Machine Learning",
                "Data Mining and Data Warehousing", "Data Analysis", "Statistical Analysis", "Data Visualization",
                "Software Development", "Web Development", "Networking and Infrastructure", "Cybersecurity",
                "Cloud Computing", "IT Support and Troubleshooting", "Construction Methods and Techniques",
                "Blueprint Reading and Interpretation", "Safety and Compliance", "Materials and Equipment Handling",
                "Problem Solving and Decision Making", "Quality Control and Assurance", "Communication and Negotiation",
                "Construction Documentation", "Curriculum Development", "Instructional Design", "Classroom Management",
                "Differentiated Instruction", "Student Assessment and Evaluation", "Technology Integration",
                "Renewable Energy Technologies", "Energy Management", "Sustainability Practices", "Project Development and Implementation",
                "Energy Policy and Regulations", "Data Analysis and Modeling", "Performance Skills", "Stage or Set Design",
                "Production Management", "Scriptwriting or Screenwriting", "Directing or Choreography", "Creative Development",
                "Improvisation", "Event Planning and Promotion", "Audience Engagement", "Fashion Design", "Trend Forecasting",
                "Styling", "Garment Construction", "Textile Knowledge", "Fashion Illustration", "Fashion Branding",
                "Fashion Merchandising", "Fashion Retailing", "Fashion Photography", "Fashion Marketing and PR",
                "Fashion Technology", "Economic Modeling", "Policy Analysis", "Quantitative Research", "Economic Forecasting",
                "Financial Analysis", "Microeconomic Theory", "Macroeconomic Analysis", "Econometric Analysis",
                "Policy Evaluation", "Economic Reporting and Communication", "Economic Research", "Culinary Skills",
                "Food Safety and Hygiene", "Menu Development", "Beverage Knowledge", "Operations Management",
                "Knowledge of Dietary Restrictions", "Menu Costing and Profitability", "Patient Care", "Medical Knowledge",
                "Clinical Skills", "Interdisciplinary Collaboration", "Problem-Solving and Critical Thinking",
                "Empathy and Emotional Intelligence", "Time Management", "Adaptability and Flexibility", "Customer Service",
                "Interpersonal Skills", "Conflict Resolution", "Multilingual Skills", "Sales and Upselling",
                "Knowledge of Local Attractions", "Manufacturing Processes", "Equipment Operation", "Quality Control",
                "Lean Manufacturing", "Safety Compliance", "Teamwork and Collaboration", "Mining Operations",
                "Geological Knowledge", "Mine Planning and Management", "Maintenance and Repairs", "Environmental Stewardship",
                "Data Analysis and Reporting", "Pharmaceutical Research", "Drug Development", "Regulatory Compliance",
                "Pharmaceutical Manufacturing", "Analytical Skills", "Data Interpretation", "Documentation and Reporting",
                "Project Management", "Network Operations", "Telecommunication Technologies", "System Maintenance",
                "Troubleshooting", "Data and Voice Communication", "Network Security", "Customer Support", "Vendor Management",
                "Transportation Operations", "Logistics", "Vehicle Operation", "Route Optimization", "Technology Proficiency","Microsoft Office",
                "Knowledge of Banking Software","Proficiency in Data Management","CRM", "RAP", "Admin", "Flex-cube", "Fin-ware"," Internet","telly",
                "MS Access","Foxpro","GST Training","Six Sigma Training","Completed 250 Hours of Computer Training Under ICWAI ITT Training Center;"
                "Functional lessoning with IT Department;","Corporate Strategy", "Growth strategies"," Internal control","Business Reviews",
                "Operational","business & Process excellence","Risk analysis","Annual Strategic Business/Operational & Financial planning and analysis",
                "Revenue Planning Execution, analysis","assurance & enhancement","Industry & Competition analysis","Scenario Planning and analysis","SOP",
                "DOA","Improvement in Policy","Process, System","organizational restructuring & audit Compliance","Demand & Supply planning","Business & Consumer analysis",
                "Analytics & Insights","Financial resource/budget allocation","New business initiative","MIS & Dashboards","Internal Vigilance","Highlight area of concern and business risk",
                "Post- merger integration","Flexcube","Windows,", "Nudi4.0","Big Data Analytics","Financial Risk Management","Financial Business Analytics","CNC Programmin","Internal Auditing",
                "FX Online","I Neo+","Branch Banking Operations","Building and Maintaining relations with clients","Excellent Product Knowledge.","NETS", "Talisma","CTS 2010","CASA","TASc","NRI",
                "Capacity of leading the team","Reporting Skills", "Administrative Writing Skills", "Communication skills - written and verbal","Planning and organizing", "Problem assessment and problem solving",
                "Information gathering and information monitoring", "Attention to detail and accuracy","Inventory Control", "Managing Processes", "Customer service orientation", "Teamwork","Microsoft Office Skills",
                "Installing configuring administrating software applications","Installation Experience of General Software Packages / Operating Systems","Advanced Financial Modelling in MS-EXCEL",
                "Operating Systems: Windows 10, Linux, Ubuntu", "Bloomberg Terminal Proficiency","Excellent speaking voice over the phone","Able to maintain a flexible schedule","Ability to identify problem areas and implement solutions",
                "Capable of maintaining confidentiality","Exceptional written and verbal communication skills","Exceptional organizational skills","Ability to solve problems independently",
                "Ability to multitask and meet deadlines","Conflict resolution skills","Willingness to work early mornings, late nights, and weekends","Goal-oriented",
                "Good communication skills","Excellent attitude towards teamwork and common goals","Hardworking","Fast learner","C", "Java", "HTML", "Oracle", "VB", "COBOL","MS-Office", "Tally","Windows", "Linux", "Android",
                "Client Servicing", "Market Exploration", "Presentation", "Interpersonal", "Problem Solving", 
                "Multicultural", "Internet Awareness", "Typing", "Investment Management", "Marketing", "Sales", 
                "Customer Handling", "Query Handling", "Time Management", "Team Management", "Negotiation", 
                "MS Office", "MS Excel", "Banking Software", "MSCIT", "Financial Accounting", "Positive Attitude",
                "Strong Leadership Abilities","Team Player","Versatile","Quick Learner","Result-oriented","Career-focused","Analytical","Communication","Interpersonal","Financial Law","Drafting Complex Legal Documents","Real Estate","Civil Law",
                "Arbitration","Case Analysis","Corporate Law","Environmental Laws and Litigation","Corporate and Business Legal Issues","Commercial Litigation Experience","Sales and Marketing","Team Management","Dealer Management","Client Relationship Management",
                "Strategic Planning","Liaising and Coordination","Market Penetration","Training and Development","Business Development","Corporate Sales","B2B Sales","Business Alliance","Key Account Management","Channel Sales","Sales Strategy","Leadership and Development","Stress Testing","Risk Analytics","Market and Credit Risk Reporting",
                "Portfolio Management","Trend and Gap Analysis","Exposure Move Analysis","Change Management","Stakeholder Management","Performance Monitoring and Evaluation","Training and Knowledge Sharing","Team Building and Leadership","Legal Drafting","Legal Opinion","Legal Compliance",
                "Banking Law","Litigation","Legal Research","Legal Assistance","MS-EXEL","MS-POWERPOINT","Excellent speaking voice over the phone","Able to maintain a flexible schedule","Ability to identify problem areas and implement solutions","Capable of maintaining confidentiality",
                "Exceptional written and verbal communication skills","Exceptional organizational skills","Ability to solve problems independently","Ability to multitask and meet deadlines","Conflict resolution skills","Willing to work early mornings, late nights, and weekends",
                "Property Law","Problem Analysis and Solution","Excellent Verbal and Written Communication Skills","Ability to Work Under Pressure","Ability to Deal with People","Punctuality","Hard Worker","Optimistic and Motivational","Good Knowledge in MS Word, Excel, TallyERP9","Analytical and Critical Thinking",
                  "Problem Solving","Decision Making","Proactive","Numerical Competency","Software Languages: C, Java, Html","Utility Package: MS-office","Operating Systems: Windows, Linux, and Android",]

matched_skills = extract_skills_from_folder(folder_path, skills)

# Print file name and matched skills
for file_name, skills in matched_skills:
    print(f"File: {file_name}")
    print(f"Skills: {skills}")
    print()
# Out:
# File: (Workassist)GovindDOC-20221209-WA0001.docx
# Skills: ['Willing to work early mornings, late nights, and weekends', 'Project Management', 'Conflict Resolution', 'Excellent speaking voice over the phone', 'Able to maintain a flexible schedule', 'Ability to identify problem areas and implement solutions', 'Capable of maintaining confidentiality', 'Exceptional written and verbal communication skills', 'Exceptional organizational skills', 'Ability to solve problems independently', 'Ability to multitask and meet deadlines', 'Willing to work early mornings', 'Conflict Resolution', 'Project Management', 'Microsoft Office', 'Excellent speaking voice over the phone', 'Able to maintain a flexible schedule', 'Ability to identify problem areas and implement solutions', 'Capable of maintaining confidentiality', 'Exceptional written and verbal communication skills', 'Exceptional organizational skills', 'Ability to solve problems independently', 'Ability to multitask and meet deadlines', 'Conflict resolution skills', 'Communication', 'Excellent speaking voice over the phone', 'Able to maintain a flexible schedule', 'Ability to identify problem areas and implement solutions', 'Capable of maintaining confidentiality', 'Exceptional written and verbal communication skills', 'Exceptional organizational skills', 'Ability to solve problems independently', 'Ability to multitask and meet deadlines', 'Conflict resolution skills', 'Willing to work early mornings, late nights, and weekends']
#
# File: (Workassist)MUNJAMRAJKUMAR[6y_0m].docx
# Skills: ['Skills not found']
#
# File: (Workassist)NityanandPrajapati[8y_7m].docx
# Skills: ['Sales', 'Specialize in client servicing', 'Power Point', 'Excel', 'MS Office', 'C', 'C', 'Client Servicing', 'Presentation', 'Interpersonal', 'Problem Solving', 'Multicultural', 'Sales', 'MS Office', 'Communication', 'Interpersonal', 'Problem Solving']
#
# File: (Workassist)RAJUKOMMURI[6y_6m] (1).docx
# Skills: ['Sales', 'Excel', 'CASA', 'VB', 'Marketing', 'Sales']
#
# File: (Workassist)RAJUKOMMURI[6y_6m].docx
# Skills: ['Sales', 'Excel', 'CASA', 'VB', 'Marketing', 'Sales']
#
# File: (Workassist)Veena  - Branch manager - 13 Yrs 0 Month.docx
# Skills: ['Customer Service', 'HTML', 'Tally', 'Customer Service', 'Operational', 'HTML', 'Oracle', 'VB', 'COBOL', 'MS-Office', 'Tally', 'Communication']
#
# File: 0_Somnath Roy_16062023.docx
# Skills: ['Communication']
#
# File: Aashish maurya - Senior business development manager - 5 Yrs 0 Month.docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Quick Learner', 'Hard work', 'Project Management', 'Sincerity', 'Excel', 'Word', 'C', 'Tally', 'Customer Service', 'Project Management', 'CASA', 'C', 'Tally', 'Marketing', 'Sales', 'Negotiation', 'Quick Learner', 'Business Development', 'Hard Worker', 'Proactive']
#
# File: Abhilash's Resume-Updated (1).docx
# Skills: ['Skills not found']
#
# File: AKP CV.docx
# Skills: ['Power Point', 'Excel', 'Word', 'Microsoft Office', 'MS Excel']
#
# File: Altaf husen  - Relationship manager - 10 Yrs 0 Month (1).docx
# Skills: ['Sales', 'C', 'C', 'Sales', 'Portfolio Management']
#
# File: Amit kumar choudhary  - Deputy manager - 8 Yrs 0 Month.docx
# Skills: ['Sales', 'Positive Attitude', 'SQL', 'C', ' Internet', 'CASA', 'C', 'Oracle', 'Sales', 'Positive Attitude']
#
# File: Amrut sapre - Relationship manager - 9 Yrs 0 Month.docx
# Skills: ['Sales', 'Customer Service', 'Compliance ', 'C', 'Customer Service', 'Operational', 'CASA', 'C', 'Sales', 'Market Penetration', 'Channel Sales']
#
# File: Anilkumar kanjibhai dhola - Personal banker  management - 5 Yrs 0 Month (1).docx
# Skills: ['Sales', 'Marketing', 'Sales', 'Communication']
#
# File: Anju_CV-2-1667124936072.docx
# Skills: ['Hard Working', 'Compliance ', 'Excel', 'Word', 'C', 'Time Management', 'Microsoft Office', 'C', 'Time Management', 'Team Player', 'Versatile', 'Communication']
#
# File: Ankit kanani - Relationship manager - 7 Yrs 0 Month.docx
# Skills: ['Team handling', 'Sales', 'MS Office', 'CASA', 'Internet Awareness', 'Sales', 'MS Office']
#
# File: Arasay Aalam - workassist.docx
# Skills: ['Business Development', 'Sales', 'Basic Computer', 'Typing', 'MS-Office', 'Client Servicing', 'Typing', 'Sales', 'Business Development']
#
# File: ARPITA_RESUME-1676651734546 (1).docx
# Skills: ['C', 'C']
#
# File: ARPITA_RESUME-1676651734546.docx
# Skills: ['C', 'C']
#
# File: arsayalam - workassist.in.docx
# Skills: ['Business Development', 'Sales', 'Basic Computer', 'Typing', 'MS-Office', 'Client Servicing', 'Typing', 'Sales', 'Business Development']
#
# File: Ashim kumar das - Senior sales manager - 17 Yrs 0 Month (1).docx
# Skills: ['Sales', 'Sales']
#
# File: Ashim kumar das - Senior sales manager - 17 Yrs 0 Month.docx
# Skills: ['Sales', 'Sales']
#
# File: Asif ali - Erm - 5 Yrs 0 Month.docx
# Skills: ['Business Development', 'Word', 'Business Development']
#
# File: AYUSHI RESUME RO.docx
# Skills: ['Sales', 'Time Management', ' Internet', 'CASA', 'NRI', 'Investment Management', 'Marketing', 'Sales', 'Customer Handling', 'Time Management']
#
# File: Bharath kumar reddy - Assistant manager - 6 Yrs 0 Month (1).docx
# Skills: ['Sales', 'Sales', 'Team Player', 'Versatile', 'Analytical']
#
# File: Bharath kumar reddy - Assistant manager - 6 Yrs 0 Month (1)workassist.docx
# Skills: ['Sales', 'Sales', 'Team Player', 'Versatile', 'Analytical']
#
# File: Chetan CV 2022-1.docx
# Skills: ['Hard Working', 'Excel', 'Word', 'MS Office', 'C', 'C', 'MS Office']
#
# File: CV (1).docx
# Skills: ['Business Development', 'Sales', 'Excel', 'MS Office', ' Internet', 'Client Servicing', 'Problem Solving', 'Marketing', 'Sales', 'Customer Handling', 'MS Office', 'MS Excel', 'Sales and Marketing', 'Business Development', 'Hard Worker', 'Problem Solving']
#
# File: CV of Mr Ganesh Naidu (1).docx
# Skills: ['Business Development', 'Compliance ', 'Software Development', 'Logistics', 'SOP', 'Marketing', 'Negotiation', 'Real Estate', 'Corporate Law', 'Business Development', 'Litigation', 'Proactive']
#
# File: CV of Mr Ganesh Naidu.docx
# Skills: ['Business Development', 'Compliance ', 'Software Development', 'Logistics', 'SOP', 'Marketing', 'Negotiation', 'Real Estate', 'Corporate Law', 'Business Development', 'Litigation', 'Proactive']
#
# File: CV Umesh Khadpe.docx
# Skills: ['Sales', 'Compliance ', 'C', 'C', 'Marketing', 'Sales', 'Arbitration', 'Corporate Law', 'Litigation']
#
# File: CV.docx
# Skills: ['Business Development', 'Sales', 'Excel', 'MS Office', ' Internet', 'Client Servicing', 'Problem Solving', 'Marketing', 'Sales', 'Customer Handling', 'MS Office', 'MS Excel', 'Sales and Marketing', 'Business Development', 'Hard Worker', 'Problem Solving']
#
# File: Darpan shah - Personal banker - 9 Yrs 7 Months (1).docx
# Skills: ['Business Development', 'Sales', 'Tally', 'Operations Management', 'Microsoft Office', 'Tally', 'Windows', 'Presentation', 'Marketing', 'Sales', 'Communication', 'Business Development', 'Portfolio Management']
#
# File: Deependrasingh rawat  - Manager - 4 Yrs 0 Month.docx
# Skills: ['Sales', 'Sincerity', 'Marketing', 'Sales', 'Decision Making']
#
# File: Devashish bhoi  - Territory sales manager - 8 Yrs 5 Months.docx
# Skills: ['Sales', 'Customer Service', 'Power Point', 'Excel', 'Word', 'MS-CIT', 'Customer Service', 'Operational', 'Marketing', 'Sales']
#
# File: Dhara mehta - Branch manager - 14 Yrs 0 Month (1).docx
# Skills: ['Sales', 'MS Office', 'Customer Support', ' Internet', 'CASA', 'Sales', 'MS Office', 'Team Player', 'Communication']
#
# File: Dhara mehta - Branch manager - 14 Yrs 0 Month.docx
# Skills: ['Sales', 'MS Office', 'Customer Support', ' Internet', 'CASA', 'Sales', 'MS Office', 'Team Player', 'Communication']
#
# File: Dharani babu k - Manager - 16 Yrs 0 Month.docx
# Skills: ['Sales', 'Customer Service', 'CSS', 'SQL', 'C', 'Data Analysis', 'Software Development', 'Customer Service', 'Data Analysis and Reporting', 'Troubleshooting', 'Admin', ' Internet', 'Operational', 'Flexcube', 'C', 'Oracle', 'VB', 'Sales', 'Team Player', 'Analytical', 'Communication']
#
# File: Dixit Bhola _Workassist.docx
# Skills: ['Sales', 'Customer Service', 'Compliance ', 'Customer Service', 'Microsoft Office', 'Sales', 'Analytical', 'Communication']
#
# File: DOC-20220607-WA0003..docx
# Skills: ['Skills not found']
#
# File: DOC-20230628-WA0008..docx
# Skills: ['Analytical Skills', 'Business Development', 'Sales', 'Customer Service', 'Relationship Management', 'Project Management', 'Client Relationship Management', 'Compliance ', 'Operations Management', 'Customer Service', 'Interpersonal Skills', 'Analytical Skills', 'Project Management', 'CASA', 'Interpersonal', 'Marketing', 'Sales', 'Analytical', 'Communication', 'Interpersonal', 'Client Relationship Management', 'Market Penetration', 'Business Development']
#
# File: EXP SONU RESUME.docx
# Skills: ['Good Communication', 'C', 'Operational', 'Hardworking', 'C', 'Communication']
#
# File: Farooq inamdar  - Deputy manager - 7 Yrs 10 Months.docx
# Skills: ['Sales', 'Hard work', 'Fast Learner', 'Excel', 'Word', 'Tally', 'Interpersonal Skills', 'Fast learner', 'Tally', 'Interpersonal', 'Sales', 'Interpersonal']
#
# File: Gaurav kalbande - Senior manager - 10 Yrs 6 Months.docx
# Skills: ['Sales', 'Tally', 'CASA', 'Tally', 'Sales', 'Customer Handling', 'MSCIT', 'Financial Accounting']
#
# File: Govindaswamy k - Profile development manager - 6 Yrs 0 Month.docx
# Skills: ['Patience', 'Positive Thinking', 'Tally', 'Hardworking', 'Tally', 'Marketing']
#
# File: Gracy nadar - Virtual relationship manager - 7 Yrs 0 Month.docx
# Skills: ['Skills not found']
#
# File: Harminder singh  - Jtse - 10 Yrs 0 Month.docx
# Skills: ['Business Development', 'Sales', 'Positive Thinking', 'C', 'Hardworking', 'C', 'Marketing', 'Sales', 'Business Development']
#
# File: Heman kumar - Sales executive - 5 Yrs 6 Months.docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Positive Attitude', 'Excel', 'Word', 'Typing', 'Customer Service', 'Hardworking', 'Typing', 'Marketing', 'Sales', 'Positive Attitude', 'Team Player', 'Sales and Marketing', 'Business Development']
#
# File: Hinal goradia - Privilege banker - 5 Yrs 8 Months.docx
# Skills: ['Positive Attitude', 'Quick Learner', 'Self-Motivated', 'CASA', 'NRI', 'Positive Attitude', 'Quick Learner', 'Communication']
#
# File: Hyder abbas kazmi - Relationship manager - 8 Yrs 0 Month.docx
# Skills: ['Analytical Skills', 'MS Office', 'MS-CIT', 'Analytical Skills', 'MS Office', 'Analytical', 'Communication']
#
# File: iimjobs_Abhaya_Gurumurthy (1).docx
# Skills: ['Compliance ', 'C', 'C', 'Investment Management', 'Negotiation']
#
# File: iimjobs_Abhaya_Gurumurthy.docx
# Skills: ['Compliance ', 'C', 'C', 'Investment Management', 'Negotiation']
#
# File: iimjobs_Abhinav_Sharma.docx
# Skills: ['Skills not found']
#
# File: iimjobs_Aditya_Tyagi.docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Relationship Management', 'Customer Service', 'CRM', 'Operational', 'SOP', 'Marketing', 'Sales', 'Business Development']
#
# File: iimjobs_AMIT_AGARWAL.docx
# Skills: ['Sales', 'Self-Motivated', 'Compliance ', 'Power Point', 'Excel', 'Word', 'MS Office', 'Financial Analysis', 'Interpersonal', 'Sales', 'MS Office', 'Analytical', 'Interpersonal']
#
# File: iimjobs_Amit_Kumar_Pandey.docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Compliance ', 'Data Analysis', 'Food Safety and Hygiene', 'Customer Service', 'Vendor Management', 'Operational', 'SOP', 'Inventory Control', 'Marketing', 'Sales', 'Business Development']
#
# File: iimjobs_Anand_Shekhar.docx
# Skills: ['C', 'C', 'Marketing', 'Communication', 'Business Alliance', 'Litigation']
#
# File: iimjobs_Ansuman_Mohapatra.docx
# Skills: ['C', 'Operational', 'C', 'Presentation', 'Portfolio Management']
#
# File: iimjobs_Ashok_K_G.docx
# Skills: ['Sales', 'Positive Attitude', 'Python', 'Machine Learning', 'Data Analysis', 'Statistical Analysis', 'Marketing', 'Sales', 'Positive Attitude', 'Strong Leadership Abilities', 'Team Player', 'Versatile', 'Decision Making']
#
# File: iimjobs_Deepti_Suin.docx
# Skills: ['Sales', 'Customer Service', 'Relationship Management', 'Digital Marketing', 'Compliance ', 'Operations Management', 'Customer Service', 'CRM', 'Operational', 'Branch Banking Operations', 'CASA', 'Marketing', 'Sales', 'Communication']
#
# File: iimjobs_Dhiraj_Gupta.docx
# Skills: ['Time Management', 'Vendor Management', 'Marketing', 'Time Management', 'Versatile']
#
# File: iimjobs_Dr_Sridhar_Vangipuram.docx
# Skills: ['Team Management', 'Strategic Planning', 'Compliance ', 'Logistics', 'Team Management', 'Negotiation', 'Real Estate', 'Arbitration', 'Team Management', 'Strategic Planning', 'Litigation', 'Legal Research']
#
# File: iimjobs_D_S_Chauhan.docx
# Skills: ['Strategic Planning', 'Compliance ', ' Internal control', 'Operational', 'Risk analysis', 'Negotiation', 'Real Estate', 'Arbitration', 'Strategic Planning', 'Legal Opinion', 'Litigation', 'Decision Making']
#
# File: iimjobs_MAHESH_VINODRAI_SHUKLA (1).docx
# Skills: ['Skills not found']
#
# File: iimjobs_Mrityunjaya_Prasad_Gupta.docx
# Skills: ['Skills not found']
#
# File: iimjobs_Narendra.docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Client Relationship Management', 'Excel', 'Word', 'MS Office', 'Internet Browsing', 'Operations Management', 'Customer Service', 'SOP', 'Marketing', 'Sales', 'Team Management', 'MS Office', 'Communication', 'Team Management', 'Client Relationship Management', 'Training and Development', 'Business Development', 'MS-POWERPOINT']
#
# File: iimjobs_Priya_Autade.docx
# Skills: ['Skills not found']
#
# File: iimjobs_Purvi_Doctor.docx
# Skills: ['Quick Learner', 'Interpersonal', 'Multicultural', 'Team Player', 'Quick Learner', 'Result-oriented', 'Analytical', 'Communication', 'Interpersonal', 'Arbitration', 'Litigation']
#
# File: iimjobs_Rahul_Sundaram.docx
# Skills: ['Skills not found']
#
# File: iimjobs_Rajneesh_K_Jha.docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Compliance ', 'C', 'Operations Management', 'Customer Service', 'Vendor Management', 'Operational', 'Branch Banking Operations', 'NRI', 'C', 'Presentation', 'Interpersonal', 'Sales', 'Team Management', 'Team Player', 'Communication', 'Interpersonal', 'Team Management', 'Business Development', 'Change Management', 'Proactive']
#
# File: iimjobs_Rakesh_Kumar.docx
# Skills: ['Sales', 'Team Management', 'Quick Learner', 'MS Office', 'C', 'CRM', 'Growth strategies', 'C', 'Marketing', 'Sales', 'Team Management', 'MS Office', 'Quick Learner', 'Team Management', 'Dealer Management', 'Channel Sales']
#
# File: iimjobs_RAMAN_VYAS.docx
# Skills: ['Business Development', 'Sales', 'Strategic Planning', 'Brand Management', 'C', 'CRM', 'Inventory Control', 'C', 'Marketing', 'Sales', 'Analytical', 'Strategic Planning', 'Business Development', 'Corporate Sales', 'Key Account Management', 'Channel Sales']
#
# File: iimjobs_Sowmya_Padarthy.docx
# Skills: ['Skills not found']
#
# File: iimjobs_Sunil_Kheria.docx
# Skills: ['Skills not found']
#
# File: iimjobs_Surya_Pratap_Singh.docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Strategic Planning', 'Marketing', 'Sales', 'Team Management', 'Real Estate', 'Team Management', 'Strategic Planning', 'Business Development']
#
# File: iimjobs_TREESA_JACOB_P.docx
# Skills: ['Customer Service', 'Basic Computer', 'Compliance ', 'Power Point', 'Excel', 'Word', 'Customer Service', 'Team Player', 'Arbitration', 'Corporate Law', 'Legal Drafting', 'Legal Opinion', 'Legal Compliance', 'Banking Law', 'Litigation', 'Legal Research', 'Legal Assistance', 'Property Law']
#
# File: iimjobs_Varun_Kumar.docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Java', 'HTML', 'Excel', 'Word', 'MS Office', 'C', 'Customer Service', 'Logistics', ' Internet', 'Operational', 'C', 'Java', 'HTML', 'Windows', 'Marketing', 'Sales', 'MS Office', 'Business Development', 'Channel Sales']
#
# File: Ilakkiya  - Branch manager - 12 Yrs 0 Month.docx
# Skills: ['Sales', 'Customer Service', 'Compliance ', 'Customer Service', 'Operational', 'Marketing', 'Sales']
#
# File: Jyoti  - Sale executive - 3 Yrs 3 Months (1).docx
# Skills: ['Sales', 'Positive Attitude', 'C', ' Internet', 'Inventory Control', 'C', 'MS-Office', 'Marketing', 'Sales', 'Positive Attitude']
#
# File: KARTHICK RESUME 2022 UPDATEDD..... (1) (2) (2).docx
# Skills: ['Sales', 'Positive Attitude', 'Admin', 'Sales', 'Positive Attitude']
#
# File: Katariya jignesh pravinbhai - Junior sales officer - 4 Yrs 0 Month.docx
# Skills: ['Power Point', 'Excel', 'CASA']
#
# File: kiran3.docx
# Skills: ['Business Development', 'Sales', ' Internet', 'Sales', 'Business Development', 'B2B Sales']
#
# File: Komal mehta - Team leader &amp_ sales manager - 8 Yrs 0 Month.docx
# Skills: ['Good Communication', 'Sales', 'Goal Oriented', 'Fast Learner', 'Excellent Attitude Towards Team Work And Common Goals', 'Hardworking And Fast Learner', 'C', 'Good communication skills', 'Hardworking', 'Fast learner', 'C', 'Marketing', 'Sales', 'Communication']
#
# File: Koushik kumar pal - Sales exicutive - 10 Yrs 0 Month.docx
# Skills: ['Skills not found']
#
# File: Krishna roy - Sales executive - 5 Yrs 0 Month.docx
# Skills: ['Quick Learner', 'Excel', 'Word', 'C', 'C', 'Quick Learner', 'Communication', 'Ability to Deal with People', 'Hard Worker']
#
# File: Kritika maheshwari - Assistant manager - 1 Yr 0 Month.docx
# Skills: ['Skills not found']
#
# File: Lal gidwani - Arm - 2 Yrs 5 Months.docx
# Skills: ['Business Development', 'Sales', 'Goal Oriented', 'Excel', 'Word', 'Tally', 'Operational', 'MS-Office', 'Tally', 'Interpersonal', 'Problem Solving', 'Marketing', 'Sales', 'Financial Accounting', 'Analytical', 'Interpersonal', 'Business Development', 'Problem Solving']
#
# File: latest bio data.docx
# Skills: ['Sales', 'Quick Learner', 'Excel', 'Word', 'Admin', 'CASA', 'Sales', 'MS Excel', 'Quick Learner', 'Analytical', 'Communication']
#
# File: Legal_Profile_kp.docx
# Skills: ['Java', 'JavaScript', 'HTML', 'MS Office', 'C', ' Internet', 'C', 'Java', 'HTML', 'Windows', 'MS Office', 'Real Estate', 'Arbitration', 'Litigation']
#
# File: M velan - Sales manager - 15 Yrs 0 Month.docx
# Skills: ['Business Development', 'Sales', 'Relationship building', 'Relationship Building', 'Hardworking', 'Sales', 'Business Development']
#
# File: Mahamad dadapeer cv.docx
# Skills: ['Business Development', 'Sales', 'Hard work', 'Time Management', 'Hardworking', 'Interpersonal', 'Sales', 'Time Management', 'Communication', 'Interpersonal', 'Business Development', 'Proactive']
#
# File: Mangesh pakhle - Deputy manager - 9 Yrs 0 Month (1).docx
# Skills: ['Excel', 'Word', 'MS Office', 'C', 'MS-CIT', 'TASc', 'C', 'Windows', 'Presentation', 'MS Office']
#
# File: Mangesh pakhle - Deputy manager - 9 Yrs 0 Month (1)workassist.docx
# Skills: ['Sales', 'Excel', 'Word', 'MS Office', 'C', 'MS-CIT', 'TASc', 'C', 'Windows', 'Presentation', 'Sales', 'MS Office']
#
# File: Manish anand  - Senior manager - 9 Yrs 0 Month (1).docx
# Skills: ['Sales', 'Excel', 'Word', 'MS Office', 'CASA', 'Sales', 'MS Office']
#
# File: Manish anand  - Senior manager - 9 Yrs 0 Month.docx
# Skills: ['Sales', 'Excel', 'Word', 'MS Office', 'CASA', 'Sales', 'MS Office']
#
# File: Manoj parmar - Back office - 4 Yrs 3 Months.docx
# Skills: ['Skills not found']
#
# File: Manoj sharma - Relationship manager - 4 Yrs 0 Month.docx
# Skills: ['Sales', 'Positive Thinking', 'MS Office', 'C', 'C', 'Windows', 'Marketing', 'Sales', 'MS Office']
#
# File: Mansi nakkawar  - Relationship manager - 4 Yrs 3 Months.docx
# Skills: ['Sales', 'Relationship building', 'Relationship Building', 'C', 'CASA', 'C', 'Marketing', 'Sales', 'Portfolio Management']
#
# File: Md rijwan mallik - Manager( sales manager) - 7 Yrs 0 Month.docx
# Skills: ['Skills not found']
#
# File: Muskan  - Work assist (1).docx
# Skills: ['Sales', 'Positive Attitude', 'Excel', 'Word', 'Time Management', 'Hardworking', 'Sales', 'Time Management', 'MS Excel', 'Positive Attitude']
#
# File: Muthu krishnan s - Assistant manager - 3 Yrs 0 Monthworkassist.docx
# Skills: ['Business Development', 'Sales', 'Project Management', 'Digital Marketing', 'MS Office', 'C', 'Project Management', 'C', 'Marketing', 'Sales', 'MS Office', 'Business Development', 'Channel Sales']
#
# File: Nagaraj g - Sales executive - 1 Yr 7 Months (2).docx
# Skills: ['Word', 'Windows', 'MS-EXEL', 'MS-POWERPOINT']
#
# File: Nagaraj g - Sales executive - 1 Yr 7 Months.docx
# Skills: ['Word', 'Windows', 'MS-EXEL', 'MS-POWERPOINT']
#
# File: Nallannagari anjanareddy cv.docx
# Skills: ['Sales', 'Customer Service', 'MS Office', 'Customer Service', 'Hardworking', 'Sales', 'MS Office']
#
# File: Naresh kumar sharma - Branch operation executive - 1 Yr 10 Months.docx
# Skills: ['Sales', 'Customer Service', 'Excel', 'Word', 'Tally', 'Typing', 'Customer Service', 'Tally', 'Windows', 'Typing', 'Sales', 'Communication']
#
# File: Naukri_AAravindharaj[6y_6m].docx
# Skills: ['Team handling', 'Business Development', 'Sales', 'Hard work', 'Fast Learner', 'HTML', 'Power Point', 'Excel', 'Word', 'MS Office', 'C', 'Fast learner', 'C', 'HTML', 'Windows', 'Sales', 'MS Office', 'Business Development']
#
# File: Naukri_Abhishekjain[7y_0m].docx
# Skills: ['Sales', 'Self-Motivated', 'Hardworking', 'MS-Office', 'Windows', 'Presentation', 'Interpersonal', 'Problem Solving', 'Marketing', 'Sales', 'Analytical', 'Communication', 'Interpersonal', 'Problem Solving']
#
# File: Naukri_AjayDhiman[6y_6m].docx
# Skills: ['Sales', 'HTML', 'Excel', 'HTML', 'MS-Office', 'Sales']
#
# File: Naukri_AkshataSawant[12y_0m] (1).docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Quick Learner', 'Power Point', 'Excel', 'Word', 'Customer Service', 'NRI', 'Hardworking', 'Sales', 'Team Player', 'Quick Learner', 'Communication', 'Business Development']
#
# File: Naukri_AkshataSawant[12y_0m].docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Quick Learner', 'Power Point', 'Excel', 'Word', 'Customer Service', 'NRI', 'Hardworking', 'Sales', 'Team Player', 'Quick Learner', 'Communication', 'Business Development']
#
# File: Naukri_AliMirza[5y_6m].docx
# Skills: ['Sales', 'Customer Service', 'Power Point', 'Excel', 'Word', 'Customer Service', 'Sales', 'MS Excel']
#
# File: Naukri_AninditaBasak[15y_0m].docx
# Skills: ['Python', 'SQL', 'Cybersecurity', 'Troubleshooting', 'Windows']
#
# File: Naukri_ANIRBANCHAKROBORTY[6y_6m].docx
# Skills: ['Sales', 'CRM', 'Marketing', 'Sales']
#
# File: Naukri_AnkushDutta[12y_0m].docx
# Skills: ['Sales', 'Customer Service', 'Self-Motivated', 'Goal Oriented', 'Compliance ', 'Customer Service', 'Troubleshooting', 'Business Reviews', 'Presentation', 'Problem Solving', 'Sales', 'Team Player', 'Analytical', 'Real Estate', 'Problem Solving']
#
# File: Naukri_Anoop[10y_0m].docx
# Skills: ['Sales', 'MS Office', 'Tally', 'CRM', ' Internet', 'Flexcube', 'CASA', 'NRI', 'Tally', 'Sales', 'MS Office', 'Proactive']
#
# File: Naukri_AnujitBanerjee[17y_0m].docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Relationship Management', 'Excel', 'Word', 'C', 'Data Analysis', 'MS Access', 'C', 'Marketing', 'Sales', 'Team Management', 'MS Excel', 'Analytical', 'Communication', 'Team Management', 'Market Penetration', 'Business Development', 'B2B Sales', 'Channel Sales', 'Portfolio Management']
#
# File: Naukri_Aysha[16y_0m].docx
# Skills: ['Analytical Skills', 'Business Development', 'Sales', 'Relationship Management', 'Relationship building', 'Teamwork', 'Digital Marketing', 'Relationship Building', 'Compliance ', 'Excel', 'Time Management', 'Analytical Skills', 'Teamwork', 'Presentation', 'Interpersonal', 'Investment Management', 'Marketing', 'Sales', 'Time Management', 'Negotiation', 'Team Player', 'Analytical', 'Communication', 'Interpersonal', 'Real Estate', 'Business Development', 'Portfolio Management', 'Excellent Verbal and Written Communication Skills', 'Decision Making']
#
# File: Naukri_DeepakSudhakar[8y_0m].docx
# Skills: ['Good Communication', 'Customer Service', 'Self-Motivated', 'Customer Service', 'Problem Solving', 'Communication', 'Problem Solving']
#
# File: Naukri_dixitbhola[7y_0m].docx
# Skills: ['Sales', 'Customer Service', 'Compliance ', 'Customer Service', 'Microsoft Office', 'Sales', 'Analytical', 'Communication']
#
# File: Naukri_DURAIRAJK[12y_0m].docx
# Skills: ['Compliance ', 'Troubleshooting', 'Admin', 'Operational']
#
# File: Naukri_GEETHA[4y_6m].docx
# Skills: ['Customer Service', 'Customer Service', 'Communication']
#
# File: Naukri_Gopalkrishan[3y_0m].docx
# Skills: ['Business Development', 'Sales', 'Punctuality', 'Hard work', 'Goal Oriented', 'Interpersonal Skills', 'Hardworking', 'Interpersonal', 'Marketing', 'Sales', 'Team Player', 'Communication', 'Interpersonal', 'Business Development', 'Punctuality']
#
# File: Naukri_Gudduyadav[10y_0m].docx
# Skills: ['Sales', 'Positive Attitude', 'Basic Computer', 'Hardworking', 'Sales', 'Positive Attitude']
#
# File: Naukri_harikrishnan[7y_0m].docx
# Skills: ['Sales', 'Sales']
#
# File: Naukri_HarinderSingh[8y_0m].docx
# Skills: ['Sales', 'Customer Service', 'C', 'Customer Service', 'C', 'Marketing', 'Sales']
#
# File: Naukri_HarshitPandey[10y_0m].docx
# Skills: ['Skills not found']
#
# File: Naukri_HinaKousar[11y_10m].docx
# Skills: ['Skills not found']
#
# File: Naukri_IKRAthithaKarikalan[8y_0m].docx
# Skills: ['Marketing']
#
# File: Naukri_JoeSamuel[12y_0m].docx
# Skills: ['Business Development', 'CSS', 'Troubleshooting', 'NRI', 'Communication', 'Business Development']
#
# File: Naukri_jyotidhanda[10y_0m].docx
# Skills: ['Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Customer Service', 'Business Reviews', 'Operational', 'Inventory Control', 'Sales', 'Team Management', 'Team Management']
#
# File: Naukri_KalyanReddy[10y_0m].docx
# Skills: ['Customer Service', 'Compliance ', 'SQL', 'Customer Service', 'Network Security', 'Vendor Management', 'Operational', 'Windows', 'Linux', 'Negotiation', 'Change Management']
#
# File: Naukri_KaushalUnadkat[6y_0m].docx
# Skills: ['Sales', 'Self-Motivated', 'Excel', 'Word', 'Interpersonal Skills', 'CASA', 'MS-Office', 'Windows', 'Interpersonal', 'Sales', 'Team Player', 'Communication', 'Interpersonal']
#
# File: Naukri_KhusbuNeog[7y_5m].docx
# Skills: ['Good Communication', 'Sales', 'Customer Service', 'Hard Working', 'Hard work', 'Sincerity', 'Excel', 'MS Office', 'C', 'Customer Service', 'Interpersonal Skills', 'Quality Control', 'CRM', 'C', 'Interpersonal', 'Marketing', 'Sales', 'MS Office', 'Communication', 'Interpersonal', 'Ability to Deal with People']
#
# File: Naukri_LaxitaSatishTiwari[6y_0m].docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Relationship Management', 'Client Relationship Management', 'Excel', 'Operations Management', 'Customer Service', 'Marketing', 'Sales', 'Client Relationship Management', 'Business Development', 'Portfolio Management']
#
# File: Naukri_Mahiraj[1y_3m] (1).docx
# Skills: ['Brand Management', 'Marketing']
#
# File: Naukri_Manikandan[10y_0m].docx
# Skills: ['Customer Service', 'Data Analysis', 'Customer Service', 'Troubleshooting', ' Internet', 'Windows', 'Change Management']
#
# File: Naukri_MinuDhirajDubey[6y_0m].docx
# Skills: ['Sales', 'C', 'C', 'Presentation', 'Sales', 'Communication']
#
# File: Naukri_MohitWalia[14y_0m].docx
# Skills: ['Sales', 'Customer Service', 'Relationship Management', 'Self-Motivated', 'Patience', 'Compliance ', 'Customer Service', 'Interpersonal Skills', 'Regulatory Compliance', 'CRM', ' Internal control', 'Flexcube', 'CASA', 'Hardworking', 'MS-Office', 'Windows', 'Interpersonal', 'Problem Solving', 'Marketing', 'Sales', 'Negotiation', 'Analytical', 'Communication', 'Interpersonal', 'Problem Solving', 'Proactive']
#
# File: Naukri_NandiniR[12y_0m].docx
# Skills: ['Sales', 'Customer Service', 'Relationship Management', 'Self-Motivated', 'MS Office', 'Customer Service', 'Flex-cube', 'Operational', 'Sales', 'MS Office', 'Banking Software', 'Communication']
#
# File: Naukri_NAVINCHEERALAN[2y_8m].docx
# Skills: ['Relationship Management', 'Goal-Oriented', 'Hard work', 'Excel', 'C', 'Typing', 'Time Management', 'CRM', 'Goal-oriented', 'C', 'MS-Office', 'Windows', 'Problem Solving', 'Typing', 'Time Management', 'Problem Solving']
#
# File: Naukri_NikhilDeepakGowda[5y_4m].docx
# Skills: ['Skills not found']
#
# File: Naukri_NilanjanGhatak[6y_6m].docx
# Skills: ['Team handling', 'Sales', 'Word', 'Admin', 'Windows', 'Marketing', 'Sales', 'Communication']
#
# File: Naukri_NiteshkumarMishra[2y_0m].docx
# Skills: ['Sales', 'Hard work', 'Digital Marketing', 'Excel', 'Word', 'Web Development', 'CRM', 'Windows', 'Presentation', 'Marketing', 'Sales', 'MS-POWERPOINT']
#
# File: Naukri_NityanandPrajapati[8y_7m].docx
# Skills: ['Sales', 'Specialize in client servicing', 'Power Point', 'Excel', 'MS Office', 'C', 'C', 'Client Servicing', 'Presentation', 'Interpersonal', 'Problem Solving', 'Multicultural', 'Sales', 'MS Office', 'Communication', 'Interpersonal', 'Problem Solving']
#
# File: Naukri_OmPrakashPandey[10y_0m].docx
# Skills: ['Sales', 'Interpersonal Skills', 'Interpersonal', 'Marketing', 'Sales', 'Team Player', 'Communication', 'Interpersonal']
#
# File: Naukri_pankajpatil[5y_0m].docx
# Skills: ['Sales', 'Punctuality', 'Self-Confidence', 'Compliance ', 'Power Point', 'Excel', 'Word', 'MS Office', 'Hardworking', 'Windows', 'Sales', 'MS Office', 'Punctuality', 'Proactive']
#
# File: Naukri_PapaiPramanik[6y_0m].docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Customer Service', 'Windows', 'Sales', 'Customer Handling', 'Communication', 'Business Development', 'Key Account Management']
#
# File: Naukri_PeriyaPerumalJ[17y_0m] (1).docx
# Skills: ['Sales', 'Goal Oriented', 'Hardworking', 'Marketing', 'Sales']
#
# File: Naukri_PeriyaPerumalJ[17y_0m].docx
# Skills: ['Sales', 'Goal Oriented', 'Hardworking', 'Marketing', 'Sales']
#
# File: Naukri_Pradeep[2y_0m].docx
# Skills: ['Sales', 'Basic Computer', 'C', 'C', 'Sales']
#
# File: Naukri_PranshuSingh[2y_0m].docx
# Skills: ['Strong network', 'Sales', 'Python', 'SQL', 'Excel', 'Machine Learning', 'Data Analysis', 'Marketing', 'Sales', 'Negotiation', 'Real Estate', 'Proactive']
#
# File: Naukri_PraveenKumar[11y_7m].docx
# Skills: ['Skills not found']
#
# File: Naukri_Premnaths[5y_3m] (1).docx
# Skills: ['Team handling', 'Business Development', 'Sales', 'Marketing', 'Sales', 'Business Development']
#
# File: Naukri_Premnaths[5y_3m].docx
# Skills: ['Team handling', 'Business Development', 'Sales', 'Marketing', 'Sales', 'Business Development']
#
# File: Naukri_PriyankaAnchan[5y_0m].docx
# Skills: ['Word', 'MS-CIT']
#
# File: Naukri_PURANSINGH[7y_0m].docx
# Skills: ['Sales', 'C', 'C', 'Sales']
#
# File: Naukri_RAJANAPATEL[8y_0m].docx
# Skills: ['Team handling', 'Sales', 'Positive Attitude', 'Compliance ', 'Tally', 'Data Analysis', 'Interpersonal Skills', 'Flexcube', 'CASA', 'Oracle', 'Tally', 'Interpersonal', 'Sales', 'Positive Attitude', 'Analytical', 'Interpersonal']
#
# File: Naukri_RANGASWAMYDG[4y_0m] (1) (1) (1).docx
# Skills: ['Good Communication', 'Sales', 'Positive Attitude', 'Good communication skills', 'Problem Solving', 'Sales', 'Positive Attitude', 'Communication', 'Problem Solving']
#
# File: Naukri_RANGASWAMYDG[4y_0m] (1) (1).docx
# Skills: ['Good Communication', 'Sales', 'Positive Attitude', 'Good communication skills', 'Problem Solving', 'Sales', 'Positive Attitude', 'Communication', 'Problem Solving']
#
# File: Naukri_RanjithPathewar[11y_0m] (1).docx
# Skills: ['Business Development', 'Sales', 'Relationship Management', 'C', 'Time Management', 'CRM', 'CASA', 'C', 'Marketing', 'Sales', 'Time Management', 'Sales and Marketing', 'Business Development', 'Proactive']
#
# File: Naukri_RITESHNIGAM[10y_0m].docx
# Skills: ['Sales', 'Relationship Management', 'Calm under Pressure', 'Teamwork', 'Compliance ', 'Power Point', 'Excel', 'Word', 'MS Office', 'Operations Management', 'Teamwork', 'Sales', 'MS Office', 'Communication']
#
# File: Naukri_SagarDuttaGupta[7y_0m].docx
# Skills: ['Sales', 'Relationship Management', 'CASA', 'Sales']
#
# File: Naukri_Sahanurislam[5y_0m].docx
# Skills: ['Sales', ' Internet', 'Sales']
#
# File: Naukri_SaiSantoshKumarVyakaranam[10y_0m].docx
# Skills: ['Analytical Skills', 'Business Development', 'Sales', 'Relationship Management', 'Quick Learner', 'Self-Motivated', 'Relationship building', 'Relationship Building', 'Compliance ', 'Power Point', 'Excel', 'Word', 'C', 'Analytical Skills', 'CRM', ' Internet', 'CASA', 'C', 'Presentation', 'Interpersonal', 'Marketing', 'Sales', 'Negotiation', 'Banking Software', 'Quick Learner', 'Analytical', 'Communication', 'Interpersonal', 'Business Development']
#
# File: Naukri_SambathkumarNatarajan[13y_0m].docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Basic Computer', 'Time Management', 'Customer Service', 'SOP', 'CASA', 'Problem Solving', 'Marketing', 'Sales', 'Time Management', 'Communication', 'Business Development', 'Problem Solving']
#
# File: Naukri_SantoshSakharle[8y_2m].docx
# Skills: ['Analytical Skills', 'Good Communication', 'Team handling', 'Sales', 'HTML', 'C', 'Analytical Skills', 'C', 'HTML', 'VB', 'Presentation', 'Sales', 'Analytical', 'Communication']
#
# File: Naukri_SarojaRai[9y_0m].docx
# Skills: ['Skills not found']
#
# File: Naukri_SathishKumarMn[9y_0m] (1).docx
# Skills: ['Good Communication', 'Team handling', 'Business Development', 'Sales', 'Self-Motivated', 'Compliance ', 'C', 'Interpersonal Skills', 'CASA', 'Good communication skills', 'C', 'MS-Office', 'Windows', 'Presentation', 'Interpersonal', 'Sales', 'Negotiation', 'Communication', 'Interpersonal', 'Business Development']
#
# File: Naukri_SathishKumarMn[9y_0m].docx
# Skills: ['Good Communication', 'Team handling', 'Business Development', 'Sales', 'Self-Motivated', 'Compliance ', 'C', 'Interpersonal Skills', 'CASA', 'Good communication skills', 'C', 'MS-Office', 'Windows', 'Presentation', 'Interpersonal', 'Sales', 'Negotiation', 'Communication', 'Interpersonal', 'Business Development']
#
# File: Naukri_Shaktikumarsingh[6y_0m].docx
# Skills: ['Hard work', 'Project Management', 'Power Point', 'Excel', 'Word', 'Operations Management', 'Time Management', 'Interpersonal Skills', 'Project Management', 'Interpersonal', 'Time Management', 'Analytical', 'Communication', 'Interpersonal']
#
# File: Naukri_Sharathe[8y_0m].docx
# Skills: ['Compliance ', 'Python', 'Troubleshooting', 'Operational', 'Windows']
#
# File: Naukri_shashikumar[9y_6m].docx
# Skills: ['Skills not found']
#
# File: Naukri_SHYAMPRASADR[6y_6m].docx
# Skills: ['Sales', 'Customer Service', 'Relationship Management', 'Client Relationship Management', 'C', 'Customer Service', 'CASA', 'NRI', 'C', 'Interpersonal', 'Marketing', 'Sales', 'Analytical', 'Communication', 'Interpersonal', 'Real Estate', 'Client Relationship Management', 'Portfolio Management', 'Decision Making']
#
# File: Naukri_SonalKumari[7y_7m].docx
# Skills: ['Customer Service', 'Brand Management', 'Customer Service', 'Problem Solving', 'Marketing', 'Analytical', 'Communication', 'Training and Development', 'Problem Solving']
#
# File: Naukri_Sonam[8y_0m].docx
# Skills: ['Compliance ', 'Troubleshooting', 'Windows', 'Linux', 'Team Player']
#
# File: Naukri_Sonukumar[11y_0m].docx
# Skills: ['Troubleshooting', 'Network Security', 'Operational', 'SOP', 'Communication']
#
# File: Naukri_SRIBHASKARRAJUADAPA[11y_0m].docx
# Skills: ['Skills not found']
#
# File: Naukri_stalin[10y_0m].docx
# Skills: ['Analytical Skills', 'Customer Service', 'Excel', 'Tally', 'Customer Service', 'Analytical Skills', 'Tally', 'MS Excel', 'Team Player', 'Analytical', 'Communication']
#
# File: Naukri_SubramaniyasivaV[9y_0m].docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Relationship Management', 'CASA', 'NRI', 'Interpersonal', 'Marketing', 'Sales', 'Team Management', 'Interpersonal', 'Team Management', 'Business Development', 'Portfolio Management']
#
# File: Naukri_SUJAYANIHARAMIN[13y_0m].docx
# Skills: ['Quick Learner', 'Excel', 'Word', 'C', 'Tally', 'C', 'Tally', 'Interpersonal', 'Quick Learner', 'Communication', 'Interpersonal']
#
# File: Naukri_SumitraShetty[8y_0m].docx
# Skills: ['Good Communication', 'Sales', 'Customer Service', 'Relationship building', 'Teamwork', 'Relationship Building', 'Compliance ', 'C', 'Customer Service', 'Teamwork', 'Good communication skills', 'C', 'Interpersonal', 'Problem Solving', 'Marketing', 'Sales', 'Negotiation', 'Result-oriented', 'Communication', 'Interpersonal', 'Problem Solving']
#
# File: Naukri_SunilKumarPandey[10y_0m].docx
# Skills: ['Skills not found']
#
# File: Naukri_SurenderAnandhan[8y_0m].docx
# Skills: ['Customer Service', 'Hard work', 'Compliance ', 'Excel', 'Customer Service', 'Microsoft Office', 'MS Excel', 'Communication']
#
# File: Naukri_SyedUlMusaib[4y_6m].docx
# Skills: ['Good Communication', 'Punctuality', 'Typing', 'Hardworking', 'Typing', 'Communication', 'Punctuality']
#
# File: Naukri_Tamizlmaran[5y_2m] (1) (1).docx
# Skills: ['Hard work', 'MS Office', 'Tally', 'Tally', 'MS Office', 'Communication', 'Ability to Work Under Pressure']
#
# File: Naukri_Tamizlmaran[5y_2m].docx
# Skills: ['Hard work', 'MS Office', 'Tally', 'Tally', 'MS Office', 'Communication', 'Ability to Work Under Pressure']
#
# File: Naukri_TejasNandkumarSawant[6y_0m].docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Excel', 'C', 'Tally', 'C', 'Tally', 'Marketing', 'Sales', 'Team Management', 'Versatile', 'Team Management', 'Business Development']
#
# File: Naukri_variyarahulravjibhai[4y_0m] (1).docx
# Skills: ['Sales', 'Teamwork', 'Continuous Learning', 'Teamwork', 'Problem Solving', 'Sales', 'Problem Solving']
#
# File: Naukri_variyarahulravjibhai[4y_0m].docx
# Skills: ['Sales', 'Teamwork', 'Continuous Learning', 'Teamwork', 'Problem Solving', 'Sales', 'Problem Solving']
#
# File: Naukri_VIJAYAKUMARJOHNNADAR[9y_0m].docx
# Skills: ['Sales', 'Basic Computer', 'Sales']
#
# File: Naukri_VilaasMDekkate[12y_0m].docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Compliance ', 'Regulatory Compliance', 'CRM', 'Marketing', 'Sales', 'Team Management', 'Negotiation', 'Team Management', 'Business Development', 'Proactive']
#
# File: Naukri_vunnamharish[3y_4m].docx
# Skills: ['Skills not found']
#
# File: Navin kumar  - Business development officer - 4 Yrs 0 Month (1).docx
# Skills: ['Sales', 'Positive Attitude', 'Sincerity', 'Excel', 'C', 'CASA', 'Hardworking', 'C', 'Marketing', 'Sales', 'Positive Attitude']
#
# File: Network Security Engineer.docx
# Skills: ['Compliance ', 'Documentation and Reporting', 'Network Security', 'SOP', 'Analytical', 'Communication']
#
# File: new_CV_Vardhrajan Yogesh Singh-2.docx
# Skills: ['Skills not found']
#
# File: Niraj mishra - Deputy manager - signature rm - 5 Yrs 0 Monthworkassist (2).docx
# Skills: ['Sales', 'Strategic Planning', 'Excel', 'Word', 'MS-CIT', 'Tally', 'Interpersonal Skills', 'CASA', 'Tally', 'Presentation', 'Interpersonal', 'Sales', 'MS Excel', 'Communication', 'Interpersonal', 'Strategic Planning']
#
# File: Nirban das - Deputy manager - 5 Yrs 0 Month.docx
# Skills: ['Sales', 'Tally', 'Foxpro', 'Tally', 'Sales']
#
# File: Pankaj Resume-1687798925082-Pankaj Panini.docx
# Skills: ['Project Management', 'Project Management', 'SOP', 'Problem Solving', 'Analytical', 'Stakeholder Management', 'Problem Solving']
#
# File: Pawan hemant wakode - Advisor - 5 Yrs 0 Month.docx
# Skills: ['Power Point', 'Excel', 'Word']
#
# File: Pratham srivastava - Relationship manager - 8 Yrs 0 Monthworkassist (2).docx
# Skills: ['Sincerity', 'Excel', 'Word', 'C', 'Microsoft Office', 'C']
#
# File: Praveenkumar Resume.docx
# Skills: ['Punctuality', 'Teamwork', 'Teamwork', 'Punctuality']
#
# File: Pritam rane - Branch sales manager - 8 Yrs 0 Month (1)workassist.docx
# Skills: ['Sales', 'Tally', ' Internet', 'MS-Office', 'Tally', 'Windows', 'Sales']
#
# File: Pritesh nisar - Proffered relationship manager - 5 Yrs 0 Month.docx
# Skills: ['Excel', 'Tally', 'MS-Office', 'Tally']
#
# File: Priti  - Sr cashier - 9 Yrs 9 Months (1) (1).docx
# Skills: ['Sales', 'Customer Service', 'MS-CIT', 'Customer Service', 'SOP', 'MS-Office', 'Sales']
#
# File: Priti  - Sr cashier - 9 Yrs 9 Months (1).docx
# Skills: ['Sales', 'Customer Service', 'MS-CIT', 'Customer Service', 'SOP', 'MS-Office', 'Sales']
#
# File: Profile2023.docx
# Skills: ['Sales', 'Compliance ', 'C', 'C', 'Sales', 'Negotiation', 'Arbitration', 'Legal Drafting', 'Litigation', 'Property Law']
#
# File: Puneet bhati  - Current account relationship manager - 5 Yrs 0 Month.docx
# Skills: ['Analytical Skills', 'Sales', 'Comprehensive Problem Solving', 'Quick Learner', 'Compliance ', 'Excel', 'MS Office', 'C', 'Analytical Skills', 'C', 'Windows', 'Presentation', 'Interpersonal', 'Problem Solving', 'Sales', 'MS Office', 'Quick Learner', 'Analytical', 'Communication', 'Interpersonal', 'Hard Worker', 'Problem Solving']
#
# File: Puneet_Work Assist.docx
# Skills: ['Positive Attitude', 'Hard Working', 'Excel', 'Word', 'Manufacturing Processes', 'Planning and organizing', 'Positive Attitude', 'Communication']
#
# File: Raghu with 9+yrs post exp.docx
# Skills: ['Team Management', 'Comprehensive Problem Solving', 'Compliance ', 'C', 'Admin', 'Flexcube', 'CASA', 'C', 'Oracle', 'MS-Office', 'Windows', 'Problem Solving', 'Team Management', 'Communication', 'Team Management', 'Excellent Verbal and Written Communication Skills', 'Problem Solving']
#
# File: Rahul keshavan - Relationship manager trade and forex - 2 Yrs 0 Month (1).docx
# Skills: ['Presentation', 'Marketing']
#
# File: Rahul mahesuriya - Branch manager - 10 Yrs 0 Month.docx
# Skills: ['Excel', 'Word', 'Windows', 'Communication']
#
# File: Rahul singh tak - Portfolio manager - 5 Yrs 0 Month.docx
# Skills: ['Analytical Skills', 'Sales', 'Basic Computer', 'Excel', 'MS Office', 'Analytical Skills', 'CRM', 'CASA', 'Marketing', 'Sales', 'MS Office', 'MS Excel', 'Analytical', 'Portfolio Management']
#
# File: Raja karmakar - Client engagement manager - 8 Yrs 6 Months.docx
# Skills: ['Good Communication', 'Customer Service', 'Customer Service', 'Result-oriented', 'Communication', 'Ability to Deal with People']
#
# File: Rajesh paul  - Retention manager - 4 Yrs 6 Months workassist.docx
# Skills: ['Sales', 'Excel', 'CASA', 'MS-Office', 'Sales', 'Versatile']
#
# File: Rajeshrao p - Area sales manager - 14 Yrs 5 Months.docx
# Skills: ['Team handling', 'Business Development', 'Sales', 'Strategic Planning', 'Compliance ', 'C', 'C', 'MS-Office', 'Presentation', 'Problem Solving', 'Marketing', 'Sales', 'Negotiation', 'Dealer Management', 'Strategic Planning', 'Business Development', 'Problem Solving', 'Decision Making', 'Proactive']
#
# File: Rakesh k - Imperia rm - 10 Yrs 0 Month (1).docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Client Relationship Management', 'C', 'Customer Service', 'CASA', 'C', 'Marketing', 'Sales', 'Team Management', 'Team Management', 'Client Relationship Management', 'Business Development']
#
# File: Ramkrishna hariyani - Personal banker - 16 Yrs 0 Month.docx
# Skills: ['Good Communication', 'Sales', 'Team Management', 'Punctuality', 'Relationship building', 'Teamwork', 'Relationship Building', 'Continuous Learning', 'Sincerity', 'Excel', 'MS Office', 'C', 'Interpersonal Skills', 'CASA', 'Teamwork', 'C', 'Interpersonal', 'Marketing', 'Sales', 'Team Management', 'MS Office', 'Communication', 'Interpersonal', 'Team Management', 'Punctuality']
#
# File: Ranadip bhattacharjee - Sales officer - 4 Yrs 0 Month.docx
# Skills: ['Positive Attitude', 'Hard Working', 'Goal Oriented', 'Marketing', 'Positive Attitude']
#
# File: Ravi sai - Chief manager - 6 Yrs 0 Month (1).docx
# Skills: ['Customer Service', 'Quick Learner', 'C', 'Customer Service', 'Interpersonal Skills', 'C', 'Interpersonal', 'Team Player', 'Quick Learner', 'Communication', 'Interpersonal']
#
# File: Ravi sai - Chief manager - 6 Yrs 0 Month.docx
# Skills: ['Customer Service', 'Quick Learner', 'C', 'Customer Service', 'Interpersonal Skills', 'C', 'Interpersonal', 'Team Player', 'Quick Learner', 'Communication', 'Interpersonal']
#
# File: ReemaSarkar__Durgapur_3.03_yrs.docx
# Skills: ['Good Communication', 'Sales', 'Patience', 'Excel', 'Word', 'Tally', 'Good communication skills', 'Tally', 'Windows', 'Sales', 'MS Excel', 'Financial Accounting', 'Communication']
#
# File: Resume - Vishal Ravi (Feb 2022).docx
# Skills: ['Sales', 'C', 'C', 'Sales']
#
# File: Resume-Mane P S.docx
# Skills: ['Sales', 'Compliance ', 'C', 'Troubleshooting', 'C', 'Marketing', 'Sales', 'Negotiation', 'Communication', 'Arbitration', 'Litigation', 'Legal Research', 'Proactive']
#
# File: Resume-Tanu (1) (1).docx
# Skills: ['Sales', 'Customer Service', 'Compliance ', 'Excel', 'C', 'Customer Service', 'Operational', 'Planning and organizing', 'C', 'Problem Solving', 'Sales', 'MS Excel', 'Problem Solving', 'Decision Making']
#
# File: Resume-Tanu (1).docx
# Skills: ['Sales', 'Customer Service', 'Compliance ', 'Excel', 'C', 'Customer Service', 'Operational', 'Planning and organizing', 'C', 'Problem Solving', 'Sales', 'MS Excel', 'Problem Solving', 'Decision Making']
#
# File: Resume_Ankita-1657946147632.docx
# Skills: ['Good Communication', 'Power Point', 'Excel', 'Word', 'MS-CIT', 'Typing', 'Microsoft Office', 'Typing', 'Marketing', 'MS Excel', 'Analytical', 'Communication']
#
# File: Sagar Dutta Gupta-Kolkata_Work Assist.docx
# Skills: ['Sales', 'Relationship Management', 'CASA', 'Sales']
#
# File: SakshiGarg_CyberArk_4 exp_Sentry_Defender Certified.docx
# Skills: ['Positive Attitude', 'Self-Motivated', 'Patience', 'HTML', 'CSS', 'Time Management', 'Quality Control', 'Troubleshooting', 'HTML', 'Oracle', 'Windows', 'Linux', 'Time Management', 'Positive Attitude', 'Communication']
#
# File: Sandeep gupta - Manager ca aquisition - 6 Yrs 0 Month (2).docx
# Skills: ['Good Communication', 'Team handling', 'Sales', 'Positive Thinking', 'Tally', 'CRM', 'CASA', 'Tally', 'Sales', 'Communication']
#
# File: sanjana fresh kotak cv (1) (1).docx
# Skills: ['Sales', 'Word', 'MS Office', 'Operational', 'NRI', 'Problem Solving', 'Marketing', 'Sales', 'Negotiation', 'MS Office', 'Team Player', 'Problem Solving', 'Decision Making']
#
# File: Santanu paul  - Deputy manager - 8 Yrs 0 Month.docx
# Skills: ['Team handling', 'Sales', 'Patience', 'Quality Control', 'Risk analysis', 'MS-Office', 'Marketing', 'Sales', 'Portfolio Management']
#
# File: Saravanan a - Credit manager - 14 Yrs 6 Months.docx
# Skills: ['Sales', 'Customer Service', 'Compliance ', 'MS Office', 'Customer Service', 'CRM', 'Presentation', 'Sales', 'MS Office']
#
# File: SARMS MITRA-IRM_Work Assist.docx
# Skills: ['Sales', 'Customer Service', 'Compliance ', 'Excel', 'Customer Service', ' Internet', 'CASA', 'Marketing', 'Sales']
#
# File: Saurav kumar - Sales manager - 3 Yrs 0 Month.docx
# Skills: ['Business Development', 'Sales', 'Positive Thinking', 'Marketing', 'Sales', 'Business Development']
#
# File: Senthilkumar t  - Branch head - 15 Yrs 0 Month (1) (1).docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Positive Attitude', 'Relationship building', 'Relationship Building', 'Customer Service', 'Marketing', 'Sales', 'Team Management', 'Positive Attitude', 'Team Management', 'Business Development']
#
# File: Sharad rohila - Associate key relationship manager - 1 Yr 5 Months.docx
# Skills: ['Good Communication', 'Positive Attitude', 'Quick Learner', 'Good communication skills', 'Positive Attitude', 'Quick Learner', 'Analytical', 'Communication', 'Hard Worker']
#
# File: Shiv Sagar Barahpuriya- IRM_Work Assist.docx
# Skills: ['Sales', 'Compliance ', 'Excel', 'Word', 'MS Office', 'CASA', 'TASc', 'Windows', 'Client Servicing', 'Sales', 'MS Office', 'MSCIT']
#
# File: SHIVAM_SOOD_RESUME-1673336585745.docx
# Skills: ['Skills not found']
#
# File: Shivank  - Relationship manager wealth - 3 Yrs 2 Months (1).docx
# Skills: ['Team handling', 'Business Development', 'Sales', 'Presentation', 'Marketing', 'Sales', 'Communication', 'Business Development', 'Portfolio Management']
#
# File: ShivankSingh[5y_0m] (1).docx
# Skills: ['Team handling', 'Business Development', 'Sales', 'Customer Service', 'Excel', 'Word', 'C', 'Customer Service', 'Operational', 'C', 'Marketing', 'Sales', 'Sales and Marketing', 'Business Development', 'Portfolio Management']
#
# File: Shray Kamboj_Resume.docx
# Skills: ['Compliance ', 'Regulatory Compliance', 'Marketing', 'Negotiation', 'Real Estate', 'Arbitration', 'Corporate Law', 'Legal Compliance', 'Litigation']
#
# File: Smitha shivrajan - Manager - 15 Yrs 0 Month (1).docx
# Skills: ['Sales', 'Flexcube', 'CASA', 'Sales', 'Proactive']
#
# File: Smitha shivrajan - Manager - 15 Yrs 0 Month.docx
# Skills: ['Sales', 'Flexcube', 'CASA', 'Sales', 'Proactive']
#
# File: Smitha tp - Senior sales manager - 10 Yrs 0 Month.docx
# Skills: ['Sales', 'Sales']
#
# File: SOMNATHMACHINDRADESHMUKH[0y_9m]new-1.docx
# Skills: ['Sales', 'Goal Oriented', 'CRM', 'CASA', 'Sales', 'Portfolio Management', 'Hard Worker']
#
# File: Sonu Kumar-Resume _IT 2023 updated  (1).docx
# Skills: ['Skills not found']
#
# File: Sonu Kumar-Resume _IT 2023 updated .docx
# Skills: ['Skills not found']
#
# File: SRE Lead (Site Reliability Engineering Lead).docx
# Skills: ['Team Management', 'Python', 'Java', 'Interpersonal Skills', 'Operational', 'Java', 'Interpersonal', 'Team Management', 'Analytical', 'Communication', 'Interpersonal', 'Team Management']
#
# File: Subir mondal - Finance executive - 12 Yrs 6 Months (1).docx
# Skills: ['Sales', 'Hard Working', 'C', 'C', 'Sales']
#
# File: Subir mondal - Finance executive - 12 Yrs 6 Months.docx
# Skills: ['Sales', 'Hard Working', 'C', 'C', 'Sales']
#
# File: Sudip koner - Sales officer - 8 Yrs 0 Month (1).docx
# Skills: ['Skills not found']
#
# File: Sudip koner - Sales officer - 8 Yrs 0 Month.docx
# Skills: ['Skills not found']
#
# File: Sudip mukherjee - Senior bdm - 10 Yrs 0 Month.docx
# Skills: ['Sales', 'Positive Attitude', 'Self-Motivated', 'Goal Oriented', 'Time Management', 'Sales', 'Time Management', 'Positive Attitude', 'Team Player']
#
# File: Sweety dutta  - Sales officer business - 5 Yrs 0 Month (1).docx
# Skills: ['Quick Learner', 'Strong Work Ethic', 'C', 'C', 'Quick Learner']
#
# File: Sweety dutta  - Sales officer business - 5 Yrs 0 Month.docx
# Skills: ['Quick Learner', 'Strong Work Ethic', 'C', 'C', 'Quick Learner']
#
# File: Sweta  - Deputy manager - 4 Yrs 0 Monthworkassist.docx
# Skills: ['Sales', 'Hard work', 'Excel', 'MS Office', 'C', 'Tally', 'CASA', 'C', 'Tally', 'Windows', 'Sales', 'MS Office', 'MS Excel']
#
# File: TimesJobs_ANKUR RAJPUT _137495985.docx
# Skills: ['Basic Computer', 'MS Office', 'Tally', 'Microsoft Office', 'Tally', 'Presentation', 'Marketing', 'MS Office']
#
# File: TimesJobs_vijay Rahod_121871864 (1).docx
# Skills: ['Team Management', 'Customer Service', 'Power Point', 'Excel', 'Word', 'Customer Service', 'Customer Support', ' Internet', 'Operational', 'Windows', 'Client Servicing', 'Team Management', 'Team Management']
#
# File: TimesJobs_Yogesh Kumar_144332811.docx
# Skills: ['Sales', 'Positive Attitude', 'Power Point', 'Excel', 'Word', 'MS Office', ' Internet', 'CASA', 'Sales', 'MS Office', 'Positive Attitude']
#
# File: Ubaidullah tak - Cheif manager - 6 Yrs 10 Months.docx
# Skills: ['Sales', 'Customer Service', 'Relationship Management', 'Hard work', 'Sincerity', 'Power Point', 'Excel', 'Word', 'Customer Service', 'CRM', 'Operational', 'NRI', 'Sales']
#
# File: Untitled1.sav
# Skills: []
#
# File: Urvashi raj - Relationship manager - 3 Yrs 0 Month.docx
# Skills: ['Good Communication', 'Sales', 'Hard Working', 'Self-Motivated', 'Hard work', 'Sales', 'Communication', 'Hard Worker']
#
# File: Vaishnavig_Workassist (1).docx
# Skills: ['Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Client Relationship Management', 'Compliance ', 'Customer Service', 'Regulatory Compliance', 'Operational', 'CASA', 'Marketing', 'Sales', 'Team Management', 'Team Management', 'Client Relationship Management']
#
# File: Vaishnavig_Workassist.docx
# Skills: ['Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Client Relationship Management', 'Compliance ', 'Customer Service', 'Regulatory Compliance', 'Operational', 'CASA', 'Marketing', 'Sales', 'Team Management', 'Team Management', 'Client Relationship Management']
#
# File: Venkatramana r - Portfolio manager - 2 Yrs 6 Months.docx
# Skills: ['Quick Learner', 'Relationship building', 'Relationship Building', 'Excel', 'Financial Analysis', 'Quick Learner', 'Communication', 'Portfolio Management']
#
# File: Vikas kumar - Assistant manager - 5 Yrs 10 Monthsworkassist.docx
# Skills: ['Sales', 'Positive Attitude', 'Hard Working', 'CASA', 'Sales', 'Positive Attitude', 'Portfolio Management']
#
# File: Vinay thakur - Business development executive - 4 Yrs 8 Months.docx
# Skills: ['Hard Working', 'Accept Challenges', 'MS Office', 'Tally', 'Software Development', 'Tally', 'MS Office', 'Financial Accounting']
#
# File: Visharad Shukla-PRM_Work Assist.docx
# Skills: ['MS Office', 'Tally', 'Operational', 'Tally', 'Marketing', 'MS Office', 'Financial Accounting']
#
# File: Work Assist Niranjan.docx
# Skills: ['Sales', 'Quick Learner', 'Punctuality', 'Excel', 'C', 'CASA', 'C', 'Sales', 'Quick Learner', 'Punctuality']
#
# File: Work assist Swathi[15y_0m] (1).docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Customer Service', 'Relationship Management', 'Strategic Planning', 'Compliance ', 'MS Office', 'Time Management', 'Customer Service', 'Operational', 'CASA', 'NRI', 'Windows', 'Client Servicing', 'Marketing', 'Sales', 'Time Management', 'Team Management', 'MS Office', 'Result-oriented', 'Team Management', 'Strategic Planning', 'Business Development', 'Portfolio Management', 'Ability to Work Under Pressure', 'Proactive']
#
# File: Work Assist Venkatesh[6y_6m].docx
# Skills: ['Sales', 'Compliance ', 'Microsoft Office', 'NRI', 'Windows', 'Presentation', 'Sales']
#
# File: workassist -Ksenthilkumar[12y_0m] new.docx
# Skills: ['Sales', 'Team Management', 'Customer Service', 'Compliance ', 'MS Office', 'Problem Solving and Decision Making', 'Customer Service', ' Internal control', 'CASA', 'VB', 'Windows', 'Problem Solving', 'Sales', 'Team Management', 'MS Office', 'Analytical', 'Team Management', 'Change Management', 'Problem Solving', 'Decision Making']
#
# File: workassist ALAPATRA[6y_0m].docx
# Skills: ['Sales', 'Customer Service', 'Quick Learner', 'Excel', 'Word', 'MS Office', 'Improvisation', 'Customer Service', 'Windows', 'Presentation', 'Interpersonal', 'Marketing', 'Sales', 'MS Office', 'MS Excel', 'Team Player', 'Quick Learner', 'Interpersonal']
#
# File: workassist Ankitsharma[6y_6m].docx
# Skills: ['Sales', 'Self-Confidence', 'Basic Computer', 'Compliance ', 'Sincerity', 'Excel', 'MS Office', 'Tally', 'Hardworking', 'Tally', 'Sales', 'MS Office', 'MS Excel']
#
# File: workassist DEBASISHDEBNATH[3y_6m].docx
# Skills: ['Skills not found']
#
# File: Workassist Jaydeep (1).docx
# Skills: ['Good Communication', 'Positive Attitude', 'Typing', 'Good communication skills', 'Typing', 'Positive Attitude', 'Communication']
#
# File: Workassist Lakshmi  - Senior sales officer.docx
# Skills: ['Sales', 'Customer Service', 'Excel', 'Word', 'Customer Service', 'CASA', 'Windows', 'Sales']
#
# File: workassist SagarMadhukarBhople[6y_0m].docx
# Skills: ['Skills not found']
#
# File: Workassist-DilipKumarMishra[5y_0m].docx
# Skills: ['Good Communication', 'Sales', 'Quick Learner', 'Excel', 'Word', 'C', 'C', 'Marketing', 'Sales', 'Team Player', 'Quick Learner', 'Communication', 'Sales and Marketing']
#
# File: workassistPURANSINGH[7y_0m].docx
# Skills: ['Sales', 'C', 'C', 'Sales']
#
# File: Workassist_AbinBabuVarghese_Ipru_ b2b_ mumbai.docx
# Skills: ['Sales', 'Relationship Management', 'Quick Learner', 'Self-Motivated', 'Relationship building', 'Relationship Building', 'CSS', 'SQL', 'Excel', 'Word', 'MS Office', 'C', 'Tally', 'Time Management', 'C', 'Oracle', 'Tally', 'Sales', 'Time Management', 'MS Office', 'Team Player', 'Quick Learner']
#
# File: workassist_AdwityaRoshan[10y_0m].docx
# Skills: ['Sales', 'Excel', 'Word', 'Internet Browsing', 'Interpersonal Skills', 'SOP', 'Windows', 'Interpersonal', 'Sales', 'MS Excel', 'Team Player', 'Interpersonal']
#
# File: WorkAssist_AmarpreetMohanty_PMS_Bhubaneswar.docx
# Skills: ['Interpersonal Skills', 'Interpersonal', 'Interpersonal']
#
# File: workassist_ANKESHCHOUDHARY (1).docx
# Skills: ['Good Communication', 'Quick Learner', 'Self-Motivated', 'Internet Browsing', ' Internet', 'NRI', 'Interpersonal', 'Marketing', 'Team Player', 'Quick Learner', 'Communication', 'Interpersonal', 'Real Estate']
#
# File: workassist_ANKESHCHOUDHARY.docx
# Skills: ['Good Communication', 'Quick Learner', 'Self-Motivated', 'Internet Browsing', ' Internet', 'NRI', 'Interpersonal', 'Marketing', 'Team Player', 'Quick Learner', 'Communication', 'Interpersonal', 'Real Estate']
#
# File: Workassist_Bhumik.docx
# Skills: ['Sales', 'Hard work', 'Sales']
#
# File: WorkAssist_bijendrakumarhati[8y_0m].docx
# Skills: ['Business Development', 'Sales', 'Relationship Management', 'Quick Learner', 'Relationship building', 'Client Relationship Management', 'Relationship Building', 'Interpersonal Skills', 'Microsoft Office', ' Internet', 'CASA', 'Interpersonal', 'Problem Solving', 'Marketing', 'Sales', 'Team Player', 'Quick Learner', 'Analytical', 'Communication', 'Interpersonal', 'Sales and Marketing', 'Client Relationship Management', 'Business Development', 'Problem Solving']
#
# File: Workassist_Chandanvishwakarma[2y_1m].docx
# Skills: ['Team handling', 'Sales', 'Team Management', 'C', 'Microsoft Office', 'C', 'Marketing', 'Sales', 'Team Management', 'Team Management']
#
# File: WorkAssist_NarasimhamurthyK[15y_0m].docx
# Skills: ['Team handling', 'Business Development', 'Sales', 'Customer Service', 'Relationship Management', 'C', 'Time Management', 'Customer Service', 'C', 'Presentation', 'Marketing', 'Sales', 'Time Management', 'Negotiation', 'Business Development', 'Channel Sales', 'Portfolio Management']
#
# File: Workassist_SakeSakeSreekanth[2y_0m] (1) (1).docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Office Management', 'Hard work', 'Excel', 'C', 'Customer Service', 'NRI', 'C', 'Client Servicing', 'Interpersonal', 'Sales', 'Communication', 'Interpersonal', 'Business Development']
#
# File: workassist_ShivankSingh[5y_0m].docx
# Skills: ['Business Development', 'Sales', 'Customer Service', 'Excel', 'Word', 'C', 'Customer Service', 'Operational', 'C', 'Marketing', 'Sales', 'Sales and Marketing', 'Business Development', 'Portfolio Management']
#
# File: Workassist_SurendraGunna[9y_0m].docx
# Skills: ['Analytical Skills', 'Sales', 'Analytical Skills', 'Sales', 'Analytical', 'Corporate Sales']
#
# File: WorkAssist_sureshprasadMahto[14y_0m].docx
# Skills: ['Business Development', 'Sales', 'Team Management', 'Relationship Management', 'Relationship building', 'Client Relationship Management', 'Relationship Building', 'Excel', 'Word', 'MS Office', 'Interpersonal Skills', 'CRM', 'Windows', 'Interpersonal', 'Problem Solving', 'Investment Management', 'Sales', 'Team Management', 'MS Office', 'MS Excel', 'Analytical', 'Communication', 'Interpersonal', 'Team Management', 'Client Relationship Management', 'Business Development', 'Channel Sales', 'Portfolio Management', 'Problem Solving']
#
# File: workassit _shashikumar[9y_6m] (1).docx
# Skills: ['Skills not found']

# %%
import os
import docx
import textract
import re
import pandas as pd

def extract_skills_from_resume(file_path, skills_list):
    matched_skills = []

    # Extract text from different file formats
    file_extension = os.path.splitext(file_path)[1].lower()

    if file_extension == '.docx':
        doc = docx.Document(file_path)
        resume_text = ' '.join([p.text for p in doc.paragraphs])

    elif file_extension == '.pdf':
        resume_text = textract.process(file_path, method='pdfminer').decode('utf-8')

    elif file_extension == '.txt':
        with open(file_path, 'r', encoding='utf-8') as f:
            resume_text = f.read()

    else:
        return matched_skills

    matched_skills = [skill for skill in skills_list if re.search(r'\b' + re.escape(skill) + r'\b', resume_text, re.IGNORECASE)]
    return matched_skills if matched_skills else ['Skills not found']

def extract_skills_from_folder(folder_path, skills_list):
    matched_skills = []

    # Iterate through files in the folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Extract skills from each resume
        if os.path.isfile(file_path):
            skills = extract_skills_from_resume(file_path, skills_list)
            if skills:
                matched_skills.append([file_name, ', '.join(skills)])
            else:
                matched_skills.append([file_name, 'Skills not found'])

    return matched_skills

# Example usage
folder_path = 'C:\\Users\\Shivam\\Desktop\\python\\WA NEW 300+ FILES'
skills = ["Analytical Skills", "Good Communication","Willing to work early mornings, late nights, and weekends","Strong network", "Team handling", "Business Development",
               "Sales", "Team Management", "Customer Service", "Relationship Management", "Positive Attitude",
               "Comprehensive Problem Solving", "Efficient Time Management", "Hard Working", "Quick Learner",
               "Conversational Skills", "Self-Motivated", "Burning Desire to Succeed", "Adaptability to Change",
               "Multitasking Ability", "Calm under Pressure", "Patience", "Punctuality", "Self-Confidence",
               "Positive Thinking", "Passionate to learn", "Excellent motivation", "Convincing power",
               "Dedication and determination", "Relationship building", "Expert knowledge of the selling process",
               "Pro-active, organized, and a can-do attitude", "Interpersonal Organizational Skills", 
               "Sincerity towards Job", "Ability to Cope Under Pressure", "Meticulousness", "Versatility",
               "Independence", "Teamwork", "Goal-Oriented", "Strong Work Ethic", "Strong Client Relations",
               "Training Development Aptitude", "Basic Computer", "Good time management and organizational skills",
               "Excellent command over written and verbal communication", "Manage time & resources effectively",
               "Adaptable with positive & learning attitude", "Straight Forward", "Help & patience",
               "Basic Accounting", "Office Management", "Good knowledge of sales and marketing",
               "Knowledge of various types of sales", "Hard work", "Multitasking",
               "Good in preparing daily revenue Reports", "Good interpersonal and organizational skills",
               "To speak: Hindi, English, Telugu, and Urdu", "To understand: Marathi", "To write: Hindi",
               "Hardworking nature", "Team building and leadership qualities", "Market Research and Analysis",
               "Branding and Creative Skills","Goal Oriented", "Strategic Thinking", "Project Management", "Creativity and Innovation",
               "Adaptability and Flexibility", "Attention to Detail and Analytical Thinking", "Strategic Planning",
               "Brand Management", "Digital Marketing", "Creative Thinking and Content Creation",
               "Data Analysis and Insights", "Client Relationship Management", "Campaign Development and Execution",
               "Current-Account Knowledge", "Banking Operation Skills", "Work Management Skills", "Relationship Building",
               "Team Collaboration", "Conflict Resolution", "Continuous Learning","Never say die attitud","Give 100% to my job",
               "Fast Learner","Adaptable to all situations","Accept Challenges","Melting Knowledge","High Adaptability"
               "Self Confident and Hard Working","Dedication and Perfection in work","pressure handling","Very meticulous and versatile",
               "Sincerity towards job and punctuality","Able to cope under pressure","Convincing Power and good communication skills","self-motivate & dynamic",
               "emotionally stable","spoken communication skills","Achieving branch target","Sales and target oriented","Compliance ","Believe in ethics & morals",
               "Client Acquisition Skills.","Excellent speaking voice over the phone","Sincerity", "Able to maintain a flexible schedule", "Ability to identify problem areas and implement solutions",
               "Capable of maintaining confidentiality", "Exceptional written and verbal communication skills","Specialize in client servicing","Exceptional organizational skills", "Ability to solve problems independently",
               "Ability to multitask and meet deadlines", "Willing to work early mornings", "late nights and weekends","Excellent Attitude Towards Team Work And Common Goals", "Hardworking And Fast Learner",
                "Python", "Java", "JavaScript", "HTML", "CSS", "SQL", "Power Point", "Excel", "Word", "MS Office", "C++ Basics","C",
                "MS-CIT", "DCA (Diploma in Computer Application) MS-office, Photoshop", "Microsoft Outlook", "Windows 7&8",
                "Windows XP, Vista, Win7 MS Office", "Tally ERP9", "Tally", "Typing", "Knowledge and operation of MS Office",
                "Internet Browsing", "Programming Languages (e.g., Python, R)", "Database Management", "Machine Learning",
                "Data Mining and Data Warehousing", "Data Analysis", "Statistical Analysis", "Data Visualization",
                "Software Development", "Web Development", "Networking and Infrastructure", "Cybersecurity",
                "Cloud Computing", "IT Support and Troubleshooting", "Construction Methods and Techniques",
                "Blueprint Reading and Interpretation", "Safety and Compliance", "Materials and Equipment Handling",
                "Problem Solving and Decision Making", "Quality Control and Assurance", "Communication and Negotiation",
                "Construction Documentation", "Curriculum Development", "Instructional Design", "Classroom Management",
                "Differentiated Instruction", "Student Assessment and Evaluation", "Technology Integration",
                "Renewable Energy Technologies", "Energy Management", "Sustainability Practices", "Project Development and Implementation",
                "Energy Policy and Regulations", "Data Analysis and Modeling", "Performance Skills", "Stage or Set Design",
                "Production Management", "Scriptwriting or Screenwriting", "Directing or Choreography", "Creative Development",
                "Improvisation", "Event Planning and Promotion", "Audience Engagement", "Fashion Design", "Trend Forecasting",
                "Styling", "Garment Construction", "Textile Knowledge", "Fashion Illustration", "Fashion Branding",
                "Fashion Merchandising", "Fashion Retailing", "Fashion Photography", "Fashion Marketing and PR",
                "Fashion Technology", "Economic Modeling", "Policy Analysis", "Quantitative Research", "Economic Forecasting",
                "Financial Analysis", "Microeconomic Theory", "Macroeconomic Analysis", "Econometric Analysis",
                "Policy Evaluation", "Economic Reporting and Communication", "Economic Research", "Culinary Skills",
                "Food Safety and Hygiene", "Menu Development", "Beverage Knowledge", "Operations Management",
                "Knowledge of Dietary Restrictions", "Menu Costing and Profitability", "Patient Care", "Medical Knowledge",
                "Clinical Skills", "Interdisciplinary Collaboration", "Problem-Solving and Critical Thinking",
                "Empathy and Emotional Intelligence", "Time Management", "Adaptability and Flexibility", "Customer Service",
                "Interpersonal Skills", "Conflict Resolution", "Multilingual Skills", "Sales and Upselling",
                "Knowledge of Local Attractions", "Manufacturing Processes", "Equipment Operation", "Quality Control",
                "Lean Manufacturing", "Safety Compliance", "Teamwork and Collaboration", "Mining Operations",
                "Geological Knowledge", "Mine Planning and Management", "Maintenance and Repairs", "Environmental Stewardship",
                "Data Analysis and Reporting", "Pharmaceutical Research", "Drug Development", "Regulatory Compliance",
                "Pharmaceutical Manufacturing", "Analytical Skills", "Data Interpretation", "Documentation and Reporting",
                "Project Management", "Network Operations", "Telecommunication Technologies", "System Maintenance",
                "Troubleshooting", "Data and Voice Communication", "Network Security", "Customer Support", "Vendor Management",
                "Transportation Operations", "Logistics", "Vehicle Operation", "Route Optimization", "Technology Proficiency","Microsoft Office",
                "Knowledge of Banking Software","Proficiency in Data Management","CRM", "RAP", "Admin", "Flex-cube", "Fin-ware"," Internet","telly",
                "MS Access","Foxpro","GST Training","Six Sigma Training","Completed 250 Hours of Computer Training Under ICWAI ITT Training Center;"
                "Functional lessoning with IT Department;","Corporate Strategy", "Growth strategies"," Internal control","Business Reviews",
                "Operational","business & Process excellence","Risk analysis","Annual Strategic Business/Operational & Financial planning and analysis",
                "Revenue Planning Execution, analysis","assurance & enhancement","Industry & Competition analysis","Scenario Planning and analysis","SOP",
                "DOA","Improvement in Policy","Process, System","organizational restructuring & audit Compliance","Demand & Supply planning","Business & Consumer analysis",
                "Analytics & Insights","Financial resource/budget allocation","New business initiative","MIS & Dashboards","Internal Vigilance","Highlight area of concern and business risk",
                "Post- merger integration","Flexcube","Windows,", "Nudi4.0","Big Data Analytics","Financial Risk Management","Financial Business Analytics","CNC Programmin","Internal Auditing",
                "FX Online","I Neo+","Branch Banking Operations","Building and Maintaining relations with clients","Excellent Product Knowledge.","NETS", "Talisma","CTS 2010","CASA","TASc","NRI",
                "Capacity of leading the team","Reporting Skills", "Administrative Writing Skills", "Communication skills - written and verbal","Planning and organizing", "Problem assessment and problem solving",
                "Information gathering and information monitoring", "Attention to detail and accuracy","Inventory Control", "Managing Processes", "Customer service orientation", "Teamwork","Microsoft Office Skills",
                "Installing configuring administrating software applications","Installation Experience of General Software Packages / Operating Systems","Advanced Financial Modelling in MS-EXCEL",
                "Operating Systems: Windows 10, Linux, Ubuntu", "Bloomberg Terminal Proficiency","Excellent speaking voice over the phone","Able to maintain a flexible schedule","Ability to identify problem areas and implement solutions",
                "Capable of maintaining confidentiality","Exceptional written and verbal communication skills","Exceptional organizational skills","Ability to solve problems independently",
                "Ability to multitask and meet deadlines","Conflict resolution skills","Willingness to work early mornings, late nights, and weekends","Goal-oriented",
                "Good communication skills","Excellent attitude towards teamwork and common goals","Hardworking","Fast learner","C", "Java", "HTML", "Oracle", "VB", "COBOL","MS-Office", "Tally","Windows", "Linux", "Android",
                "Client Servicing", "Market Exploration", "Presentation", "Interpersonal", "Problem Solving", 
                "Multicultural", "Internet Awareness", "Typing", "Investment Management", "Marketing", "Sales", 
                "Customer Handling", "Query Handling", "Time Management", "Team Management", "Negotiation", 
                "MS Office", "MS Excel", "Banking Software", "MSCIT", "Financial Accounting", "Positive Attitude",
                "Strong Leadership Abilities","Team Player","Versatile","Quick Learner","Result-oriented","Career-focused","Analytical","Communication","Interpersonal","Financial Law","Drafting Complex Legal Documents","Real Estate","Civil Law",
                "Arbitration","Case Analysis","Corporate Law","Environmental Laws and Litigation","Corporate and Business Legal Issues","Commercial Litigation Experience","Sales and Marketing","Team Management","Dealer Management","Client Relationship Management",
                "Strategic Planning","Liaising and Coordination","Market Penetration","Training and Development","Business Development","Corporate Sales","B2B Sales","Business Alliance","Key Account Management","Channel Sales","Sales Strategy","Leadership and Development","Stress Testing","Risk Analytics","Market and Credit Risk Reporting",
                "Portfolio Management","Trend and Gap Analysis","Exposure Move Analysis","Change Management","Stakeholder Management","Performance Monitoring and Evaluation","Training and Knowledge Sharing","Team Building and Leadership","Legal Drafting","Legal Opinion","Legal Compliance",
                "Banking Law","Litigation","Legal Research","Legal Assistance","MS-EXEL","MS-POWERPOINT","Excellent speaking voice over the phone","Able to maintain a flexible schedule","Ability to identify problem areas and implement solutions","Capable of maintaining confidentiality",
                "Exceptional written and verbal communication skills","Exceptional organizational skills","Ability to solve problems independently","Ability to multitask and meet deadlines","Conflict resolution skills","Willing to work early mornings, late nights, and weekends",
                "Property Law","Problem Analysis and Solution","Excellent Verbal and Written Communication Skills","Ability to Work Under Pressure","Ability to Deal with People","Punctuality","Hard Worker","Optimistic and Motivational","Good Knowledge in MS Word, Excel, TallyERP9","Analytical and Critical Thinking",
                  "Problem Solving","Decision Making","Proactive","Numerical Competency","Software Languages: C, Java, Html","Utility Package: MS-office","Operating Systems: Windows, Linux, and Android",]

matched_skills = extract_skills_from_folder(folder_path, skills)

# Save output to Excel file
output_file = 'WA_KARAN_SIR_SKILLS.xlsx'
df = pd.DataFrame(matched_skills, columns=['File', 'Skills'])
df.to_excel(output_file, index=False)
print(f"Skills saved to {output_file} file.")
# Out:
# Skills saved to WA_KARAN_SIR_SKILLS.xlsx file.
